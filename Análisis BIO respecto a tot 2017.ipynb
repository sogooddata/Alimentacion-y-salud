# %%
# !pip install ppscore
# Out:
# ...
#      |████████████████████████████████| 47 kB 3.3 MB/s
# ...
#   Created wheel for ppscore: filename=ppscore-1.2.0-py2.py3-none-any.whl size=13067 sha256=dddd795545d316031e5193d505dd59e5922e1a3b9814b6115af0864504f64ad1
#   Stored in directory: /root/.cache/pip/wheels/d2/3c/58/2ff786414b21713edc6f4fdb54fdee89ac37bca5edd1f60634
# Successfully built ppscore
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib. pyplot as plt
import numpy as np
import colorama
import ppscore as pps

from seaborn import lmplot
from scipy import stats as ss
from colorama import Fore, Back, Style
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

Andalucia = pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Andalucia.xlsx')
Aragon= pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Aragon.xlsx')
Asturias=pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Asturias.xlsx')
Baleares=pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Baleares.xlsx')
C_Valenciana=pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\C_Valenciana.xlsx')
Canarias=pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Canarias.xlsx')
Cantabria=pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Cantabria.xlsx')
Castilla_La_Mancha=pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Castilla La Mancha.xlsx')
Castilla_Leon=pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Castilla y Leon.xlsx')
Catalunya = pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Catalunya.xlsx')
Ceuta_Melilla=pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Ceuta y Melilla.xlsx')
Extremadura = pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Extremadura.xlsx')
Galicia=pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Galicia.xlsx')
La_Rioja = pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\La Rioja.xlsx')
Madrid=pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Madrid.xlsx')
Murcia = pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Murcia.xlsx')
Navarra = pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Navarra.xlsx')
Pais_Vasco = pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Pais Vasco.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-0658b6067b9e> in <module>()
#      12 from sklearn.metrics import mean_squared_error
#      13
# ---> 14 Andalucia = pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Andalucia.xlsx')
#      15 Aragon= pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Aragon.xlsx')
#      16 Asturias=pd.read_excel('C:\\Users\\chari\\OneDrive\\Documentos\\So Good Data\\Datos Nielsen\\Nuevos datos\\Análisis\\Asturias.xlsx')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
# ...

# %%
#creo listas que me sirvan para etiquetas en los graficos
seccion=['alim seca', 'bebidas', 'conservas', 'leche y batidos', 'charcuteria', 'congelados', 'derv lacteos', 'precocinados', 'quesos']
alim_seca=['aceite', 'aditivos', 'alim infantiles', 'aperitivos', 'arroz', 'azucar', 'bolleria inds', 'cacao', 'cafes', 'cereales desayuno', 'chocolates', 'dieteticos', 'dulces navidad', 'frutos secos', 'galletas', 'golosinas', 'infusiones', 'legumbres', 'panaderia', 'pastas', 'reposteria', 'salsas', 'sopas deshid']
bebidas=['aguas', 'bebidas alcoholicas', 'refrescos', 'cerveza', 'espumosos', 'vinos', 'zumos']
conservas=['aceitunas', 'conservas carne', 'conservas frutas y dulces', 'conservas pescado', 'conservas vegetales', 'platos preparados']
leche_batidos=['batidos', 'horchata', 'leche liquida', 'leche no liquida']
charcuteria=['ahumados', 'charcuteria', 'pates refrigerados', 'salazones', 'salchichas', 'sobrasada']
congelados=['helados', 'otros congelados', 'pescados', 'pescados preparados', 'platos prep congelados', 'verduras congeladas']
derv_lacteos=['mantequilla', 'margarina', 'nata', 'postres preparados', 'quesos petit', 'yogures']
precocinados=['platos prep refrigerados']
quesos=['queso azul', 'queso bola', 'queso fresco', 'queso fundido', 'queso pasta blanda', 'queso rallado', 'queso tradicional', 'queso blanco past', 'requeson', 'resto quesos']

# %%
comunidades=['Andalucia', 'Aragon', 'Asturias', 'Baleares', 'C_Valenciana', 'Canarias', 'Cantabria', 'Castilla_La_Mancha', 'Castilla_Leon', 'Catalunya', 'Ceuta_Melilla', 'Extremadura', 'Galicia', 'La_Rioja', 'Madrid', 'Murcia', 'Navarra','Pais_Vasco']
poblacion_total_2017=[8379820, 1308750, 1034960, 1115999, 4941509, 2108121, 580295, 2031479, 2425801, 7555830, 85540, 1079339, 2708339, 315381, 6507184, 1470273, 643234, 2194158]
renta_por_hogar_2017=[23699, 29098, 27454, 32163, 24034, 22790, 27024, 23159, 26113, 31411, 31603, 20395, 26533, 28775, 32451, 23574, 33431, 34203]


#Bucle para obtener la media por semana y el total del consumo de 2017 de cada comunidad autónoma 
bio_2017=[]
no_bio_2017=[]
media_bio_2017=[]
media_no_bio_2017=[]
total_bio_2017=[]
total_no_bio_2017=[]

#inicio listas por sector y seccion BIO
alim_seca_bio_2017=[]
bebidas_bio_2017=[]
conservas_bio_2017=[]
leche_batidos_bio_2017=[]
charcuteria_bio_2017=[]
congelados_bio_2017=[]
derv_lacteos_bio_2017=[]
precocinados_bio_2017=[]
quesos_bio_2017=[]
alim_bebida_bio_2017=[]
prod_frescos_bio_2017=[]

total_alim_bebida_bio_2017=[]
total_prod_frescos_bio_2017=[]
total_alim_seca_bio_2017=[]
total_bebidas_bio_2017=[]
total_conservas_bio_2017=[]
total_leche_batidos_bio_2017=[]
total_charcuteria_bio_2017=[]
total_congelados_bio_2017=[]
total_derv_lacteos_bio_2017=[]
total_precocinados_bio_2017=[]
total_quesos_bio_2017=[]

#inicio las listas por sector y seccion NO BIO
alim_seca_no_bio_2017=[]
bebidas_no_bio_2017=[]
conservas_no_bio_2017=[]
leche_batidos_no_bio_2017=[]
charcuteria_no_bio_2017=[]
congelados_no_bio_2017=[]
derv_lacteos_no_bio_2017=[]
precocinados_no_bio_2017=[]
alim_bebida_no_bio_2017=[]
prod_frescos_no_bio_2017=[]
quesos_no_bio_2017=[]

total_alim_bebida_no_bio_2017=[]
total_prod_frescos_no_bio_2017=[]
total_alim_seca_no_bio_2017=[]
total_bebidas_no_bio_2017=[]
total_conservas_no_bio_2017=[]
total_leche_batidos_no_bio_2017=[]
total_charcuteria_no_bio_2017=[]
total_congelados_no_bio_2017=[]
total_derv_lacteos_no_bio_2017=[]
total_precocinados_no_bio_2017=[]
total_quesos_no_bio_2017=[]


for i in [Andalucia, Aragon, Asturias, Baleares, C_Valenciana, Canarias, Cantabria, Castilla_La_Mancha, Castilla_Leon, Catalunya, Ceuta_Melilla, Extremadura, Galicia, La_Rioja, Madrid, Murcia, Navarra,Pais_Vasco]:
    #Limpio datos quitando drogueria y mascotas
    no_drogueria=i.drop(i[i["SECTOR"] == "DROGUERIA Y PERFUMERIA"].index)
    no_mascotas=no_drogueria.drop(no_drogueria[no_drogueria["CATEGORIA"] == "ALIMENTOS MASCOTAS"].index)
    bio=no_mascotas.loc[:, 'SEGMENTO BIO'] == 'BIO'
    alim_bio= no_mascotas.loc[bio]
    no_bio=no_mascotas.loc[:, 'SEGMENTO BIO'] == 'NO BIO'
    alim_no_bio= no_mascotas.loc[no_bio]
    
    #Selecciono por sector BIO
    alim_bebida_b=alim_bio.loc[:,'SECTOR'] == 'ALIM. Y BEBIDAS'
    prod_frescos_b=alim_bio.loc[:, 'SECTOR'] == 'PROD.FRESCOS'
    
    alim_bebida_bio=alim_bio.loc[alim_bebida_b] 
    prod_frescos_bio=alim_bio.loc[prod_frescos_b]
    
    #Selecciono por seccion BIO
    alim_seca_b=alim_bio.loc[:,'SECCION'] == 'ALIM.SECA'
    bebidas_b=alim_bio.loc[:,'SECCION'] == 'BEBIDAS'
    conservas_b=alim_bio.loc[:,'SECCION'] == 'CONSERVAS'
    leche_batidos_b=alim_bio.loc[:,'SECCION'] == 'LECHE Y BATIDOS'
    charcuteria_b=alim_bio.loc[:,'SECCION'] == 'CHARCUTERIA'
    congelados_b=alim_bio.loc[:,'SECCION'] == 'CONGELADOS'
    derv_lacteos_b=alim_bio.loc[:,'SECCION'] == 'DERV.LACTEOS'
    quesos_b=alim_bio.loc[:,'SECCION'] == 'QUESOS'
    precocinados_b=alim_bio.loc[:,'SECCION'] == 'PL. COCINADOS Y PRECOCINADOS'
    
    alim_seca_bio=alim_bio.loc[alim_seca_b] 
    bebidas_bio=alim_bio.loc[bebidas_b] 
    conservas_bio=alim_bio.loc[conservas_b]
    leche_batidos_bio=alim_bio.loc[leche_batidos_b]
    charcuteria_bio=alim_bio.loc[charcuteria_b] 
    congelados_bio=alim_bio.loc[congelados_b] 
    derv_lacteos_bio=alim_bio.loc[derv_lacteos_b]
    quesos_bio=alim_bio.loc[quesos_b]
    precocinados_bio=alim_bio.loc[precocinados_b]
    
    #selecciono las ventas totales por semana BIO
    alim_bio_2017=alim_bio.loc[:,"SEMANA 01-17":"SEMANA 52-17"]
    total_bio_semana=alim_bio_2017.sum()
    
    #Selecciono ventas totales por sector y semana BIO
    alim_bebida_bio_17=alim_bebida_bio.loc[:,"SEMANA 01-17":"SEMANA 52-17"] 
    total_alim_bebida_bio_17=alim_bebida_bio_17.sum()
    
    prod_frescos_bio_17=prod_frescos_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"] 
    total_prod_frescos_bio_17=prod_frescos_bio_17.sum()
    
    #Selecciono ventas totales por sección y semana BIO
    alim_seca_bio_17=alim_seca_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_alim_seca_bio_17=alim_seca_bio_17.sum()
    
    bebidas_bio_17=bebidas_bio.loc[:,"SEMANA 01-17":"SEMANA 52-17"] 
    total_bebidas_bio_17=bebidas_bio_17.sum()
    
    conservas_bio_17=conservas_bio.loc[:,"SEMANA 01-17":"SEMANA 52-17"] 
    total_conservas_bio_17=conservas_bio_17.sum()
    
    leche_batidos_bio_17=leche_batidos_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_leche_batidos_bio_17=leche_batidos_bio_17.sum()
    
    charcuteria_bio_17=charcuteria_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_charcuteria_bio_17=charcuteria_bio_17.sum()
    
    congelados_bio_17=congelados_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_congelados_bio_17=congelados_bio_17.sum()
    
    derv_lacteos_bio_17=derv_lacteos_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_derv_lacteos_bio_17=derv_lacteos_bio_17.sum()

    quesos_bio_17=quesos_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_quesos_bio_17=quesos_bio_17.sum()
    
    precocinados_bio_17=precocinados_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_precocinados_bio_17=precocinados_bio_17.sum()
    
    #Selecciono por sector NO BIO
    alim_bebida_n=alim_no_bio.loc[:,'SECTOR'] == 'ALIM. Y BEBIDAS'
    prod_frescos_n=alim_no_bio.loc[:, 'SECTOR'] == 'PROD.FRESCOS'
    
    alim_bebida_no_bio=alim_no_bio.loc[alim_bebida_n] 
    prod_frescos_no_bio=alim_no_bio.loc[prod_frescos_n]
    
    #Selecciono por seccion NO BIO
    alim_seca_n=alim_no_bio.loc[:,'SECCION'] == 'ALIM.SECA'
    bebidas_n=alim_no_bio.loc[:,'SECCION'] == 'BEBIDAS'
    conservas_n=alim_no_bio.loc[:,'SECCION'] == 'CONSERVAS'
    leche_batidos_n=alim_no_bio.loc[:,'SECCION'] == 'LECHE Y BATIDOS'
    charcuteria_n=alim_no_bio.loc[:,'SECCION'] == 'CHARCUTERIA'
    congelados_n=alim_no_bio.loc[:,'SECCION'] == 'CONGELADOS'
    derv_lacteos_n=alim_no_bio.loc[:,'SECCION'] == 'DERV.LACTEOS'
    quesos_n=alim_no_bio.loc[:,'SECCION'] == 'QUESOS'
    precocinados_n=alim_no_bio.loc[:,'SECCION'] == 'PL. COCINADOS Y PRECOCINADOS'
    
    alim_seca_no_bio=alim_no_bio.loc[alim_seca_n] 
    bebidas_no_bio=alim_no_bio.loc[bebidas_n] 
    conservas_no_bio=alim_no_bio.loc[conservas_n]
    leche_batidos_no_bio=alim_no_bio.loc[leche_batidos_n]
    charcuteria_no_bio=alim_no_bio.loc[charcuteria_n] 
    congelados_no_bio=alim_no_bio.loc[congelados_n] 
    derv_lacteos_no_bio=alim_no_bio.loc[derv_lacteos_n]
    quesos_no_bio=alim_no_bio.loc[quesos_n]
    precocinados_no_bio=alim_no_bio.loc[precocinados_n]
    
    #Selecciono las ventas totales por semana NO BIO
    alim_no_bio_2017=alim_no_bio.loc[:,"SEMANA 01-17":"SEMANA 52-17"]
    total_no_bio_semana=alim_no_bio_2017.sum()
    
   #Selecciono ventas totales por sector y semana NO BIO
    alim_bebida_no_bio_17=alim_bebida_no_bio.loc[:,"SEMANA 01-17":"SEMANA 52-17"] 
    total_alim_bebida_no_bio_17=alim_bebida_no_bio_17.sum()
    
    prod_frescos_no_bio_17=prod_frescos_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"] 
    total_prod_frescos_no_bio_17=prod_frescos_no_bio_17.sum()
    
    #Selecciono ventas totales por sección y semana NO BIO
    alim_seca_no_bio_17=alim_seca_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_alim_seca_no_bio_17=alim_seca_no_bio_17.sum()
    
    bebidas_no_bio_17=bebidas_no_bio.loc[:,"SEMANA 01-17":"SEMANA 52-17"] 
    total_bebidas_no_bio_17=bebidas_no_bio_17.sum()
    
    conservas_no_bio_17=conservas_no_bio.loc[:,"SEMANA 01-17":"SEMANA 52-17"] 
    total_conservas_no_bio_17=conservas_no_bio_17.sum()
    
    leche_batidos_no_bio_17=leche_batidos_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_leche_batidos_no_bio_17=leche_batidos_no_bio_17.sum()
    
    charcuteria_no_bio_17=charcuteria_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_charcuteria_no_bio_17=charcuteria_no_bio_17.sum()
    
    congelados_no_bio_17=congelados_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_congelados_no_bio_17=congelados_no_bio_17.sum()
    
    derv_lacteos_no_bio_17=derv_lacteos_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_derv_lacteos_no_bio_17=derv_lacteos_no_bio_17.sum()

    quesos_no_bio_17=quesos_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_quesos_no_bio_17=quesos_no_bio_17.sum()
    
    precocinados_no_bio_17=precocinados_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_precocinados_no_bio_17=precocinados_no_bio_17.sum()

#COMPLETO LAS LISTAS INICIADAS
    #Completo las listas BIO
    bio_2017.append(alim_bio_2017)
    media_bio_2017.append(total_bio_semana.mean())
    total_bio_2017.append(total_bio_semana.sum())
    
    
        #Completo las listas por sector BIO
    alim_bebida_bio_2017.append(alim_bebida_bio_17) 
    prod_frescos_bio_2017.append(prod_frescos_bio_17) 
    
    total_alim_bebida_bio_2017.append(total_alim_bebida_bio_17.sum())
    total_prod_frescos_bio_2017.append(total_prod_frescos_bio_17.sum())


        #Completo las listas por sección BIO
    alim_seca_bio_2017.append(alim_seca_bio_17)
    bebidas_bio_2017.append(bebidas_bio_17)
    conservas_bio_2017.append(conservas_bio_17)
    leche_batidos_bio_2017.append(leche_batidos_bio_17)
    charcuteria_bio_2017.append(charcuteria_bio_17)
    congelados_bio_2017.append(congelados_bio_17)
    derv_lacteos_bio_2017.append(derv_lacteos_bio_17)
    quesos_bio_2017.append(quesos_bio_17)
    precocinados_bio_2017.append(precocinados_bio_17)
    
    total_alim_seca_bio_2017.append(total_alim_seca_bio_17.sum())
    total_bebidas_bio_2017.append(total_bebidas_bio_17.sum())
    total_conservas_bio_2017.append(total_conservas_bio_17.sum())
    total_leche_batidos_bio_2017.append(total_leche_batidos_bio_17.sum())
    total_charcuteria_bio_2017.append(total_charcuteria_bio_17.sum())
    total_congelados_bio_2017.append(total_congelados_bio_17.sum())
    total_derv_lacteos_bio_2017.append(total_derv_lacteos_bio_17.sum())
    total_quesos_bio_2017.append(total_quesos_bio_17.sum())
    total_precocinados_bio_2017.append(total_precocinados_bio_17.sum())
    
    #Completo las listas NO BIO
    no_bio_2017.append(alim_no_bio_2017)
    media_no_bio_2017.append(total_no_bio_semana.mean())
    total_no_bio_2017.append(total_no_bio_semana.sum())
    
        #Completo las listas por sector NO BIO
    alim_bebida_no_bio_2017.append(alim_bebida_no_bio_17) 
    prod_frescos_no_bio_2017.append(prod_frescos_no_bio_17) 
    
    total_alim_bebida_no_bio_2017.append(total_alim_bebida_no_bio_17.sum())
    total_prod_frescos_no_bio_2017.append(total_prod_frescos_no_bio_17.sum())


        #Completo las listas por sección NO BIO
    alim_seca_no_bio_2017.append(alim_seca_no_bio_17)
    bebidas_no_bio_2017.append(bebidas_no_bio_17)
    conservas_no_bio_2017.append(conservas_no_bio_17)
    leche_batidos_no_bio_2017.append(leche_batidos_no_bio_17)
    charcuteria_no_bio_2017.append(charcuteria_no_bio_17)
    congelados_no_bio_2017.append(congelados_no_bio_17)
    derv_lacteos_no_bio_2017.append(derv_lacteos_no_bio_17)
    quesos_no_bio_2017.append(quesos_no_bio_17)
    precocinados_no_bio_2017.append(precocinados_no_bio_17)
    
    total_alim_seca_no_bio_2017.append(total_alim_seca_no_bio_17.sum())
    total_bebidas_no_bio_2017.append(total_bebidas_no_bio_17.sum())
    total_conservas_no_bio_2017.append(total_conservas_no_bio_17.sum())
    total_leche_batidos_no_bio_2017.append(total_leche_batidos_no_bio_17.sum())
    total_charcuteria_no_bio_2017.append(total_charcuteria_no_bio_17.sum())
    total_congelados_no_bio_2017.append(total_congelados_no_bio_17.sum())
    total_derv_lacteos_no_bio_2017.append(total_derv_lacteos_no_bio_17.sum())
    total_quesos_no_bio_2017.append(total_quesos_no_bio_17.sum())
    total_precocinados_no_bio_2017.append(total_precocinados_no_bio_17.sum())

# %%
#Bucle para obtener la media por semana y el total del consumo de 2017 de cada comunidad autónoma 
#inicio listas por CATEGORIA BIO
#Alimentacion y bebidas
#ALIMENTACION SECA BIO
total_aceite_bio_2017=[]
total_aditivos_bio_2017=[]
total_alim_infantiles_bio_2017=[]
total_aperitivos_bio_2017=[]
total_arroz_bio_2017=[]
total_azucar_edulc_bio_2017=[]
total_bolleria_inds_bio_2017=[]
total_cacao_bio_2017=[]
total_cafes_bio_2017=[]
total_cereales_desayuno_bio_2017=[]
total_chocolates_bio_2017=[]
total_dieteticos_bio_2017=[]
total_dulces_navidad_bio_2017=[]
total_frutos_secos_bio_2017=[]
total_galletas_bio_2017=[]
total_golosinas_bio_2017=[]
total_infusiones_bio_2017=[]
total_legumbres_bio_2017=[]
total_panaderia_bio_2017=[]
total_pastas_bio_2017=[]
total_reposteria_bio_2017=[]
total_salsas_bio_2017=[]
total_sopas_deshid_bio_2017=[]

#BEBIDAS BIO
total_aguas_bio_2017=[]
total_beb_alcoholicas_bio_2017=[]
total_refrescos_bio_2017=[]
total_cerveza_bio_2017=[]
total_espumosos_bio_2017=[]
total_vinos_bio_2017=[]
total_zumos_bio_2017=[]

#CONSERVAS BIO
total_aceitunas_bio_2017=[]
total_cons_carne_pates_bio_2017=[]
total_cons_frutas_dulces_bio_2017=[]
total_cons_pescado_bio_2017=[]
total_cons_vegetales_bio_2017=[]
total_platos_prep_bio_2017=[]

#LECHE Y BATIDOS BIO
total_batidos_bio_2017=[]
total_horchata_bio_2017=[]
total_leche_liquida_bio_2017=[]
total_leche_no_liquida_bio_2017=[]

#Productos frescos
#CHARCUTERIA BIO
total_ahumados_bio_2017=[]
total_charcuteria_cat_bio_2017=[]
total_pates_refrig_bio_2017=[]
total_salazones_bio_2017=[]
total_salchichas_bio_2017=[]
total_sobrasada_bio_2017=[]

#CONGELADOS BIO
total_helados_bio_2017=[]
total_otros_congelados_bio_2017=[]
total_pescados_bio_2017=[]
total_pescados_prep_bio_2017=[]
total_platos_prep_conge_bio_2017=[]
total_verduras_congeladas_bio_2017=[]

#DERIVADOS LACTEOS BIO
total_mantequilla_bio_2017=[]
total_margarina_bio_2017=[]
total_nata_bio_2017=[]
total_postres_prep_bio_2017=[]
total_quesos_petit_bio_2017=[]
total_yogures_bio_2017=[]

#PRECOCINADOS BIO
total_platos_prep_refrig_bio_2017=[]

#QUESOS BIO
total_queso_azul_bio_2017=[]
total_queso_bola_bio_2017=[]
total_queso_fresco_bio_2017=[]
total_queso_fundido_bio_2017=[]
total_queso_pasta_blanda_bio_2017=[]
total_queso_rallado_bio_2017=[]
total_queso_tradicional_bio_2017=[]
total_queso_blanco_past_bio_2017=[]
total_requeson_bio_2017=[]
total_resto_quesos_bio_2017=[]


#inicio las listas por CATEGORIA NO BIO
#Alimentacion y bebidas
#ALIMENTACION SECA NO BIO 
total_aceite_no_bio_2017=[]
total_aditivos_no_bio_2017=[]
total_alim_infantiles_no_bio_2017=[]
total_aperitivos_no_bio_2017=[]
total_arroz_no_bio_2017=[]
total_azucar_edulc_no_bio_2017=[]
total_bolleria_inds_no_bio_2017=[]
total_cacao_no_bio_2017=[]
total_cafes_no_bio_2017=[]
total_cereales_desayuno_no_bio_2017=[]
total_chocolates_no_bio_2017=[]
total_dieteticos_no_bio_2017=[]
total_dulces_navidad_no_bio_2017=[]
total_frutos_secos_no_bio_2017=[]
total_galletas_no_bio_2017=[]
total_golosinas_no_bio_2017=[]
total_infusiones_no_bio_2017=[]
total_legumbres_no_bio_2017=[]
total_panaderia_no_bio_2017=[]
total_pastas_no_bio_2017=[]
total_reposteria_no_bio_2017=[]
total_salsas_no_bio_2017=[]
total_sopas_deshid_no_bio_2017=[]

#BEBIDAS NO BIO
total_aguas_no_bio_2017=[]
total_beb_alcoholicas_no_bio_2017=[]
total_refrescos_no_bio_2017=[]
total_cerveza_no_bio_2017=[]
total_espumosos_no_bio_2017=[]
total_vinos_no_bio_2017=[]
total_zumos_no_bio_2017=[]

#CONSERVAS NO BIO
total_aceitunas_no_bio_2017=[]
total_cons_carne_pates_no_bio_2017=[]
total_cons_frutas_dulces_no_bio_2017=[]
total_cons_pescado_no_bio_2017=[]
total_cons_vegetales_no_bio_2017=[]
total_platos_prep_no_bio_2017=[]

#LECHE Y BATIDOS NO BIO
total_batidos_no_bio_2017=[]
total_horchata_no_bio_2017=[]
total_leche_liquida_no_bio_2017=[]
total_leche_no_liquida_no_bio_2017=[]

#Productos frescos
#CHARCUTERIA NO BIO
total_ahumados_no_bio_2017=[]
total_charcuteria_cat_no_bio_2017=[]
total_pates_refrig_no_bio_2017=[]
total_salazones_no_bio_2017=[]
total_salchichas_no_bio_2017=[]
total_sobrasada_no_bio_2017=[]

#CONGELADOS NO BIO
total_helados_no_bio_2017=[]
total_otros_congelados_no_bio_2017=[]
total_pescados_no_bio_2017=[]
total_pescados_prep_no_bio_2017=[]
total_platos_prep_conge_no_bio_2017=[]
total_verduras_congeladas_no_bio_2017=[]

#DERIVADOS LACTEOS NO BIO
total_mantequilla_no_bio_2017=[]
total_margarina_no_bio_2017=[]
total_nata_no_bio_2017=[]
total_postres_prep_no_bio_2017=[]
total_quesos_petit_no_bio_2017=[]
total_yogures_no_bio_2017=[]

#PRECOCINADOS NO BIO
total_platos_prep_refrig_no_bio_2017=[]

#QUESOS NO BIO
total_queso_azul_no_bio_2017=[]
total_queso_bola_no_bio_2017=[]
total_queso_fresco_no_bio_2017=[]
total_queso_fundido_no_bio_2017=[]
total_queso_pasta_blanda_no_bio_2017=[]
total_queso_rallado_no_bio_2017=[]
total_queso_tradicional_no_bio_2017=[]
total_queso_blanco_past_no_bio_2017=[]
total_requeson_no_bio_2017=[]
total_resto_quesos_no_bio_2017=[]

for i in [Andalucia, Aragon, Asturias, Baleares, C_Valenciana, Canarias, Cantabria, Castilla_La_Mancha, Castilla_Leon, Catalunya, Ceuta_Melilla, Extremadura, Galicia, La_Rioja, Madrid, Murcia, Navarra,Pais_Vasco]:
    #Limpio datos quitando drogueria y mascotas
    no_drogueria=i.drop(i[i["SECTOR"] == "DROGUERIA Y PERFUMERIA"].index)
    no_mascotas=no_drogueria.drop(no_drogueria[no_drogueria["CATEGORIA"] == "ALIMENTOS MASCOTAS"].index)
    bio=no_mascotas.loc[:, 'SEGMENTO BIO'] == 'BIO'
    alim_bio= no_mascotas.loc[bio]
    no_bio=no_mascotas.loc[:, 'SEGMENTO BIO'] == 'NO BIO'
    alim_no_bio= no_mascotas.loc[no_bio]
    
        
    #Selecciono por CATEGORIA BIO
    #ALIMENTACION SECA
    aceite_b=alim_bio.loc[:,'CATEGORIA'] == 'ACEITE'
    aceite_bio=alim_bio.loc[aceite_b]
    
    aditivos_b=alim_bio.loc[:,'CATEGORIA'] == 'ADITIVOS COCINA'
    aditivos_bio=alim_bio.loc[aditivos_b]
    
    alim_infantiles_b=alim_bio.loc[:,'CATEGORIA'] == 'ALIMENTOS INFANTILES'
    alim_infantiles_bio=alim_bio.loc[alim_infantiles_b]
    
    aperitivos_b=alim_bio.loc[:,'CATEGORIA'] == 'APERITIVOS'
    aperitivos_bio=alim_bio.loc[aperitivos_b]
    
    arroz_b=alim_bio.loc[:,'CATEGORIA'] == 'ARROZ'
    arroz_bio=alim_bio.loc[arroz_b]
    
    azucar_edulc_b=alim_bio.loc[:,'CATEGORIA'] == 'AZUCAR Y EDULCORANTES'
    azucar_edulc_bio=alim_bio.loc[azucar_edulc_b]
    
    bolleria_inds_b=alim_bio.loc[:,'CATEGORIA'] == 'BOLLERIA INDUSTRIAL'
    bolleria_inds_bio=alim_bio.loc[bolleria_inds_b]
    
    cacao_b=alim_bio.loc[:,'CATEGORIA'] == 'CACAO'
    cacao_bio=alim_bio.loc[cacao_b]
    
    cafes_b=alim_bio.loc[:,'CATEGORIA'] == 'CAFES'
    cafes_bio=alim_bio.loc[cafes_b]
    
    cereales_desayuno_b=alim_bio.loc[:,'CATEGORIA'] == 'CEREALES DESAYUNO'
    cereales_desayuno_bio=alim_bio.loc[cereales_desayuno_b]
    
    chocolates_b=alim_bio.loc[:,'CATEGORIA'] == 'CHOCOLATES'
    chocolates_bio=alim_bio.loc[chocolates_b]
    
    dieteticos_b=alim_bio.loc[:,'CATEGORIA'] == 'DIETETICOS'
    dieteticos_bio=alim_bio.loc[dieteticos_b]
    
    dulces_navidad_b=alim_bio.loc[:,'CATEGORIA'] == 'DULCES NAVIDENOS'
    dulces_navidad_bio=alim_bio.loc[dulces_navidad_b]
    
    frutos_secos_b=alim_bio.loc[:,'CATEGORIA'] == 'FRUTOS SECOS'
    frutos_secos_bio=alim_bio.loc[frutos_secos_b]
    
    galletas_b=alim_bio.loc[:,'CATEGORIA'] == 'GALLETAS'
    galletas_bio=alim_bio.loc[galletas_b]
    
    golosinas_b=alim_bio.loc[:,'CATEGORIA'] == 'GOLOSINAS'
    golosinas_bio=alim_bio.loc[golosinas_b]
    
    infusiones_b=alim_bio.loc[:,'CATEGORIA'] == 'INFUSIONES'
    infusiones_bio=alim_bio.loc[infusiones_b]
    
    legumbres_b=alim_bio.loc[:,'CATEGORIA'] == 'LEGUMBRES SECAS'
    legumbres_bio=alim_bio.loc[legumbres_b]
    
    panaderia_b=alim_bio.loc[:,'CATEGORIA'] == 'PANADERIA INDUSTRIAL'
    panaderia_bio=alim_bio.loc[panaderia_b]
    
    pastas_b=alim_bio.loc[:,'CATEGORIA'] == 'PASTAS'
    pastas_bio=alim_bio.loc[pastas_b]
    
    reposteria_b=alim_bio.loc[:,'CATEGORIA'] == 'REPOSTERIA'
    reposteria_bio=alim_bio.loc[reposteria_b]
    
    salsas_b=alim_bio.loc[:,'CATEGORIA'] == 'SALSAS'
    salsas_bio=alim_bio.loc[salsas_b]
    
    sopas_deshid_b=alim_bio.loc[:,'CATEGORIA'] == 'SOPAS Y DESHIDRATADOS'
    sopas_deshid_bio=alim_bio.loc[sopas_deshid_b]
    
    #BEBIDAS
    aguas_b=alim_bio.loc[:,'CATEGORIA'] == 'AGUAS'
    aguas_bio=alim_bio.loc[aguas_b]
    
    beb_alcoholicas_b=alim_bio.loc[:,'CATEGORIA'] == 'BEBIDAS ALCOHOLICAS'
    beb_alcoholicas_bio=alim_bio.loc[beb_alcoholicas_b]
    
    refrescos_b=alim_bio.loc[:,'CATEGORIA'] == 'BEBIDAS REFRESCANTES'
    refrescos_bio=alim_bio.loc[refrescos_b]
    
    cerveza_b=alim_bio.loc[:,'CATEGORIA'] == 'CERVEZA'
    cerveza_bio=alim_bio.loc[cerveza_b]
    
    espumosos_b=alim_bio.loc[:,'CATEGORIA'] == 'ESPUMOSOS'
    espumosos_bio=alim_bio.loc[espumosos_b]
    
    vinos_b=alim_bio.loc[:,'CATEGORIA'] == 'VINOS'
    vinos_bio=alim_bio.loc[vinos_b]
    
    zumos_b=alim_bio.loc[:,'CATEGORIA'] == 'ZUMOS'
    zumos_bio=alim_bio.loc[zumos_b]
    
    #CONSERVAS
    aceitunas_b=alim_bio.loc[:,'CATEGORIA'] == 'ACEITUNAS Y ENCURT'
    aceitunas_bio=alim_bio.loc[aceitunas_b]
    
    cons_carne_pates_b=alim_bio.loc[:,'CATEGORIA'] == 'CONSERVAS DE CARNE Y PATES'
    cons_carne_pates_bio=alim_bio.loc[cons_carne_pates_b]
    
    cons_frutas_dulces_b=alim_bio.loc[:,'CATEGORIA'] == 'CONSERVAS DE FRUTAS Y DULCES'
    cons_frutas_dulces_bio=alim_bio.loc[cons_frutas_dulces_b]
    
    cons_pescado_b=alim_bio.loc[:,'CATEGORIA'] == 'CONSERVAS DE PESCADO'
    cons_pescado_bio=alim_bio.loc[cons_pescado_b]
    
    cons_vegetales_b=alim_bio.loc[:,'CATEGORIA'] == 'CONSERVAS VEGETALES'
    cons_vegetales_bio=alim_bio.loc[cons_vegetales_b]
    
    platos_prep_b=alim_bio.loc[:,'CATEGORIA'] == 'PLATOS PREPARADOS CONSERVA'
    platos_prep_bio=alim_bio.loc[platos_prep_b]
    
    #LECHE Y BATIDOS
    batidos_b=alim_bio.loc[:,'CATEGORIA'] == 'BATIDOS'
    batidos_bio=alim_bio.loc[batidos_b]
    
    horchata_b=alim_bio.loc[:,'CATEGORIA'] == 'HORCHATA.'
    horchata_bio=alim_bio.loc[horchata_b]
    
    leche_liquida_b=alim_bio.loc[:,'CATEGORIA'] == 'LECHE LIQUIDA Y BEBIDAS VEGETALES'
    leche_liquida_bio=alim_bio.loc[leche_liquida_b]
    
    leche_no_liquida_b=alim_bio.loc[:,'CATEGORIA'] == 'LECHE NO LIQUIDA'
    leche_no_liquida_bio=alim_bio.loc[leche_no_liquida_b]
    
    #CHARCUTERIA
    ahumados_b=alim_bio.loc[:,'CATEGORIA'] == 'AHUMADOS'
    ahumados_bio=alim_bio.loc[ahumados_b]
    
    charcuteria_cat_b=alim_bio.loc[:,'CATEGORIA'] == 'CHARCUTERIA'
    charcuteria_cat_bio=alim_bio.loc[charcuteria_cat_b]
    
    pates_refrig_b=alim_bio.loc[:,'CATEGORIA'] == 'PATES REFRIGERADOS'
    pates_refrig_bio=alim_bio.loc[pates_refrig_b]
    
    salazones_b=alim_bio.loc[:,'CATEGORIA'] == 'SALAZONES'
    salazones_bio=alim_bio.loc[salazones_b]
    
    salchichas_b=alim_bio.loc[:,'CATEGORIA'] == 'SALCHICHAS REFRIGERADAS'
    salchichas_bio=alim_bio.loc[salchichas_b]
    
    sobrasada_b=alim_bio.loc[:,'CATEGORIA'] == 'SOBRASADA'
    sobrasada_bio=alim_bio.loc[sobrasada_b]
    
    #CONGELADOS    
    helados_b=alim_bio.loc[:,'CATEGORIA'] == 'HELADOS'
    helados_bio=alim_bio.loc[helados_b]
    
    otros_congelados_b=alim_bio.loc[:,'CATEGORIA'] == 'OTROS CONGELADOS'
    otros_congelados_bio=alim_bio.loc[otros_congelados_b]
    
    pescados_b=alim_bio.loc[:,'CATEGORIA'] == 'PESCADO CONGELADO'
    pescados_bio=alim_bio.loc[pescados_b]
    
    pescados_prep_b=alim_bio.loc[:,'CATEGORIA'] == 'PESCADO PREPARADO CONGELADO'
    pescados_prep_bio=alim_bio.loc[pescados_prep_b]
    
    platos_prep_conge_b=alim_bio.loc[:,'CATEGORIA'] == 'PLATOS PREPARADOS CONGELADOS'
    platos_prep_conge_bio=alim_bio.loc[platos_prep_conge_b]
    
    verduras_congelada_b=alim_bio.loc[:,'CATEGORIA'] == 'VERDURAS CONGELADAS'
    verduras_congelada_bio=alim_bio.loc[verduras_congelada_b]
    
    #DERIVADOS LACTEOS
    mantequilla_b=alim_bio.loc[:,'CATEGORIA'] == 'MANTEQUILLA'
    mantequilla_bio=alim_bio.loc[mantequilla_b]
    
    margarina_b=alim_bio.loc[:,'CATEGORIA'] == 'MARGARINA'
    margarina_bio=alim_bio.loc[margarina_b]
    
    nata_b=alim_bio.loc[:,'CATEGORIA'] == 'NATA'
    nata_bio=alim_bio.loc[nata_b]
    
    postres_prep_b=alim_bio.loc[:,'CATEGORIA'] == 'POSTRES PREPARADOS'
    postres_prep_bio=alim_bio.loc[postres_prep_b]
    
    quesos_petit_b=alim_bio.loc[:,'CATEGORIA'] == 'QUESO TIPO PETIT'
    quesos_petit_bio=alim_bio.loc[quesos_petit_b]
    
    yogures_b=alim_bio.loc[:,'CATEGORIA'] == 'YOGURES'
    yogures_bio=alim_bio.loc[yogures_b]
    
    #PRECOCINADOS
    platos_prep_refrig_b=alim_bio.loc[:,'CATEGORIA'] == 'PLATOS PREPARADOS REFRIGERADOS'
    platos_prep_refrig_bio=alim_bio.loc[platos_prep_refrig_b]
    
    #QUESOS
    queso_azul_b=alim_bio.loc[:,'CATEGORIA'] == 'QUESO AZUL'
    queso_azul_bio=alim_bio.loc[queso_azul_b]
    
    queso_bola_b=alim_bio.loc[:,'CATEGORIA'] == 'QUESO BOLA'
    queso_bola_bio=alim_bio.loc[queso_bola_b]
    
    queso_fresco_b=alim_bio.loc[:,'CATEGORIA'] == 'QUESO FRESCO'
    queso_fresco_bio=alim_bio.loc[queso_fresco_b]
    
    queso_fundido_b=alim_bio.loc[:,'CATEGORIA'] == 'QUESO FUNDIDO'
    queso_fundido_bio=alim_bio.loc[queso_fundido_b]
    
    queso_pasta_blanda_b=alim_bio.loc[:,'CATEGORIA'] == 'QUESO PASTA BLANDA'
    queso_pasta_blanda_bio=alim_bio.loc[queso_pasta_blanda_b]
    
    queso_rallado_b=alim_bio.loc[:,'CATEGORIA'] == 'QUESO RALLADO'
    queso_rallado_bio=alim_bio.loc[queso_rallado_b]
    
    queso_tradicional_b=alim_bio.loc[:,'CATEGORIA'] == 'QUESO TRADICIONAL'
    queso_tradicional_bio=alim_bio.loc[queso_tradicional_b]
    
    queso_blanco_past_b=alim_bio.loc[:,'CATEGORIA'] == 'QUESOS BLANCOS PASTEURIZADOS'
    queso_blanco_past_bio=alim_bio.loc[queso_blanco_past_b]
    
    requeson_b=alim_bio.loc[:,'CATEGORIA'] == 'REQUESON'
    requeson_bio=alim_bio.loc[requeson_b]
    
    resto_quesos_b=alim_bio.loc[:,'CATEGORIA'] == 'RESTO QUESOS NATURALES'
    resto_quesos_bio=alim_bio.loc[resto_quesos_b]
    
    
    #Selecciono ventas totales por CATEGORIA y SEMANA BIO
    #ALIMENTACION SECA
    aceite_bio_17=aceite_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_aceite_bio_17=aceite_bio_17.sum()
    
    aditivos_bio_17=aditivos_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_aditivos_bio_17=aditivos_bio_17.sum()
    
    alim_infantiles_bio_17=alim_infantiles_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_alim_infantiles_bio_17=alim_infantiles_bio_17.sum()

    aperitivos_bio_17=aperitivos_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_aperitivos_bio_17=aperitivos_bio_17.sum()
    
    arroz_bio_17=arroz_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_arroz_bio_17=arroz_bio_17.sum()
    
    azucar_edulc_bio_17=azucar_edulc_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_azucar_edulc_bio_17=azucar_edulc_bio_17.sum()
    
    bolleria_inds_bio_17= bolleria_inds_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_bolleria_inds_bio_17=bolleria_inds_bio_17.sum()
    
    cacao_bio_17=cacao_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cacao_bio_17=cacao_bio_17.sum()
    
    cafes_bio_17=cafes_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cafes_bio_17=cafes_bio_17.sum()
    
    cereales_desayuno_bio_17=cereales_desayuno_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cereales_desayuno_bio_17=cereales_desayuno_bio_17.sum()
    
    chocolates_bio_17=chocolates_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_chocolates_bio_17=chocolates_bio_17.sum()
    
    dieteticos_bio_17=dieteticos_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_dieteticos_bio_17=dieteticos_bio_17.sum()
    
    dulces_navidad_bio_17=dulces_navidad_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_dulces_navidad_bio_17=dulces_navidad_bio_17.sum()
    
    frutos_secos_bio_17=frutos_secos_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_frutos_secos_bio_17=frutos_secos_bio_17.sum()
    
    galletas_bio_17=galletas_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_galletas_bio_17=galletas_bio_17.sum()
    
    golosinas_bio_17=golosinas_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_golosinas_bio_17=golosinas_bio_17.sum()
    
    infusiones_bio_17=infusiones_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_infusiones_bio_17=infusiones_bio_17.sum()
    
    legumbres_bio_17=legumbres_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_legumbres_bio_17=legumbres_bio_17.sum()
    
    panaderia_bio_17=panaderia_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_panaderia_bio_17=panaderia_bio_17.sum()
    
    pastas_bio_17=pastas_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_pastas_bio_17=pastas_bio_17.sum()
    
    reposteria_bio_17=reposteria_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_reposteria_bio_17=reposteria_bio_17.sum()
    
    salsas_bio_17=salsas_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_salsas_bio_17=salsas_bio_17.sum()
    
    sopas_deshid_bio_17=sopas_deshid_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_sopas_deshid_bio_17=sopas_deshid_bio_17.sum()
    
    #BEBIDAS
    aguas_bio_17=aguas_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_aguas_bio_17=aguas_bio_17.sum()
    
    beb_alcoholicas_bio_17=beb_alcoholicas_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_beb_alcoholicas_bio_17=beb_alcoholicas_bio_17.sum()
    
    refrescos_bio_17=refrescos_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_refrescos_bio_17=refrescos_bio_17.sum()
    
    cerveza_bio_17=cerveza_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cerveza_bio_17=cerveza_bio_17.sum()
    
    espumosos_bio_17=espumosos_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_espumosos_bio_17=espumosos_bio_17.sum()
    
    vinos_bio_17=vinos_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_vinos_bio_17=vinos_bio_17.sum()
    
    zumos_bio_17=zumos_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_zumos_bio_17=zumos_bio_17.sum()
    
    
    #CONSERVAS
    aceitunas_bio_17=aceitunas_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_aceitunas_bio_17=aceitunas_bio_17.sum()
    
    cons_carne_pates_bio_17=cons_carne_pates_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cons_carne_pates_bio_17=cons_carne_pates_bio_17.sum()
    
    cons_frutas_dulces_bio_17=cons_frutas_dulces_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cons_frutas_dulces_bio_17=cons_frutas_dulces_bio_17.sum()
    
    cons_pescado_bio_17=cons_pescado_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cons_pescado_bio_17=cons_pescado_bio_17.sum()
    
    cons_vegetales_bio_17=cons_vegetales_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cons_vegetales_bio_17=cons_vegetales_bio_17.sum()
    
    platos_prep_bio_17=platos_prep_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_platos_prep_bio_17=platos_prep_bio_17.sum()
    
    
    #LECHE Y BATIDOS
    batidos_bio_17=batidos_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_batidos_bio_17=batidos_bio_17.sum()
    
    horchata_bio_17=horchata_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_horchata_bio_17=horchata_bio_17.sum()
    
    leche_liquida_bio_17=leche_liquida_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_leche_liquida_bio_17=leche_liquida_bio_17.sum()
    
    leche_no_liquida_bio_17=leche_no_liquida_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_leche_no_liquida_bio_17=leche_no_liquida_bio_17.sum()
    
    #CHARCUTERIA
    ahumados_bio_17=ahumados_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_ahumados_bio_17=ahumados_bio_17.sum()
    
    charcuteria_cat_bio_17=charcuteria_cat_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_charcuteria_cat_bio_17=charcuteria_cat_bio_17.sum()
    
    pates_refrig_bio_17=pates_refrig_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_pates_refrig_bio_17=pates_refrig_bio_17.sum()
    
    salazones_bio_17=salazones_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_salazones_bio_17=salazones_bio_17.sum()
    
    salchichas_bio_17=salchichas_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_salchichas_bio_17=salchichas_bio_17.sum()
    
    sobrasada_bio_17=sobrasada_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_sobrasada_bio_17=sobrasada_bio_17.sum()
    
    #CONGELADOS
    helados_bio_17=helados_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_helados_bio_17=helados_bio_17.sum()
    
    otros_congelados_bio_17=otros_congelados_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_otros_congelados_bio_17=otros_congelados_bio_17.sum()
    
    pescados_bio_17=pescados_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_pescados_bio_17=pescados_bio_17.sum()

    pescados_prep_bio_17=pescados_prep_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_pescados_prep_bio_17=pescados_prep_bio_17.sum()
    
    platos_prep_conge_bio_17=platos_prep_conge_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_platos_prep_conge_bio_17=platos_prep_conge_bio_17.sum()
    
    verduras_congelada_bio_17=verduras_congelada_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_verduras_congeladas_bio_17=verduras_congelada_bio_17.sum()
    
    
    #DERIVADOS LACTEOS
    mantequilla_bio_17=mantequilla_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_mantequilla_bio_17=mantequilla_bio_17.sum()
    
    margarina_bio_17=margarina_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_margarina_bio_17=margarina_bio_17.sum()
    
    nata_bio_17=nata_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_nata_bio_17=nata_bio_17.sum()
    
    postres_prep_bio_17=postres_prep_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_postres_prep_bio_17=postres_prep_bio_17.sum()
    
    quesos_petit_bio_17=quesos_petit_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_quesos_petit_bio_17=quesos_petit_bio_17.sum()
    
    yogures_bio_17=yogures_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_yogures_bio_17=yogures_bio_17.sum()
    
    
    #PRECOCINADOS
    platos_prep_refrig_bio_17=platos_prep_refrig_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_platos_prep_refrig_bio_17=platos_prep_refrig_bio_17.sum()
    
    
    #QUESOS
    queso_azul_bio_17=queso_azul_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_azul_bio_17=queso_azul_bio_17.sum()
    
    queso_bola_bio_17=queso_bola_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_bola_bio_17=queso_bola_bio_17.sum()
    
    queso_fresco_bio_17=queso_fresco_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_fresco_bio_17=queso_fresco_bio_17.sum()
    
    queso_fundido_bio_17=queso_fundido_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_fundido_bio_17=queso_fundido_bio_17.sum()
    
    queso_pasta_blanda_bio_17=queso_pasta_blanda_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_pasta_blanda_bio_17=queso_pasta_blanda_bio_17.sum()
    
    queso_rallado_bio_17=queso_rallado_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_rallado_bio_17=queso_rallado_bio_17.sum()
    
    queso_tradicional_bio_17=queso_tradicional_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_tradicional_bio_17=queso_tradicional_bio_17.sum()
    
    queso_blanco_past_bio_17=queso_blanco_past_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_blanco_past_bio_17=queso_blanco_past_bio_17.sum()
    
    requeson_bio_17=requeson_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_requeson_bio_17=requeson_bio_17.sum()
    
    resto_quesos_bio_17=resto_quesos_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_resto_quesos_bio_17=resto_quesos_bio_17.sum()
    

    #Selecciono por CATEGORIA NO BIO
    #ALIMENTACION SECA
    aceite_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'ACEITE'
    aceite_no_bio=alim_no_bio.loc[aceite_no_b]
    
    aditivos_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'ADITIVOS COCINA'
    aditivos_no_bio=alim_no_bio.loc[aditivos_no_b]
    
    alim_infantiles_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'ALIMENTOS INFANTILES'
    alim_infantiles_no_bio=alim_no_bio.loc[alim_infantiles_no_b]
    
    aperitivos_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'APERITIVOS'
    aperitivos_no_bio=alim_no_bio.loc[aperitivos_no_b]
    
    arroz_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'ARROZ'
    arroz_no_bio=alim_no_bio.loc[arroz_no_b]
    
    azucar_edulc_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'AZUCAR Y EDULCORANTES'
    azucar_edulc_no_bio=alim_no_bio.loc[azucar_edulc_no_b]
    
    bolleria_inds_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'BOLLERIA INDUSTRIAL'
    bolleria_inds_no_bio=alim_no_bio.loc[bolleria_inds_no_b]
    
    cacao_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'CACAO'
    cacao_no_bio=alim_no_bio.loc[cacao_no_b]
    
    cafes_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'CAFES'
    cafes_no_bio=alim_no_bio.loc[cafes_no_b]
    
    cereales_desayuno_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'CEREALES DESAYUNO'
    cereales_desayuno_no_bio=alim_no_bio.loc[cereales_desayuno_no_b]
    
    chocolates_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'CHOCOLATES'
    chocolates_no_bio=alim_no_bio.loc[chocolates_no_b]
    
    dieteticos_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'DIETETICOS'
    dieteticos_no_bio=alim_no_bio.loc[dieteticos_no_b]
    
    dulces_navidad_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'DULCES NAVIDENOS'
    dulces_navidad_no_bio=alim_no_bio.loc[dulces_navidad_no_b]
    
    frutos_secos_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'FRUTOS SECOS'
    frutos_secos_no_bio=alim_no_bio.loc[frutos_secos_no_b]
    
    galletas_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'GALLETAS'
    galletas_no_bio=alim_no_bio.loc[galletas_no_b]
    
    golosinas_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'GOLOSINAS'
    golosinas_no_bio=alim_no_bio.loc[golosinas_no_b]
    
    infusiones_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'INFUSIONES'
    infusiones_no_bio=alim_no_bio.loc[infusiones_no_b]
    
    legumbres_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'LEGUMBRES SECAS'
    legumbres_no_bio=alim_no_bio.loc[legumbres_no_b]
    
    panaderia_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'PANADERIA INDUSTRIAL'
    panaderia_no_bio=alim_no_bio.loc[panaderia_no_b]
    
    pastas_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'PASTAS'
    pastas_no_bio=alim_no_bio.loc[pastas_no_b]
    
    reposteria_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'REPOSTERIA'
    reposteria_no_bio=alim_no_bio.loc[reposteria_no_b]
    
    salsas_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'SALSAS'
    salsas_no_bio=alim_no_bio.loc[salsas_no_b]
    
    sopas_deshid_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'SOPAS Y DESHIDRATADOS'
    sopas_deshid_no_bio=alim_no_bio.loc[sopas_deshid_no_b]
    
    #BEBIDAS
    aguas_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'AGUAS'
    aguas_no_bio=alim_no_bio.loc[aguas_no_b]
    
    beb_alcoholicas_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'BEBIDAS ALCOHOLICAS'
    beb_alcoholicas_no_bio=alim_no_bio.loc[beb_alcoholicas_no_b]
    
    refrescos_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'BEBIDAS REFRESCANTES'
    refrescos_no_bio=alim_no_bio.loc[refrescos_no_b]
    
    cerveza_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'CERVEZA'
    cerveza_no_bio=alim_no_bio.loc[cerveza_no_b]
    
    espumosos_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'ESPUMOSOS'
    espumosos_no_bio=alim_no_bio.loc[espumosos_no_b]
    
    vinos_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'VINOS'
    vinos_no_bio=alim_no_bio.loc[vinos_no_b]
    
    zumos_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'ZUMOS'
    zumos_no_bio=alim_no_bio.loc[zumos_no_b]
    
    #CONSERVAS
    aceitunas_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'ACEITUNAS Y ENCURT'
    aceitunas_no_bio=alim_no_bio.loc[aceitunas_no_b]
    
    cons_carne_pates_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'CONSERVAS DE CARNE Y PATES'
    cons_carne_pates_no_bio=alim_no_bio.loc[cons_carne_pates_no_b]
    
    cons_frutas_dulces_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'CONSERVAS DE FRUTAS Y DULCES'
    cons_frutas_dulces_no_bio=alim_no_bio.loc[cons_frutas_dulces_no_b]
    
    cons_pescado_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'CONSERVAS DE PESCADO'
    cons_pescado_no_bio=alim_no_bio.loc[cons_pescado_no_b]
    
    cons_vegetales_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'CONSERVAS VEGETALES'
    cons_vegetales_no_bio=alim_no_bio.loc[cons_vegetales_no_b]
    
    platos_prep_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'PLATOS PREPARADOS CONSERVA'
    platos_prep_no_bio=alim_no_bio.loc[platos_prep_no_b]
    
    #LECHE Y BATIDOS
    batidos_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'BATIDOS'
    batidos_no_bio=alim_no_bio.loc[batidos_no_b]
    
    horchata_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'HORCHATA.'
    horchata_no_bio=alim_no_bio.loc[horchata_no_b]
    
    leche_liquida_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'LECHE LIQUIDA Y BEBIDAS VEGETALES'
    leche_liquida_no_bio=alim_no_bio.loc[leche_liquida_no_b]
    
    leche_no_liquida_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'LECHE NO LIQUIDA'
    leche_no_liquida_no_bio=alim_no_bio.loc[leche_no_liquida_no_b]
    
    #CHARCUTERIA
    ahumados_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'AHUMADOS'
    ahumados_no_bio=alim_no_bio.loc[ahumados_no_b]
    
    charcuteria_cat_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'CHARCUTERIA'
    charcuteria_cat_no_bio=alim_no_bio.loc[charcuteria_cat_no_b]
    
    pates_refrig_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'PATES REFRIGERADOS'
    pates_refrig_no_bio=alim_no_bio.loc[pates_refrig_no_b]
    
    salazones_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'SALAZONES'
    salazones_no_bio=alim_no_bio.loc[salazones_no_b]
    
    salchichas_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'SALCHICHAS REFRIGERADAS'
    salchichas_no_bio=alim_no_bio.loc[salchichas_no_b]
    
    sobrasada_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'SOBRASADA'
    sobrasada_no_bio=alim_no_bio.loc[sobrasada_no_b]
    
    #CONGELADOS    
    helados_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'HELADOS'
    helados_no_bio=alim_no_bio.loc[helados_no_b]
    
    otros_congelados_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'OTROS CONGELADOS'
    otros_congelados_no_bio=alim_no_bio.loc[otros_congelados_no_b]
    
    pescados_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'PESCADO CONGELADO'
    pescados_no_bio=alim_no_bio.loc[pescados_no_b]
    
    pescados_prep_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'PESCADO PREPARADO CONGELADO'
    pescados_prep_no_bio=alim_no_bio.loc[pescados_prep_no_b]
    
    platos_prep_conge_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'PLATOS PREPARADOS CONGELADOS'
    platos_prep_conge_no_bio=alim_no_bio.loc[platos_prep_conge_no_b]
    
    verduras_congeladas_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'VERDURAS CONGELADAS'
    verduras_congeladas_no_bio=alim_no_bio.loc[verduras_congeladas_no_b]
    
    #DERIVADOS LACTEOS
    mantequilla_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'MANTEQUILLA'
    mantequilla_no_bio=alim_no_bio.loc[mantequilla_no_b]
    
    margarina_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'MARGARINA'
    margarina_no_bio=alim_no_bio.loc[margarina_no_b]
    
    nata_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'NATA'
    nata_no_bio=alim_no_bio.loc[nata_no_b]
    
    postres_prep_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'POSTRES PREPARADOS'
    postres_prep_no_bio=alim_no_bio.loc[postres_prep_no_b]
    
    quesos_petit_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'QUESO TIPO PETIT'
    quesos_petit_no_bio=alim_no_bio.loc[quesos_petit_no_b]
    
    yogures_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'YOGURES'
    yogures_no_bio=alim_no_bio.loc[yogures_no_b]
    
    #PRECOCINADOS
    platos_prep_refrig_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'PLATOS PREPARADOS REFRIGERADOS'
    platos_prep_refrig_no_bio=alim_no_bio.loc[platos_prep_refrig_no_b]
    
    #QUESOS
    queso_azul_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'QUESO AZUL'
    queso_azul_no_bio=alim_no_bio.loc[queso_azul_no_b]
    
    queso_bola_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'QUESO BOLA'
    queso_bola_no_bio=alim_no_bio.loc[queso_bola_no_b]
    
    queso_fresco_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'QUESO FRESCO'
    queso_fresco_no_bio=alim_no_bio.loc[queso_fresco_no_b]
    
    queso_fundido_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'QUESO FUNDIDO'
    queso_fundido_no_bio=alim_no_bio.loc[queso_fundido_no_b]
    
    queso_pasta_blanda_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'QUESO PASTA BLANDA'
    queso_pasta_blanda_no_bio=alim_no_bio.loc[queso_pasta_blanda_no_b]
    
    queso_rallado_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'QUESO RALLADO'
    queso_rallado_no_bio=alim_no_bio.loc[queso_rallado_no_b]
    
    queso_tradicional_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'QUESO TRADICIONAL'
    queso_tradicional_no_bio=alim_no_bio.loc[queso_tradicional_no_b]
    
    queso_blanco_past_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'QUESOS BLANCOS PASTEURIZADOS'
    queso_blanco_past_no_bio=alim_no_bio.loc[queso_blanco_past_no_b]
    
    requeson_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'REQUESON'
    requeson_no_bio=alim_no_bio.loc[requeson_no_b]
    
    resto_quesos_no_b=alim_no_bio.loc[:,'CATEGORIA'] == 'RESTO QUESOS NATURALES'
    resto_quesos_no_bio=alim_no_bio.loc[resto_quesos_no_b]
    
   
    
    #Selecciono ventas totales por CATEGORIA y SEMANA NO BIO
    #ALIMENTACION SECA
    aceite_no_bio_17=aceite_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_aceite_no_bio_17=aceite_no_bio_17.sum()
    
    aditivos_no_bio_17=aditivos_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_aditivos_no_bio_17=aditivos_no_bio_17.sum()
    
    alim_infantiles_no_bio_17=alim_infantiles_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_alim_infantiles_no_bio_17=alim_infantiles_no_bio_17.sum()

    aperitivos_no_bio_17=aperitivos_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_aperitivos_no_bio_17=aperitivos_no_bio_17.sum()
    
    arroz_no_bio_17=arroz_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_arroz_no_bio_17=arroz_no_bio_17.sum()
    
    azucar_edulc_no_bio_17=azucar_edulc_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_azucar_edulc_no_bio_17=azucar_edulc_no_bio_17.sum()
    
    bolleria_inds_no_bio_17=bolleria_inds_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_bolleria_inds_no_bio_17=bolleria_inds_no_bio_17.sum()
    
    cacao_no_bio_17=cacao_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cacao_no_bio_17=cacao_no_bio_17.sum()
    
    cafes_no_bio_17=cafes_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cafes_no_bio_17=cafes_no_bio_17.sum()
    
    cereales_desayuno_no_bio_17=cereales_desayuno_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cereales_desayuno_no_bio_17=cereales_desayuno_no_bio_17.sum()
    
    chocolates_no_bio_17=chocolates_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_chocolates_no_bio_17=chocolates_no_bio_17.sum()
    
    dieteticos_no_bio_17=dieteticos_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_dieteticos_no_bio_17=dieteticos_no_bio_17.sum()
    
    dulces_navidad_no_bio_17=dulces_navidad_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_dulces_navidad_no_bio_17=dulces_navidad_no_bio_17.sum()
    
    frutos_secos_no_bio_17=frutos_secos_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_frutos_secos_no_bio_17=frutos_secos_no_bio_17.sum()
    
    galletas_no_bio_17=galletas_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_galletas_no_bio_17=galletas_no_bio_17.sum()
    
    golosinas_no_bio_17=golosinas_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_golosinas_no_bio_17=golosinas_no_bio_17.sum()
    
    infusiones_no_bio_17=infusiones_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_infusiones_no_bio_17=infusiones_no_bio_17.sum()
    
    legumbres_no_bio_17=legumbres_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_legumbres_no_bio_17=legumbres_no_bio_17.sum()
    
    panaderia_no_bio_17=panaderia_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_panaderia_no_bio_17=panaderia_no_bio_17.sum()
    
    pastas_no_bio_17=pastas_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_pastas_no_bio_17=pastas_no_bio_17.sum()
    
    reposteria_no_bio_17=reposteria_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_reposteria_no_bio_17=reposteria_no_bio_17.sum()
    
    salsas_no_bio_17=salsas_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_salsas_no_bio_17=salsas_no_bio_17.sum()
    
    sopas_deshid_no_bio_17=sopas_deshid_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_sopas_deshid_no_bio_17=sopas_deshid_no_bio_17.sum()
    
    #BEBIDAS
    aguas_no_bio_17=aguas_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_aguas_no_bio_17=aguas_no_bio_17.sum()
    
    beb_alcoholicas_no_bio_17=beb_alcoholicas_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_beb_alcoholicas_no_bio_17=beb_alcoholicas_no_bio_17.sum()
    
    refrescos_no_bio_17=refrescos_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_refrescos_no_bio_17=refrescos_no_bio_17.sum()
    
    cerveza_no_bio_17=cerveza_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cerveza_no_bio_17=cerveza_no_bio_17.sum()
    
    espumosos_no_bio_17=espumosos_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_espumosos_no_bio_17=espumosos_no_bio_17.sum()
    
    vinos_no_bio_17=vinos_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_vinos_no_bio_17=vinos_no_bio_17.sum()
    
    zumos_no_bio_17=zumos_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_zumos_no_bio_17=zumos_no_bio_17.sum()
    
    
    #CONSERVAS
    aceitunas_no_bio_17=aceitunas_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_aceitunas_no_bio_17=aceitunas_no_bio_17.sum()
    
    cons_carne_pates_no_bio_17=cons_carne_pates_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cons_carne_pates_no_bio_17=cons_carne_pates_no_bio_17.sum()
    
    cons_frutas_dulces_no_bio_17=cons_frutas_dulces_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cons_frutas_dulces_no_bio_17=cons_frutas_dulces_no_bio_17.sum()
    
    cons_pescado_no_bio_17=cons_pescado_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cons_pescado_no_bio_17=cons_pescado_no_bio_17.sum()
    
    cons_vegetales_no_bio_17=cons_vegetales_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_cons_vegetales_no_bio_17=cons_vegetales_no_bio_17.sum()
    
    platos_prep_no_bio_17=platos_prep_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_platos_prep_no_bio_17=platos_prep_no_bio_17.sum()
    
    
    #LECHE Y BATIDOS
    batidos_no_bio_17=batidos_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_batidos_no_bio_17=batidos_no_bio_17.sum()
    
    horchata_no_bio_17=horchata_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_horchata_no_bio_17=horchata_no_bio_17.sum()
    
    leche_liquida_no_bio_17=leche_liquida_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_leche_liquida_no_bio_17=leche_liquida_no_bio_17.sum()
    
    leche_no_liquida_no_bio_17=leche_no_liquida_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_leche_no_liquida_no_bio_17=leche_no_liquida_no_bio_17.sum()
    
    #CHARCUTERIA
    ahumados_no_bio_17=ahumados_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_ahumados_no_bio_17=ahumados_no_bio_17.sum()
    
    charcuteria_cat_no_bio_17=charcuteria_cat_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_charcuteria_cat_no_bio_17=charcuteria_cat_no_bio_17.sum()
    
    pates_refrig_no_bio_17=pates_refrig_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_pates_refrig_no_bio_17=pates_refrig_no_bio_17.sum()
    
    salazones_no_bio_17=salazones_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_salazones_no_bio_17=salazones_no_bio_17.sum()
    
    salchichas_no_bio_17=salchichas_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_salchichas_no_bio_17=salchichas_no_bio_17.sum()
    
    sobrasada_no_bio_17=sobrasada_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_sobrasada_no_bio_17=sobrasada_no_bio_17.sum()
    
    #CONGELADOS
    helados_no_bio_17=helados_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_helados_no_bio_17=helados_no_bio_17.sum()
    
    otros_congelados_no_bio_17=otros_congelados_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_otros_congelados_no_bio_17=otros_congelados_no_bio_17.sum()
    
    pescados_no_bio_17=pescados_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_pescados_no_bio_17=pescados_no_bio_17.sum()
    
    pescados_prep_no_bio_17=pescados_prep_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_pescados_prep_no_bio_17=pescados_prep_no_bio_17.sum()
    
    platos_prep_conge_no_bio_17=platos_prep_conge_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_platos_prep_conge_no_bio_17=platos_prep_conge_no_bio_17.sum()
    
    verduras_congeladas_no_bio_17=verduras_congeladas_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_verduras_congeladas_no_bio_17=verduras_congeladas_no_bio_17.sum()
    
    
    #DERIVADOS LACTEOS
    mantequilla_no_bio_17=mantequilla_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_mantequilla_no_bio_17=mantequilla_no_bio_17.sum()
    
    margarina_no_bio_17=margarina_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_margarina_no_bio_17=margarina_no_bio_17.sum()
    
    nata_no_bio_17= nata_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_nata_no_bio_17=nata_no_bio_17.sum()
    
    postres_prep_no_bio_17=postres_prep_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_postres_prep_no_bio_17=postres_prep_no_bio_17.sum()
    
    quesos_petit_no_bio_17=quesos_petit_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_quesos_petit_no_bio_17=quesos_petit_no_bio_17.sum()
    
    yogures_no_bio_17=yogures_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_yogures_no_bio_17=yogures_no_bio_17.sum()
    
    
    #PRECOCINADOS
    platos_prep_refrig_no_bio_17=platos_prep_refrig_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_platos_prep_refrig_no_bio_17=platos_prep_refrig_no_bio_17.sum()
    
    
    #QUESOS
    queso_azul_no_bio_17=queso_azul_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_azul_no_bio_17=queso_azul_no_bio_17.sum()
    
    queso_bola_no_bio_17=queso_bola_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_bola_no_bio_17=queso_bola_no_bio_17.sum()
    
    queso_fresco_no_bio_17=queso_fresco_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_fresco_no_bio_17=queso_fresco_no_bio_17.sum()
    
    queso_fundido_no_bio_17=queso_fundido_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_fundido_no_bio_17=queso_fundido_no_bio_17.sum()
    
    queso_pasta_blanda_no_bio_17=queso_pasta_blanda_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_pasta_blanda_no_bio_17=queso_pasta_blanda_no_bio_17.sum()
    
    queso_rallado_no_bio_17=queso_rallado_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_rallado_no_bio_17=queso_rallado_no_bio_17.sum()
    
    queso_tradicional_no_bio_17=queso_tradicional_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_tradicional_no_bio_17=queso_tradicional_no_bio_17.sum()
    
    queso_blanco_past_no_bio_17=queso_blanco_past_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_queso_blanco_past_no_bio_17=queso_blanco_past_no_bio_17.sum()
    
    requeson_no_bio_17=requeson_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_requeson_no_bio_17=requeson_no_bio_17.sum()
    
    resto_quesos_no_bio_17=resto_quesos_no_bio.loc[:, "SEMANA 01-17":"SEMANA 52-17"]
    total_resto_quesos_no_bio_17=resto_quesos_no_bio_17.sum()
    
    
#COMPLETO LAS LISTAS INICIADAS
    #Completo las listas por CATEGORIA BIO
    #Alimentacion y bebidas
    #ALIMENTACION SECA BIO
    total_aceite_bio_2017.append(total_aceite_bio_17.sum()) 
    total_aditivos_bio_2017.append(total_aditivos_bio_17.sum()) 
    total_alim_infantiles_bio_2017.append(total_alim_infantiles_bio_17.sum()) 
    total_aperitivos_bio_2017.append(total_aperitivos_bio_17.sum()) 
    total_arroz_bio_2017.append(total_arroz_bio_17.sum()) 
    total_azucar_edulc_bio_2017.append(total_azucar_edulc_bio_17.sum()) 
    total_bolleria_inds_bio_2017.append(total_bolleria_inds_bio_17.sum()) 
    total_cacao_bio_2017.append(total_cacao_bio_17.sum()) 
    total_cafes_bio_2017.append(total_cafes_bio_17.sum()) 
    total_cereales_desayuno_bio_2017.append(total_cereales_desayuno_bio_17.sum()) 
    total_chocolates_bio_2017.append(total_chocolates_bio_17.sum()) 
    total_dieteticos_bio_2017.append(total_dieteticos_bio_17.sum()) 
    total_dulces_navidad_bio_2017.append(total_dulces_navidad_bio_17.sum()) 
    total_frutos_secos_bio_2017.append(total_frutos_secos_bio_17.sum()) 
    total_galletas_bio_2017.append(total_galletas_bio_17.sum()) 
    total_golosinas_bio_2017.append(total_golosinas_bio_17.sum()) 
    total_infusiones_bio_2017.append(total_infusiones_bio_17.sum()) 
    total_legumbres_bio_2017.append(total_legumbres_bio_17.sum()) 
    total_panaderia_bio_2017.append(total_panaderia_bio_17.sum()) 
    total_pastas_bio_2017.append(total_pastas_bio_17.sum()) 
    total_reposteria_bio_2017.append(total_reposteria_bio_17.sum()) 
    total_salsas_bio_2017.append(total_salsas_bio_17.sum()) 
    total_sopas_deshid_bio_2017.append(total_sopas_deshid_bio_17.sum()) 

    #BEBIDAS BIO
    total_aguas_bio_2017.append(total_aguas_bio_17.sum()) 
    total_beb_alcoholicas_bio_2017.append(total_beb_alcoholicas_bio_17.sum()) 
    total_refrescos_bio_2017.append(total_refrescos_bio_17.sum()) 
    total_cerveza_bio_2017.append(total_cerveza_bio_17.sum()) 
    total_espumosos_bio_2017.append(total_espumosos_bio_17.sum()) 
    total_vinos_bio_2017.append(total_vinos_bio_17.sum()) 
    total_zumos_bio_2017.append(total_zumos_bio_17.sum()) 

    #CONSERVAS BIO
    total_aceitunas_bio_2017.append(total_aceitunas_bio_17.sum()) 
    total_cons_carne_pates_bio_2017.append(total_cons_carne_pates_bio_17.sum()) 
    total_cons_frutas_dulces_bio_2017.append(total_cons_frutas_dulces_bio_17.sum()) 
    total_cons_pescado_bio_2017.append(total_cons_pescado_bio_17.sum()) 
    total_cons_vegetales_bio_2017.append(total_cons_vegetales_bio_17.sum()) 
    total_platos_prep_bio_2017.append(total_platos_prep_bio_17.sum()) 

    #LECHE Y BATIDOS BIO
    total_batidos_bio_2017.append(total_batidos_bio_17.sum()) 
    total_horchata_bio_2017.append(total_horchata_bio_17.sum()) 
    total_leche_liquida_bio_2017.append(total_leche_liquida_bio_17.sum()) 
    total_leche_no_liquida_bio_2017.append(total_leche_no_liquida_bio_17.sum()) 

    #Productos frescos
    #CHARCUTERIA BIO
    total_ahumados_bio_2017.append(total_ahumados_bio_17.sum()) 
    total_charcuteria_cat_bio_2017.append(total_charcuteria_cat_bio_17.sum()) 
    total_pates_refrig_bio_2017.append(total_pates_refrig_bio_17.sum()) 
    total_salazones_bio_2017.append(total_salazones_bio_17.sum()) 
    total_salchichas_bio_2017.append(total_salchichas_bio_17.sum()) 
    total_sobrasada_bio_2017.append(total_sobrasada_bio_17.sum()) 

    #CONGELADOS BIO
    total_helados_bio_2017.append(total_helados_bio_17.sum()) 
    total_otros_congelados_bio_2017.append(total_otros_congelados_bio_17.sum()) 
    total_pescados_bio_2017.append(total_pescados_bio_17.sum()) 
    total_pescados_prep_bio_2017.append(total_pescados_prep_bio_17.sum()) 
    total_platos_prep_conge_bio_2017.append(total_platos_prep_conge_bio_17.sum()) 
    total_verduras_congeladas_bio_2017.append(total_verduras_congeladas_bio_17.sum()) 

    #DERIVADOS LACTEOS BIO
    total_mantequilla_bio_2017.append(total_mantequilla_bio_17.sum()) 
    total_margarina_bio_2017.append(total_margarina_bio_17.sum()) 
    total_nata_bio_2017.append(total_nata_bio_17.sum()) 
    total_postres_prep_bio_2017.append(total_postres_prep_bio_17.sum()) 
    total_quesos_petit_bio_2017.append(total_quesos_petit_bio_17.sum()) 
    total_yogures_bio_2017.append(total_yogures_bio_17.sum()) 

    #PRECOCINADOS BIO
    total_platos_prep_refrig_bio_2017.append(total_platos_prep_refrig_bio_17.sum()) 

    #QUESOS BIO
    total_queso_azul_bio_2017.append(total_queso_azul_bio_17.sum()) 
    total_queso_bola_bio_2017.append(total_queso_bola_bio_17.sum()) 
    total_queso_fresco_bio_2017.append(total_queso_fresco_bio_17.sum()) 
    total_queso_fundido_bio_2017.append(total_queso_fundido_bio_17.sum()) 
    total_queso_pasta_blanda_bio_2017.append(total_queso_pasta_blanda_bio_17.sum()) 
    total_queso_rallado_bio_2017.append(total_queso_rallado_bio_17.sum()) 
    total_queso_tradicional_bio_2017.append(total_queso_tradicional_bio_17.sum()) 
    total_queso_blanco_past_bio_2017.append(total_queso_blanco_past_bio_17.sum()) 
    total_requeson_bio_2017.append(total_requeson_bio_17.sum()) 
    total_resto_quesos_bio_2017.append(total_resto_quesos_bio_17.sum()) 
    

    #Completo las listas por CATEGORIA NO BIO
    #Alimentacion y bebidas
    #ALIMENTACION SECA NO BIO 
    total_aceite_no_bio_2017.append(total_aceite_no_bio_17.sum())
    total_aditivos_no_bio_2017.append(total_aditivos_no_bio_17.sum())
    total_alim_infantiles_no_bio_2017.append(total_alim_infantiles_no_bio_17.sum()) 
    total_aperitivos_no_bio_2017.append(total_aperitivos_no_bio_17.sum())
    total_arroz_no_bio_2017.append(total_arroz_no_bio_17.sum())
    total_azucar_edulc_no_bio_2017.append(total_azucar_edulc_no_bio_17.sum())
    total_bolleria_inds_no_bio_2017.append(total_bolleria_inds_no_bio_17.sum())
    total_cacao_no_bio_2017.append(total_cacao_no_bio_17.sum())
    total_cafes_no_bio_2017.append(total_cafes_no_bio_17.sum())
    total_cereales_desayuno_no_bio_2017.append(total_cereales_desayuno_no_bio_17.sum()) 
    total_chocolates_no_bio_2017.append(total_chocolates_no_bio_17.sum())
    total_dieteticos_no_bio_2017.append(total_dieteticos_no_bio_17.sum())
    total_dulces_navidad_no_bio_2017.append(total_dulces_navidad_no_bio_17.sum())
    total_frutos_secos_no_bio_2017.append(total_frutos_secos_no_bio_17.sum())
    total_galletas_no_bio_2017.append(total_galletas_no_bio_17.sum())
    total_golosinas_no_bio_2017.append(total_golosinas_no_bio_17.sum())
    total_infusiones_no_bio_2017.append(total_infusiones_no_bio_17.sum())
    total_legumbres_no_bio_2017.append(total_legumbres_no_bio_17.sum())
    total_panaderia_no_bio_2017.append(total_panaderia_no_bio_17.sum())
    total_pastas_no_bio_2017.append(total_pastas_no_bio_17.sum())
    total_reposteria_no_bio_2017.append(total_reposteria_no_bio_17.sum())
    total_salsas_no_bio_2017.append(total_salsas_no_bio_17.sum())
    total_sopas_deshid_no_bio_2017.append(total_sopas_deshid_no_bio_17.sum())

    #BEBIDAS NO BIO
    total_aguas_no_bio_2017.append(total_aguas_no_bio_17.sum()) 
    total_beb_alcoholicas_no_bio_2017.append(total_beb_alcoholicas_no_bio_17.sum())
    total_refrescos_no_bio_2017.append(total_refrescos_no_bio_17.sum())
    total_cerveza_no_bio_2017.append(total_cerveza_no_bio_17.sum())
    total_espumosos_no_bio_2017.append(total_espumosos_no_bio_17.sum())
    total_vinos_no_bio_2017.append(total_vinos_no_bio_17.sum())
    total_zumos_no_bio_2017.append(total_zumos_no_bio_17.sum())

    #CONSERVAS NO BIO
    total_aceitunas_no_bio_2017.append(total_aceitunas_no_bio_17.sum()) 
    total_cons_carne_pates_no_bio_2017.append(total_cons_carne_pates_no_bio_17.sum())
    total_cons_frutas_dulces_no_bio_2017.append(total_cons_frutas_dulces_no_bio_17.sum())
    total_cons_pescado_no_bio_2017.append(total_cons_pescado_no_bio_17.sum())
    total_cons_vegetales_no_bio_2017.append(total_cons_vegetales_no_bio_17.sum())
    total_platos_prep_no_bio_2017.append(total_platos_prep_no_bio_17.sum())

    #LECHE Y BATIDOS NO BIO
    total_batidos_no_bio_2017.append(total_batidos_no_bio_17.sum())
    total_horchata_no_bio_2017.append(total_horchata_no_bio_17.sum())
    total_leche_liquida_no_bio_2017.append(total_leche_liquida_no_bio_17.sum())
    total_leche_no_liquida_no_bio_2017.append(total_leche_no_liquida_no_bio_17.sum())

    #Productos frescos
    #CHARCUTERIA NO BIO
    total_ahumados_no_bio_2017.append(total_ahumados_no_bio_17.sum())
    total_charcuteria_cat_no_bio_2017.append(total_charcuteria_cat_no_bio_17.sum()) 
    total_pates_refrig_no_bio_2017.append(total_pates_refrig_no_bio_17.sum())
    total_salazones_no_bio_2017.append(total_salazones_no_bio_17.sum())
    total_salchichas_no_bio_2017.append(total_salchichas_no_bio_17.sum())
    total_sobrasada_no_bio_2017.append(total_sobrasada_no_bio_17.sum())

    #CONGELADOS NO BIO
    total_helados_no_bio_2017.append(total_helados_no_bio_17.sum())
    total_otros_congelados_no_bio_2017.append(total_otros_congelados_no_bio_17.sum())
    total_pescados_no_bio_2017.append(total_pescados_no_bio_17.sum())
    total_pescados_prep_no_bio_2017.append(total_pescados_prep_no_bio_17.sum())
    total_platos_prep_conge_no_bio_2017.append(total_platos_prep_conge_no_bio_17.sum())
    total_verduras_congeladas_no_bio_2017.append(total_verduras_congeladas_no_bio_17.sum())

    #DERIVADOS LACTEOS NO BIO
    total_mantequilla_no_bio_2017.append(total_mantequilla_no_bio_17.sum())
    total_margarina_no_bio_2017.append(total_margarina_no_bio_17.sum())
    total_nata_no_bio_2017.append(total_nata_no_bio_17.sum())
    total_postres_prep_no_bio_2017.append(total_postres_prep_no_bio_17.sum())
    total_quesos_petit_no_bio_2017.append(total_quesos_petit_no_bio_17.sum())
    total_yogures_no_bio_2017.append(total_yogures_no_bio_17.sum())

    #PRECOCINADOS NO BIO
    total_platos_prep_refrig_no_bio_2017.append(total_platos_prep_refrig_no_bio_17.sum())

    #QUESOS NO BIO
    total_queso_azul_no_bio_2017.append(total_queso_azul_no_bio_17.sum())
    total_queso_bola_no_bio_2017.append(total_queso_bola_no_bio_17.sum())
    total_queso_fresco_no_bio_2017.append(total_queso_fresco_no_bio_17.sum())
    total_queso_fundido_no_bio_2017.append(total_queso_fundido_no_bio_17.sum())
    total_queso_pasta_blanda_no_bio_2017.append(total_queso_pasta_blanda_no_bio_17.sum())
    total_queso_rallado_no_bio_2017.append(total_queso_rallado_no_bio_17.sum())
    total_queso_tradicional_no_bio_2017.append(total_queso_tradicional_no_bio_17.sum())
    total_queso_blanco_past_no_bio_2017.append(total_queso_blanco_past_no_bio_17.sum())
    total_requeson_no_bio_2017.append(total_requeson_no_bio_17.sum())
    total_resto_quesos_no_bio_2017.append(total_resto_quesos_no_bio_17.sum())

# %%
#Voy a hacer una tabla con los datos de enfermedades en valores absolutos y relativos
#Hipertension
hipertension_t=[1364.2,247.2,209.0,111.5,837.5,357.3,113.8,388.4,426.7,1205.4,12.4,188.3,574.7,45.3,1025.1,240.4,111.9,380.8]
hipertension_p=[19.53,22.36,23.01,11.56,20.18,19.50,22.91,22.86,20.43,19.53,18.96,20.58,24.31,17.32,19.08,19.92,21.11,20.82]

#Diabetes
diabetes_t=[579.6, 87.4,78.8,46.7,333.4,203.3,29.5,127.9,154.9,435.2,5.5,84.3,217.0,14.2,397.8,87.8,39.9,125.9]
diabetes_p=[8.29,7.90,8.66,4.85,8.02,11.09,5.95,7.53,7.42,7.04,8.44,9.19,9.18,5.41,7.39,7.28,7.52,6.86]

#Colesterol
colesterol_t=[1074.3,212.7,191.0,121.9,717.0,289.0,87.4,301.4,414.4,1138.7,11.8,174.5,618.0,47.9,985.3,185.2,112.6,334.5]
colesterol_p=[15.38,19.23,21.06,12.67,17.28,15.76,17.59,17.74,19.84,18.53,18.23,19.05,26.14,18.44,18.34,15.34,21.21,18.26]

#Obesidad
obesidad_t=[1349.9,161.4,185.4,134.6,738.6,315.7,66.1,302.6,256.6,858.5,13.2,163.6,406.5,36.6,805.7,182.5,75.0,242.6]
obesidad_p=[21,15.73,21.68,15.49,18.75,19.26,17.5,20.32,13.22,14.94,21.93,19.28,18.35,14.95,15.87,16.11,15.37,13.84]

#Creo la tabla
enfermedadest=pd.DataFrame({'comunidades': comunidades, 'hipertension tot': hipertension_t, 'diabetes tot': diabetes_t, 'colesterol tot': colesterol_t, 'obesidad tot':obesidad_t, 'hipertension rel': hipertension_p, 'diabetes rel': diabetes_p, 'colesterol rel': colesterol_p, 'obesidad rel': obesidad_p})
enfermedadest
# Out:
#            comunidades  hipertension tot  diabetes tot  colesterol tot  \
# 0            Andalucia            1364.2         579.6          1074.3
# 1               Aragon             247.2          87.4           212.7
# 2             Asturias             209.0          78.8           191.0
# 3             Baleares             111.5          46.7           121.9
# 4         C_Valenciana             837.5         333.4           717.0
# 5             Canarias             357.3         203.3           289.0
# 6            Cantabria             113.8          29.5            87.4
# 7   Castilla_La_Mancha             388.4         127.9           301.4
# 8        Castilla_Leon             426.7         154.9           414.4
# 9            Catalunya            1205.4         435.2          1138.7
# 10       Ceuta_Melilla              12.4           5.5            11.8
# 11         Extremadura             188.3          84.3           174.5
# ...

# %%
#Hago las tablas con los datos BIO y NO BIO TOTALES
tabla_tot_2017=pd.DataFrame({'comunidades':comunidades, 'tot BIO 2017':total_bio_2017, 'tot NO BIO 2017': total_no_bio_2017})
tabla_tot_2017=pd.DataFrame({'comunidades':comunidades, 'tot BIO 2017':total_bio_2017, 'tot NO BIO 2017': total_no_bio_2017, 'tot 2017':tabla_tot_2017.iloc[:,1]+tabla_tot_2017.iloc[:,2]})
tabla_tot_2017=pd.DataFrame({'comunidades':comunidades, 'tot BIO 2017':total_bio_2017, 'tot NO BIO 2017': total_no_bio_2017, 'tot 2017':tabla_tot_2017.iloc[:,1]+tabla_tot_2017.iloc[:,2], '%BIO 2017':tabla_tot_2017.iloc[:,1]/tabla_tot_2017.iloc[:,3], '%NO BIO 2017':tabla_tot_2017.iloc[:,2]/tabla_tot_2017.iloc[:,3], 'poblacion CA':poblacion_total_2017})
tabla_tot_2017
# Out:
#            comunidades  tot BIO 2017  tot NO BIO 2017    tot 2017  %BIO 2017  \
# 0            Andalucia      26227.61       7176034.42  7202262.03   0.003642
# 1               Aragon       5890.76       1097933.78  1103824.54   0.005337
# 2             Asturias       5041.94        910255.30   915297.24   0.005509
# 3             Baleares       9890.61       1272497.35  1282387.96   0.007713
# 4         C_Valenciana      21894.22       4839519.44  4861413.66   0.004504
# 5             Canarias      17990.24       2283830.82  2301821.06   0.007816
# 6            Cantabria       3258.18        615148.51   618406.69   0.005269
# 7   Castilla_La_Mancha       4190.25       1548101.63  1552291.88   0.002699
# 8        Castilla_Leon       7030.34       2029738.38  2036768.72   0.003452
# 9            Catalunya      50330.17       6883771.53  6934101.70   0.007258
# 10       Ceuta_Melilla        220.37         43729.24    43949.61   0.005014
# ...

# %%
#ANALIZO LOS DATOS POR SECCIÓN 
#Creo la tabla con los totales y porcentajes de cada sección
tabla_seccion_2017=pd.DataFrame({'comunidades':comunidades, 'tot alim seca BIO 2017':total_alim_seca_bio_2017, 'tot alim seca NO BIO 2017': total_alim_seca_no_bio_2017, 'tot bebidas BIO 2017':total_bebidas_bio_2017, 'tot bebidas NO BIO 2017': total_bebidas_no_bio_2017, 'tot conservas BIO 2017':total_conservas_bio_2017, 'tot conservas NO BIO 2017': total_conservas_no_bio_2017, 'tot leche y batidos BIO 2017':total_leche_batidos_bio_2017, 'tot leche y batidos NO BIO 2017': total_leche_batidos_no_bio_2017, 'tot charcuteria BIO 2017':total_charcuteria_bio_2017, 'tot charcuteria NO BIO 2017': total_charcuteria_no_bio_2017, 'tot congelados BIO 2017':total_congelados_bio_2017, 'tot congelados NO BIO 2017': total_congelados_no_bio_2017, 'tot derv lacteos BIO 2017':total_derv_lacteos_bio_2017, 'tot derv lacteos NO BIO 2017': total_derv_lacteos_no_bio_2017, 'tot precocinados BIO 2017': total_precocinados_bio_2017, 'tot precocinados NO BIO 2017': total_precocinados_no_bio_2017, 'tot quesos BIO 2017': total_quesos_bio_2017, 'tot quesos NO BIO 2017': total_quesos_no_bio_2017})
tabla_seccion_2017=pd.DataFrame({'comunidades':comunidades, 'tot alim seca BIO 2017':total_alim_seca_bio_2017, 'tot alim seca NO BIO 2017': total_alim_seca_no_bio_2017, 'tot bebidas BIO 2017':total_bebidas_bio_2017, 'tot bebidas NO BIO 2017': total_bebidas_no_bio_2017, 'tot conservas BIO 2017':total_conservas_bio_2017, 'tot conservas NO BIO 2017': total_conservas_no_bio_2017, 'tot leche y batidos BIO 2017':total_leche_batidos_bio_2017, 'tot leche y batidos NO BIO 2017': total_leche_batidos_no_bio_2017, 'tot charcuteria BIO 2017':total_charcuteria_bio_2017, 'tot charcuteria NO BIO 2017': total_charcuteria_no_bio_2017, 'tot congelados BIO 2017':total_congelados_bio_2017, 'tot congelados NO BIO 2017': total_congelados_no_bio_2017, 'tot derv lacteos BIO 2017':total_derv_lacteos_bio_2017, 'tot derv lacteos NO BIO 2017': total_derv_lacteos_no_bio_2017, 'tot precocinados BIO 2017': total_precocinados_bio_2017, 'tot precocinados NO BIO 2017': total_precocinados_no_bio_2017, 'tot quesos BIO 2017': total_quesos_bio_2017, 'tot quesos NO BIO 2017': total_quesos_no_bio_2017, 'tot alim seca 2017':tabla_seccion_2017.iloc[:,1]+tabla_seccion_2017.iloc[:,2], 'tot bebidas 2017':tabla_seccion_2017.iloc[:,3]+tabla_seccion_2017.iloc[:,4], 'tot conservas 2017':tabla_seccion_2017.iloc[:,5]+tabla_seccion_2017.iloc[:,6], 'tot leche y batidos 2017':tabla_seccion_2017.iloc[:,7]+tabla_seccion_2017.iloc[:,8], 'tot charcuteria 2017':tabla_seccion_2017.iloc[:,9]+tabla_seccion_2017.iloc[:,10], 'tot congelados 2017':tabla_seccion_2017.iloc[:,11]+tabla_seccion_2017.iloc[:,12], 'tot derv lacteos 2017':tabla_seccion_2017.iloc[:,13]+tabla_seccion_2017.iloc[:,14], 'tot precocinados 2017':tabla_seccion_2017.iloc[:,15]+tabla_seccion_2017.iloc[:,16], 'tot quesos 2017':tabla_seccion_2017.iloc[:,17]+tabla_seccion_2017.iloc[:,18]})
tabla_seccion_2017=pd.DataFrame({'comunidades':comunidades, 'tot alim seca BIO 2017':total_alim_seca_bio_2017, 'tot alim seca NO BIO 2017': total_alim_seca_no_bio_2017, 'tot bebidas BIO 2017':total_bebidas_bio_2017, 'tot bebidas NO BIO 2017': total_bebidas_no_bio_2017, 'tot conservas BIO 2017':total_conservas_bio_2017, 'tot conservas NO BIO 2017': total_conservas_no_bio_2017, 'tot leche y batidos BIO 2017':total_leche_batidos_bio_2017, 'tot leche y batidos NO BIO 2017': total_leche_batidos_no_bio_2017, 'tot charcuteria BIO 2017':total_charcuteria_bio_2017, 'tot charcuteria NO BIO 2017': total_charcuteria_no_bio_2017, 'tot congelados BIO 2017':total_congelados_bio_2017, 'tot congelados NO BIO 2017': total_congelados_no_bio_2017, 'tot derv lacteos BIO 2017':total_derv_lacteos_bio_2017, 'tot derv lacteos NO BIO 2017': total_derv_lacteos_no_bio_2017, 'tot precocinados BIO 2017': total_precocinados_bio_2017, 'tot precocinados NO BIO 2017': total_precocinados_no_bio_2017, 'tot quesos BIO 2017': total_quesos_bio_2017, 'tot quesos NO BIO 2017': total_quesos_no_bio_2017, 'tot alim seca 2017':tabla_seccion_2017.iloc[:,1]+tabla_seccion_2017.iloc[:,2], 'tot bebidas 2017':tabla_seccion_2017.iloc[:,3]+tabla_seccion_2017.iloc[:,4], 'tot conservas 2017':tabla_seccion_2017.iloc[:,5]+tabla_seccion_2017.iloc[:,6], 'tot leche y batidos 2017':tabla_seccion_2017.iloc[:,7]+tabla_seccion_2017.iloc[:,8], 'tot charcuteria 2017':tabla_seccion_2017.iloc[:,9]+tabla_seccion_2017.iloc[:,10], 'tot congelados 2017':tabla_seccion_2017.iloc[:,11]+tabla_seccion_2017.iloc[:,12], 'tot derv lacteos 2017':tabla_seccion_2017.iloc[:,13]+tabla_seccion_2017.iloc[:,14], 'tot precocinados 2017':tabla_seccion_2017.iloc[:,15]+tabla_seccion_2017.iloc[:,16], 'tot quesos 2017':tabla_seccion_2017.iloc[:,17]+tabla_seccion_2017.iloc[:,18], '%alim seca BIO 2017':tabla_seccion_2017.iloc[:,1]/tabla_tot_2017['tot 2017'], '%alim seca NO BIO 2017':tabla_seccion_2017.iloc[:,2]/tabla_tot_2017['tot 2017'], '%bebidas BIO 2017':tabla_seccion_2017.iloc[:,3]/tabla_tot_2017['tot 2017'], '%bebidas NO BIO 2017':tabla_seccion_2017.iloc[:,4]/tabla_tot_2017['tot 2017'], '%conservas BIO 2017':tabla_seccion_2017.iloc[:,5]/tabla_tot_2017['tot 2017'], '%conservas NO BIO 2017':tabla_seccion_2017.iloc[:,6]/tabla_tot_2017['tot 2017'], '%leche y batidos BIO 2017':tabla_seccion_2017.iloc[:,7]/tabla_tot_2017['tot 2017'], '%leche y batidos NO BIO 2017':tabla_seccion_2017.iloc[:,8]/tabla_tot_2017['tot 2017'], '%charcuteria BIO 2017':tabla_seccion_2017.iloc[:,9]/tabla_tot_2017['tot 2017'], '%charcuteria NO BIO 2017':tabla_seccion_2017.iloc[:,10]/tabla_tot_2017['tot 2017'], '%congelados BIO 2017':tabla_seccion_2017.iloc[:,11]/tabla_tot_2017['tot 2017'], '%congelados NO BIO 2017':tabla_seccion_2017.iloc[:,12]/tabla_tot_2017['tot 2017'], '%derv lacteos BIO 2017':tabla_seccion_2017.iloc[:,13]/tabla_tot_2017['tot 2017'], '%derv lacteos NO BIO 2017':tabla_seccion_2017.iloc[:,14]/tabla_tot_2017['tot 2017'], '%precocinados BIO 2017':tabla_seccion_2017.iloc[:,15]/tabla_tot_2017['tot 2017'], '%precocinados NO BIO 2017':tabla_seccion_2017.iloc[:,16]/tabla_tot_2017['tot 2017'], '%quesos BIO 2017':tabla_seccion_2017.iloc[:,17]/tabla_tot_2017['tot 2017'], '%quesos NO BIO 2017':tabla_seccion_2017.iloc[:,18]/tabla_tot_2017['tot 2017'], '%alim seca':tabla_seccion_2017['tot alim seca 2017']/tabla_tot_2017['tot 2017'], '%bebidas':tabla_seccion_2017['tot bebidas 2017']/tabla_tot_2017['tot 2017'], '%conservas':tabla_seccion_2017['tot conservas 2017']/tabla_tot_2017['tot 2017'], '%leche y batidos':tabla_seccion_2017['tot leche y batidos 2017']/tabla_tot_2017['tot 2017'], '%charcuteria':tabla_seccion_2017['tot charcuteria 2017']/tabla_tot_2017['tot 2017'], '%congelados':tabla_seccion_2017['tot congelados 2017']/tabla_tot_2017['tot 2017'], '%derv lacteos':tabla_seccion_2017['tot derv lacteos 2017']/tabla_tot_2017['tot 2017'], '%precocinados':tabla_seccion_2017['tot precocinados 2017']/tabla_tot_2017['tot 2017'], '%quesos':tabla_seccion_2017['tot quesos 2017']/tabla_tot_2017['tot 2017']})
tabla_seccion_2017.loc[:,'%alim seca BIO 2017':'%quesos NO BIO 2017']
# Out:
#     %alim seca BIO 2017  %alim seca NO BIO 2017  %bebidas BIO 2017  \
# 0              0.001912                0.291357           0.000282
# 1              0.002367                0.305522           0.000268
# 2              0.002656                0.318462           0.000709
# 3              0.003921                0.301309           0.000595
# 4              0.002049                0.294083           0.000341
# 5              0.003582                0.312235           0.001879
# 6              0.002420                0.326576           0.000363
# 7              0.001370                0.292871           0.000171
# 8              0.001588                0.314851           0.000253
# 9              0.003015                0.312734           0.000623
# 10             0.002895                0.350422           0.000468
# 11             0.001342                0.295192           0.000136
# 12             0.002747                0.327996           0.000558
# ...

# %%
#Tablas con cada una de las categorias
alim_seca_categorias=pd.DataFrame({'comunidades': comunidades, 'aceite bio':total_aceite_bio_2017, 'aditivos bio':total_aditivos_bio_2017, 'alim infantiles bio':total_alim_infantiles_bio_2017, 'aperitivos bio':total_aperitivos_bio_2017, 'arroz bio':total_arroz_bio_2017, 'azucar bio':total_azucar_edulc_bio_2017, 'bolleria inds bio':total_bolleria_inds_bio_2017 , 'cacao bio':total_cacao_bio_2017, 'cafes bio':total_cafes_bio_2017, 'cereales desayuno bio':total_cereales_desayuno_bio_2017, 'chocolates bio':total_chocolates_bio_2017, 'dieteticos bio':total_dieteticos_bio_2017, 'dulces navidad bio':total_dulces_navidad_bio_2017, 'frutos secos bio':total_frutos_secos_bio_2017, 'galletas bio': total_galletas_bio_2017, 'golosinas bio':total_golosinas_bio_2017, 'infusiones bio':total_infusiones_bio_2017, 'legumbres bio':total_legumbres_bio_2017, 'panaderia bio': total_panaderia_bio_2017, 'pastas bio':total_pastas_bio_2017, 'reposteria bio': total_reposteria_bio_2017, 'salsas bio':total_salsas_bio_2017, 'sopas deshid bio':total_sopas_deshid_bio_2017, 'aceite no bio':total_aceite_no_bio_2017, 'aditivos no bio':total_aditivos_no_bio_2017, 'alim infantiles no bio':total_alim_infantiles_no_bio_2017, 'aperitivos no bio':total_aperitivos_no_bio_2017, 'arroz no bio':total_arroz_no_bio_2017, 'azucar no bio':total_azucar_edulc_no_bio_2017, 'bolleria inds no bio':total_bolleria_inds_no_bio_2017 , 'cacao no bio':total_cacao_no_bio_2017, 'cafes no bio':total_cafes_no_bio_2017, 'cereales desayuno no bio':total_cereales_desayuno_no_bio_2017, 'chocolates no bio':total_chocolates_no_bio_2017, 'dieteticos no bio':total_dieteticos_no_bio_2017, 'dulces navidad no bio':total_dulces_navidad_no_bio_2017, 'frutos secos no bio':total_frutos_secos_no_bio_2017, 'galletas no bio': total_galletas_no_bio_2017, 'golosinas no bio':total_golosinas_no_bio_2017, 'infusiones no bio':total_infusiones_no_bio_2017, 'legumbres no bio':total_legumbres_no_bio_2017, 'panaderia no bio': total_panaderia_no_bio_2017, 'pastas no bio':total_pastas_no_bio_2017, 'reposteria no bio': total_reposteria_no_bio_2017, 'salsas no bio':total_salsas_no_bio_2017, 'sopas deshid no bio':total_sopas_deshid_no_bio_2017  })
alim_seca_categorias=pd.DataFrame({'comunidades': comunidades, 'aceite bio':total_aceite_bio_2017, 'aditivos bio':total_aditivos_bio_2017, 'alim infantiles bio':total_alim_infantiles_bio_2017, 'aperitivos bio':total_aperitivos_bio_2017, 'arroz bio':total_arroz_bio_2017, 'azucar bio':total_azucar_edulc_bio_2017, 'bolleria inds bio':total_bolleria_inds_bio_2017 , 'cacao bio':total_cacao_bio_2017, 'cafes bio':total_cafes_bio_2017, 'cereales desayuno bio':total_cereales_desayuno_bio_2017, 'chocolates bio':total_chocolates_bio_2017, 'dieteticos bio':total_dieteticos_bio_2017, 'dulces navidad bio':total_dulces_navidad_bio_2017, 'frutos secos bio':total_frutos_secos_bio_2017, 'galletas bio': total_galletas_bio_2017, 'golosinas bio':total_golosinas_bio_2017, 'infusiones bio':total_infusiones_bio_2017, 'legumbres bio':total_legumbres_bio_2017, 'panaderia bio': total_panaderia_bio_2017, 'pastas bio':total_pastas_bio_2017, 'reposteria bio': total_reposteria_bio_2017, 'salsas bio':total_salsas_bio_2017, 'sopas deshid bio':total_sopas_deshid_bio_2017, 'aceite no bio':total_aceite_no_bio_2017, 'aditivos no bio':total_aditivos_no_bio_2017, 'alim infantiles no bio':total_alim_infantiles_no_bio_2017, 'aperitivos no bio':total_aperitivos_no_bio_2017, 'arroz no bio':total_arroz_no_bio_2017, 'azucar no bio':total_azucar_edulc_no_bio_2017, 'bolleria inds no bio':total_bolleria_inds_no_bio_2017 , 'cacao no bio':total_cacao_no_bio_2017, 'cafes no bio':total_cafes_no_bio_2017, 'cereales desayuno no bio':total_cereales_desayuno_no_bio_2017, 'chocolates no bio':total_chocolates_no_bio_2017, 'dieteticos no bio':total_dieteticos_no_bio_2017, 'dulces navidad no bio':total_dulces_navidad_no_bio_2017, 'frutos secos no bio':total_frutos_secos_no_bio_2017, 'galletas no bio': total_galletas_no_bio_2017, 'golosinas no bio':total_golosinas_no_bio_2017, 'infusiones no bio':total_infusiones_no_bio_2017, 'legumbres no bio':total_legumbres_no_bio_2017, 'panaderia no bio': total_panaderia_no_bio_2017, 'pastas no bio':total_pastas_no_bio_2017, 'reposteria no bio': total_reposteria_no_bio_2017, 'salsas no bio':total_salsas_no_bio_2017, 'sopas deshid no bio':total_sopas_deshid_no_bio_2017, 'tot aceite':alim_seca_categorias['aceite bio']+alim_seca_categorias['aceite no bio'], 'tot aditivos':alim_seca_categorias['aditivos bio']+alim_seca_categorias['aditivos no bio'], 'tot alim infantiles':alim_seca_categorias['alim infantiles bio']+alim_seca_categorias['alim infantiles no bio'], 'tot aperitivos':alim_seca_categorias['aperitivos bio']+alim_seca_categorias['aperitivos no bio'], 'tot arroz':alim_seca_categorias['arroz bio']+alim_seca_categorias['arroz no bio'], 'tot azucar':alim_seca_categorias['azucar bio']+alim_seca_categorias['azucar no bio'], 'tot bolleria inds':alim_seca_categorias['bolleria inds bio']+alim_seca_categorias['bolleria inds no bio'], 'tot cacao':alim_seca_categorias['cacao bio']+alim_seca_categorias['cacao no bio'], 'tot cafes':alim_seca_categorias['cafes bio']+alim_seca_categorias['cafes no bio'], 'tot cereales desayuno':alim_seca_categorias['cereales desayuno bio']+alim_seca_categorias['cereales desayuno no bio'], 'tot chocolates':alim_seca_categorias['chocolates bio']+alim_seca_categorias['chocolates no bio'], 'tot dieteticos':alim_seca_categorias['dieteticos bio']+alim_seca_categorias['dieteticos no bio'], 'tot dulces navidad':alim_seca_categorias['dulces navidad bio']+alim_seca_categorias['dulces navidad no bio'], 'tot frutos secos':alim_seca_categorias['frutos secos bio']+alim_seca_categorias['frutos secos no bio'], 'tot galletas': alim_seca_categorias['galletas bio']+alim_seca_categorias['galletas no bio'], 'tot golosinas':alim_seca_categorias['golosinas bio']+alim_seca_categorias['golosinas no bio'], 'tot infusiones':alim_seca_categorias['infusiones bio']+alim_seca_categorias['infusiones no bio'], 'tot legumbres':alim_seca_categorias['legumbres bio']+alim_seca_categorias['legumbres no bio'],  'tot panaderia':alim_seca_categorias['panaderia bio']+alim_seca_categorias['panaderia no bio'], 'tot pastas':alim_seca_categorias['pastas bio']+alim_seca_categorias['pastas no bio'], 'tot reposteria':alim_seca_categorias['reposteria bio']+alim_seca_categorias['reposteria no bio'], 'tot salsas':alim_seca_categorias['salsas bio']+alim_seca_categorias['salsas no bio'], 'tot sopas deshid':alim_seca_categorias['sopas deshid bio']+alim_seca_categorias['sopas deshid no bio']})
alim_seca_categorias=pd.DataFrame({'comunidades': comunidades, 'aceite bio':total_aceite_bio_2017, 'aditivos bio':total_aditivos_bio_2017, 'alim infantiles bio':total_alim_infantiles_bio_2017, 'aperitivos bio':total_aperitivos_bio_2017, 'arroz bio':total_arroz_bio_2017, 'azucar bio':total_azucar_edulc_bio_2017, 'bolleria inds bio':total_bolleria_inds_bio_2017 , 'cacao bio':total_cacao_bio_2017, 'cafes bio':total_cafes_bio_2017, 'cereales desayuno bio':total_cereales_desayuno_bio_2017, 'chocolates bio':total_chocolates_bio_2017, 'dieteticos bio':total_dieteticos_bio_2017, 'dulces navidad bio':total_dulces_navidad_bio_2017, 'frutos secos bio':total_frutos_secos_bio_2017, 'galletas bio': total_galletas_bio_2017, 'golosinas bio':total_golosinas_bio_2017, 'infusiones bio':total_infusiones_bio_2017, 'legumbres bio':total_legumbres_bio_2017, 'panaderia bio': total_panaderia_bio_2017, 'pastas bio':total_pastas_bio_2017, 'reposteria bio': total_reposteria_bio_2017, 'salsas bio':total_salsas_bio_2017, 'sopas deshid bio':total_sopas_deshid_bio_2017, 'aceite no bio':total_aceite_no_bio_2017, 'aditivos no bio':total_aditivos_no_bio_2017, 'alim infantiles no bio':total_alim_infantiles_no_bio_2017, 'aperitivos no bio':total_aperitivos_no_bio_2017, 'arroz no bio':total_arroz_no_bio_2017, 'azucar no bio':total_azucar_edulc_no_bio_2017, 'bolleria inds no bio':total_bolleria_inds_no_bio_2017 , 'cacao no bio':total_cacao_no_bio_2017, 'cafes no bio':total_cafes_no_bio_2017, 'cereales desayuno no bio':total_cereales_desayuno_no_bio_2017, 'chocolates no bio':total_chocolates_no_bio_2017, 'dieteticos no bio':total_dieteticos_no_bio_2017, 'dulces navidad no bio':total_dulces_navidad_no_bio_2017, 'frutos secos no bio':total_frutos_secos_no_bio_2017, 'galletas no bio': total_galletas_no_bio_2017, 'golosinas no bio':total_golosinas_no_bio_2017, 'infusiones no bio':total_infusiones_no_bio_2017, 'legumbres no bio':total_legumbres_no_bio_2017, 'panaderia no bio': total_panaderia_no_bio_2017, 'pastas no bio':total_pastas_no_bio_2017, 'reposteria no bio': total_reposteria_no_bio_2017, 'salsas no bio':total_salsas_no_bio_2017, 'sopas deshid no bio':total_sopas_deshid_no_bio_2017, 'tot aceite':alim_seca_categorias['aceite bio']+alim_seca_categorias['aceite no bio'], 'tot aditivos':alim_seca_categorias['aditivos bio']+alim_seca_categorias['aditivos no bio'], 'tot alim infantiles':alim_seca_categorias['alim infantiles bio']+alim_seca_categorias['alim infantiles no bio'], 'tot aperitivos':alim_seca_categorias['aperitivos bio']+alim_seca_categorias['aperitivos no bio'], 'tot arroz':alim_seca_categorias['arroz bio']+alim_seca_categorias['arroz no bio'], 'tot azucar':alim_seca_categorias['azucar bio']+alim_seca_categorias['azucar no bio'], 'tot bolleria inds':alim_seca_categorias['bolleria inds bio']+alim_seca_categorias['bolleria inds no bio'], 'tot cacao':alim_seca_categorias['cacao bio']+alim_seca_categorias['cacao no bio'], 'tot cafes':alim_seca_categorias['cafes bio']+alim_seca_categorias['cafes no bio'], 'tot cereales desayuno':alim_seca_categorias['cereales desayuno bio']+alim_seca_categorias['cereales desayuno no bio'], 'tot chocolates':alim_seca_categorias['chocolates bio']+alim_seca_categorias['chocolates no bio'], 'tot dieteticos':alim_seca_categorias['dieteticos bio']+alim_seca_categorias['dieteticos no bio'], 'tot dulces navidad':alim_seca_categorias['dulces navidad bio']+alim_seca_categorias['dulces navidad no bio'], 'tot frutos secos':alim_seca_categorias['frutos secos bio']+alim_seca_categorias['frutos secos no bio'], 'tot galletas': alim_seca_categorias['galletas bio']+alim_seca_categorias['galletas no bio'], 'tot golosinas':alim_seca_categorias['golosinas bio']+alim_seca_categorias['golosinas no bio'], 'tot infusiones':alim_seca_categorias['infusiones bio']+alim_seca_categorias['infusiones no bio'], 'tot legumbres':alim_seca_categorias['legumbres bio']+alim_seca_categorias['legumbres no bio'],  'tot panaderia':alim_seca_categorias['panaderia bio']+alim_seca_categorias['panaderia no bio'], 'tot pastas':alim_seca_categorias['pastas bio']+alim_seca_categorias['pastas no bio'], 'tot reposteria':alim_seca_categorias['reposteria bio']+alim_seca_categorias['reposteria no bio'], 'tot salsas':alim_seca_categorias['salsas bio']+alim_seca_categorias['salsas no bio'], 'tot sopas deshid':alim_seca_categorias['sopas deshid bio']+alim_seca_categorias['sopas deshid no bio'], '%aceite':alim_seca_categorias['tot aceite']/tabla_tot_2017['tot 2017'], '%aditivos':alim_seca_categorias['tot aditivos']/tabla_tot_2017['tot 2017'], '%alim infantiles':alim_seca_categorias['tot alim infantiles']/tabla_tot_2017['tot 2017'], '%aperitivos':alim_seca_categorias['tot aperitivos']/tabla_tot_2017['tot 2017'], '%arroz':alim_seca_categorias['tot arroz']/tabla_tot_2017['tot 2017'], '%azucar':alim_seca_categorias['tot azucar']/tabla_tot_2017['tot 2017'], '%bolleria inds':alim_seca_categorias['tot bolleria inds']/tabla_tot_2017['tot 2017'], '%cacao':alim_seca_categorias['tot cacao']/tabla_tot_2017['tot 2017'], '%cafes':alim_seca_categorias['tot cafes']/tabla_tot_2017['tot 2017'], '%cereales desayuno':alim_seca_categorias['tot cereales desayuno']/tabla_tot_2017['tot 2017'], '%chocolates':alim_seca_categorias['tot chocolates']/tabla_tot_2017['tot 2017'], '%dieteticos':alim_seca_categorias['tot dieteticos']/tabla_tot_2017['tot 2017'], '%dulces navidad':alim_seca_categorias['tot dulces navidad']/tabla_tot_2017['tot 2017'], '%frutos secos':alim_seca_categorias['tot frutos secos']/tabla_tot_2017['tot 2017'], '%galletas':alim_seca_categorias['tot galletas']/tabla_tot_2017['tot 2017'], '%golosinas':alim_seca_categorias['tot golosinas']/tabla_tot_2017['tot 2017'], '%infusiones':alim_seca_categorias['tot infusiones']/tabla_tot_2017['tot 2017'], '%legumbres':alim_seca_categorias['tot legumbres']/tabla_tot_2017['tot 2017'], '%panaderia':alim_seca_categorias['tot panaderia']/tabla_tot_2017['tot 2017'], '%pastas':alim_seca_categorias['tot pastas']/tabla_tot_2017['tot 2017'], '%reposteria':alim_seca_categorias['tot reposteria']/tabla_tot_2017['tot 2017'], '%salsas':alim_seca_categorias['tot salsas']/tabla_tot_2017['tot 2017'], '%sopas deshid':alim_seca_categorias['tot sopas deshid']/tabla_tot_2017['tot 2017'], '%aceite bio':alim_seca_categorias['aceite bio']/tabla_tot_2017['tot 2017'], '%aditivos bio':alim_seca_categorias['aditivos bio']/tabla_tot_2017['tot 2017'], '%alim infantiles bio':alim_seca_categorias['alim infantiles bio']/tabla_tot_2017['tot 2017'], '%aperitivos bio':alim_seca_categorias['aperitivos bio']/tabla_tot_2017['tot 2017'], '%arroz bio':alim_seca_categorias['arroz bio']/tabla_tot_2017['tot 2017'], '%azucar bio':alim_seca_categorias['azucar bio']/tabla_tot_2017['tot 2017'], '%bolleria inds bio':alim_seca_categorias['bolleria inds bio']/tabla_tot_2017['tot 2017'], '%cacao bio':alim_seca_categorias['cacao bio']/tabla_tot_2017['tot 2017'], '%cafes bio':alim_seca_categorias['cafes bio']/tabla_tot_2017['tot 2017'], '%cereales desayuno bio':alim_seca_categorias['cereales desayuno bio']/tabla_tot_2017['tot 2017'], '%chocolates bio':alim_seca_categorias['chocolates bio']/tabla_tot_2017['tot 2017'], '%dieteticos bio':alim_seca_categorias['dieteticos bio']/tabla_tot_2017['tot 2017'], '%dulces navidad bio':alim_seca_categorias['dulces navidad bio']/tabla_tot_2017['tot 2017'], '%frutos secos bio':alim_seca_categorias['frutos secos bio']/tabla_tot_2017['tot 2017'], '%galletas bio':alim_seca_categorias['galletas bio']/tabla_tot_2017['tot 2017'], '%golosinas bio':alim_seca_categorias['golosinas bio']/tabla_tot_2017['tot 2017'], '%infusiones bio':alim_seca_categorias['infusiones bio']/tabla_tot_2017['tot 2017'], '%legumbres bio':alim_seca_categorias['legumbres bio']/tabla_tot_2017['tot 2017'], '%panaderia bio':alim_seca_categorias['panaderia bio']/tabla_tot_2017['tot 2017'], '%pastas bio':alim_seca_categorias['pastas bio']/tabla_tot_2017['tot 2017'], '%reposteria bio':alim_seca_categorias['reposteria bio']/tabla_tot_2017['tot 2017'], '%salsas bio':alim_seca_categorias['salsas bio']/tabla_tot_2017['tot 2017'], '%sopas deshid bio':alim_seca_categorias['sopas deshid bio']/tabla_tot_2017['tot 2017'], '%aceite no bio':alim_seca_categorias['aceite no bio']/tabla_tot_2017['tot 2017'], '%aditivos no bio':alim_seca_categorias['aditivos no bio']/tabla_tot_2017['tot 2017'], '%alim infantiles no bio':alim_seca_categorias['alim infantiles no bio']/tabla_tot_2017['tot 2017'], '%aperitivos no bio':alim_seca_categorias['aperitivos no bio']/tabla_tot_2017['tot 2017'], '%arroz no bio':alim_seca_categorias['arroz no bio']/tabla_tot_2017['tot 2017'], '%azucar no bio':alim_seca_categorias['azucar no bio']/tabla_tot_2017['tot 2017'], '%bolleria inds no bio':alim_seca_categorias['bolleria inds no bio']/tabla_tot_2017['tot 2017'], '%cacao no bio':alim_seca_categorias['cacao no bio']/tabla_tot_2017['tot 2017'], '%cafes no bio':alim_seca_categorias['cafes no bio']/tabla_tot_2017['tot 2017'], '%cereales desayuno no bio':alim_seca_categorias['cereales desayuno no bio']/tabla_tot_2017['tot 2017'], '%chocolates no bio':alim_seca_categorias['chocolates no bio']/tabla_tot_2017['tot 2017'], '%dieteticos no bio':alim_seca_categorias['dieteticos no bio']/tabla_tot_2017['tot 2017'], '%dulces navidad no bio':alim_seca_categorias['dulces navidad no bio']/tabla_tot_2017['tot 2017'], '%frutos secos no bio':alim_seca_categorias['frutos secos no bio']/tabla_tot_2017['tot 2017'], '%galletas no bio':alim_seca_categorias['galletas no bio']/tabla_tot_2017['tot 2017'], '%golosinas no bio':alim_seca_categorias['golosinas no bio']/tabla_tot_2017['tot 2017'], '%infusiones no bio':alim_seca_categorias['infusiones no bio']/tabla_tot_2017['tot 2017'], '%legumbres no bio':alim_seca_categorias['legumbres no bio']/tabla_tot_2017['tot 2017'], '%panaderia no bio':alim_seca_categorias['panaderia no bio']/tabla_tot_2017['tot 2017'], '%pastas no bio':alim_seca_categorias['pastas no bio']/tabla_tot_2017['tot 2017'], '%reposteria no bio':alim_seca_categorias['reposteria no bio']/tabla_tot_2017['tot 2017'], '%salsas no bio':alim_seca_categorias['salsas no bio']/tabla_tot_2017['tot 2017'], '%sopas deshid no bio':alim_seca_categorias['sopas deshid no bio']/tabla_tot_2017['tot 2017']})

bebidas_categorias=pd.DataFrame({'comunidades': comunidades, 'aguas bio':total_aguas_bio_2017, 'beb alcoholicas bio': total_beb_alcoholicas_bio_2017, 'refrescos bio': total_refrescos_bio_2017, 'cerveza bio': total_cerveza_bio_2017, 'espumosos bio': total_espumosos_bio_2017, 'vinos bio': total_vinos_bio_2017, 'zumos bio':total_zumos_bio_2017, 'aguas no bio':total_aguas_no_bio_2017, 'beb alcoholicas no bio': total_beb_alcoholicas_no_bio_2017, 'refrescos no bio': total_refrescos_no_bio_2017, 'cerveza no bio': total_cerveza_no_bio_2017, 'espumosos no bio': total_espumosos_no_bio_2017, 'vinos no bio': total_vinos_no_bio_2017, 'zumos no bio':total_zumos_no_bio_2017 })
bebidas_categorias=pd.DataFrame({'comunidades': comunidades, 'aguas bio':total_aguas_bio_2017, 'beb alcoholicas bio': total_beb_alcoholicas_bio_2017, 'refrescos bio': total_refrescos_bio_2017, 'cerveza bio': total_cerveza_bio_2017, 'espumosos bio': total_espumosos_bio_2017, 'vinos bio': total_vinos_bio_2017, 'zumos bio':total_zumos_bio_2017, 'aguas no bio':total_aguas_no_bio_2017, 'beb alcoholicas no bio': total_beb_alcoholicas_no_bio_2017, 'refrescos no bio': total_refrescos_no_bio_2017, 'cerveza no bio': total_cerveza_no_bio_2017, 'espumosos no bio': total_espumosos_no_bio_2017, 'vinos no bio': total_vinos_no_bio_2017, 'zumos no bio':total_zumos_no_bio_2017, 'tot aguas':bebidas_categorias['aguas bio']+bebidas_categorias['aguas no bio'], 'tot beb alcoholicas':bebidas_categorias['beb alcoholicas bio']+bebidas_categorias['beb alcoholicas no bio'], 'tot refrescos':bebidas_categorias['refrescos bio']+bebidas_categorias['refrescos no bio'], 'tot cerveza':bebidas_categorias['cerveza bio']+bebidas_categorias['cerveza no bio'], 'tot espumosos':bebidas_categorias['espumosos bio']+bebidas_categorias['espumosos no bio'], 'tot vinos':bebidas_categorias['vinos bio']+bebidas_categorias['vinos no bio'], 'tot zumos':bebidas_categorias['zumos bio']+bebidas_categorias['zumos no bio']})
bebidas_categorias=pd.DataFrame({'comunidades': comunidades, 'aguas bio':total_aguas_bio_2017, 'beb alcoholicas bio': total_beb_alcoholicas_bio_2017, 'refrescos bio': total_refrescos_bio_2017, 'cerveza bio': total_cerveza_bio_2017, 'espumosos bio': total_espumosos_bio_2017, 'vinos bio': total_vinos_bio_2017, 'zumos bio':total_zumos_bio_2017, 'aguas no bio':total_aguas_no_bio_2017, 'beb alcoholicas no bio': total_beb_alcoholicas_no_bio_2017, 'refrescos no bio': total_refrescos_no_bio_2017, 'cerveza no bio': total_cerveza_no_bio_2017, 'espumosos no bio': total_espumosos_no_bio_2017, 'vinos no bio': total_vinos_no_bio_2017, 'zumos no bio':total_zumos_no_bio_2017, 'tot aguas':bebidas_categorias['aguas bio']+bebidas_categorias['aguas no bio'], 'tot beb alcoholicas':bebidas_categorias['beb alcoholicas bio']+bebidas_categorias['beb alcoholicas no bio'], 'tot refrescos':bebidas_categorias['refrescos bio']+bebidas_categorias['refrescos no bio'], 'tot cerveza':bebidas_categorias['cerveza bio']+bebidas_categorias['cerveza no bio'], 'tot espumosos':bebidas_categorias['espumosos bio']+bebidas_categorias['espumosos no bio'], 'tot vinos':bebidas_categorias['vinos bio']+bebidas_categorias['vinos no bio'], 'tot zumos':bebidas_categorias['zumos bio']+bebidas_categorias['zumos no bio'], '%aguas': bebidas_categorias['tot aguas']/tabla_tot_2017['tot 2017'], '%beb alcoholicas': bebidas_categorias['tot beb alcoholicas']/tabla_tot_2017['tot 2017'], '%refrescos': bebidas_categorias['tot refrescos']/tabla_tot_2017['tot 2017'], '%cerveza': bebidas_categorias['tot cerveza']/tabla_tot_2017['tot 2017'], '%espumosos': bebidas_categorias['tot espumosos']/tabla_tot_2017['tot 2017'], '%vinos': bebidas_categorias['tot vinos']/tabla_tot_2017['tot 2017'], '%zumos': bebidas_categorias['tot zumos']/tabla_tot_2017['tot 2017'], '%aguas bio': bebidas_categorias['aguas bio']/tabla_tot_2017['tot 2017'], '%beb alcoholicas bio': bebidas_categorias['beb alcoholicas bio']/tabla_tot_2017['tot 2017'], '%refrescos bio': bebidas_categorias['refrescos bio']/tabla_tot_2017['tot 2017'], '%cerveza bio': bebidas_categorias['cerveza bio']/tabla_tot_2017['tot 2017'], '%espumosos bio': bebidas_categorias['espumosos bio']/tabla_tot_2017['tot 2017'], '%vinos bio': bebidas_categorias['vinos bio']/tabla_tot_2017['tot 2017'], '%zumos bio': bebidas_categorias['zumos bio']/tabla_tot_2017['tot 2017'], '%aguas no bio': bebidas_categorias['aguas no bio']/tabla_tot_2017['tot 2017'], '%beb alcoholicas no bio': bebidas_categorias['beb alcoholicas no bio']/tabla_tot_2017['tot 2017'], '%refrescos no bio': bebidas_categorias['refrescos no bio']/tabla_tot_2017['tot 2017'], '%cerveza no bio': bebidas_categorias['cerveza no bio']/tabla_tot_2017['tot 2017'], '%espumosos no bio': bebidas_categorias['espumosos no bio']/tabla_tot_2017['tot 2017'], '%vinos no bio': bebidas_categorias['vinos no bio']/tabla_tot_2017['tot 2017'], '%zumos no bio': bebidas_categorias['zumos no bio']/tabla_tot_2017['tot 2017']})

conservas_categorias=pd.DataFrame({'comunidades': comunidades, 'aceitunas bio': total_aceitunas_bio_2017, 'conservas carne bio':total_cons_carne_pates_bio_2017, 'conservas frutas y dulces bio':total_cons_frutas_dulces_bio_2017, 'conservas pescado bio': total_cons_pescado_bio_2017, 'conservas vegetales bio': total_cons_vegetales_bio_2017, 'platos preparados bio':total_platos_prep_bio_2017, 'aceitunas no bio': total_aceitunas_no_bio_2017, 'conservas carne no bio':total_cons_carne_pates_no_bio_2017, 'conservas frutas y dulces no bio':total_cons_frutas_dulces_no_bio_2017, 'conservas pescado no bio': total_cons_pescado_no_bio_2017, 'conservas vegetales no bio': total_cons_vegetales_no_bio_2017, 'platos preparados no bio':total_platos_prep_no_bio_2017 })
conservas_categorias=pd.DataFrame({'comunidades': comunidades, 'aceitunas bio': total_aceitunas_bio_2017, 'conservas carne bio':total_cons_carne_pates_bio_2017, 'conservas frutas y dulces bio':total_cons_frutas_dulces_bio_2017, 'conservas pescado bio': total_cons_pescado_bio_2017, 'conservas vegetales bio': total_cons_vegetales_bio_2017, 'platos preparados bio':total_platos_prep_bio_2017, 'aceitunas no bio': total_aceitunas_no_bio_2017, 'conservas carne no bio':total_cons_carne_pates_no_bio_2017, 'conservas frutas y dulces no bio':total_cons_frutas_dulces_no_bio_2017, 'conservas pescado no bio': total_cons_pescado_no_bio_2017, 'conservas vegetales no bio': total_cons_vegetales_no_bio_2017, 'platos preparados no bio':total_platos_prep_no_bio_2017, 'tot aceitunas':conservas_categorias['aceitunas bio']+conservas_categorias['aceitunas no bio'], 'tot conservas carne':conservas_categorias['conservas carne bio']+conservas_categorias['conservas carne no bio'], 'tot conservas frutas y dulces':conservas_categorias['conservas frutas y dulces bio']+conservas_categorias['conservas frutas y dulces no bio'], 'tot conservas pescado':conservas_categorias['conservas pescado bio']+conservas_categorias['conservas pescado no bio'], 'tot conservas vegetales':conservas_categorias['conservas vegetales bio']+conservas_categorias['conservas vegetales no bio'], 'tot platos preparados':conservas_categorias['platos preparados bio']+conservas_categorias['platos preparados no bio']})
conservas_categorias=pd.DataFrame({'comunidades': comunidades, 'aceitunas bio': total_aceitunas_bio_2017, 'conservas carne bio':total_cons_carne_pates_bio_2017, 'conservas frutas y dulces bio':total_cons_frutas_dulces_bio_2017, 'conservas pescado bio': total_cons_pescado_bio_2017, 'conservas vegetales bio': total_cons_vegetales_bio_2017, 'platos preparados bio':total_platos_prep_bio_2017, 'aceitunas no bio': total_aceitunas_no_bio_2017, 'conservas carne no bio':total_cons_carne_pates_no_bio_2017, 'conservas frutas y dulces no bio':total_cons_frutas_dulces_no_bio_2017, 'conservas pescado no bio': total_cons_pescado_no_bio_2017, 'conservas vegetales no bio': total_cons_vegetales_no_bio_2017, 'platos preparados no bio':total_platos_prep_no_bio_2017, 'tot aceitunas':conservas_categorias['aceitunas bio']+conservas_categorias['aceitunas no bio'], 'tot conservas carne':conservas_categorias['conservas carne bio']+conservas_categorias['conservas carne no bio'], 'tot conservas frutas y dulces':conservas_categorias['conservas frutas y dulces bio']+conservas_categorias['conservas frutas y dulces no bio'], 'tot conservas pescado':conservas_categorias['conservas pescado bio']+conservas_categorias['conservas pescado no bio'], 'tot conservas vegetales':conservas_categorias['conservas vegetales bio']+conservas_categorias['conservas vegetales no bio'], 'tot platos preparados':conservas_categorias['platos preparados bio']+conservas_categorias['platos preparados no bio'], '%aceitunas': conservas_categorias['tot aceitunas']/tabla_tot_2017['tot 2017'], '%conservas carne': conservas_categorias['tot conservas carne']/tabla_tot_2017['tot 2017'], '%conservas frutas y dulces': conservas_categorias['tot conservas frutas y dulces']/tabla_tot_2017['tot 2017'], '%conservas pescado': conservas_categorias['tot conservas pescado']/tabla_tot_2017['tot 2017'], '%conservas vegetales': conservas_categorias['tot conservas vegetales']/tabla_tot_2017['tot 2017'], '%platos preparados': conservas_categorias['tot platos preparados']/tabla_tot_2017['tot 2017'], '%aceitunas bio': conservas_categorias['aceitunas bio']/tabla_tot_2017['tot 2017'], '%conservas carne bio': conservas_categorias['conservas carne bio']/tabla_tot_2017['tot 2017'], '%conservas frutas y dulces bio': conservas_categorias['conservas frutas y dulces bio']/tabla_tot_2017['tot 2017'], '%conservas pescado bio': conservas_categorias['conservas pescado bio']/tabla_tot_2017['tot 2017'], '%conservas vegetales bio': conservas_categorias['conservas vegetales bio']/tabla_tot_2017['tot 2017'], '%platos preparados bio': conservas_categorias['platos preparados bio']/tabla_tot_2017['tot 2017'], '%aceitunas no bio': conservas_categorias['aceitunas no bio']/tabla_tot_2017['tot 2017'], '%conservas carne no bio': conservas_categorias['conservas carne no bio']/tabla_tot_2017['tot 2017'], '%conservas frutas y dulces no bio': conservas_categorias['conservas frutas y dulces no bio']/tabla_tot_2017['tot 2017'], '%conservas pescado no bio': conservas_categorias['conservas pescado no bio']/tabla_tot_2017['tot 2017'], '%conservas vegetales no bio': conservas_categorias['conservas vegetales no bio']/tabla_tot_2017['tot 2017'], '%platos preparados no bio': conservas_categorias['platos preparados no bio']/tabla_tot_2017['tot 2017']})

leche_batidos_categorias=pd.DataFrame({'comunidades': comunidades, 'batidos bio': total_batidos_bio_2017, 'horchata bio': total_horchata_bio_2017, 'leche liquida bio': total_leche_liquida_bio_2017, 'leche no liquida bio': total_leche_no_liquida_bio_2017, 'batidos no bio': total_batidos_no_bio_2017, 'horchata no bio': total_horchata_no_bio_2017, 'leche liquida no bio': total_leche_liquida_no_bio_2017, 'leche no liquida no bio': total_leche_no_liquida_no_bio_2017 })
leche_batidos_categorias=pd.DataFrame({'comunidades': comunidades, 'batidos bio': total_batidos_bio_2017, 'horchata bio': total_horchata_bio_2017, 'leche liquida bio': total_leche_liquida_bio_2017, 'leche no liquida bio': total_leche_no_liquida_bio_2017, 'batidos no bio': total_batidos_no_bio_2017, 'horchata no bio': total_horchata_no_bio_2017, 'leche liquida no bio': total_leche_liquida_no_bio_2017, 'leche no liquida no bio': total_leche_no_liquida_no_bio_2017, 'tot batidos':leche_batidos_categorias['batidos bio']+leche_batidos_categorias['batidos no bio'], 'tot horchata':leche_batidos_categorias['horchata bio']+leche_batidos_categorias['horchata no bio'], 'tot leche liquida':leche_batidos_categorias['leche liquida bio']+leche_batidos_categorias['leche liquida no bio'], 'tot leche no liquida':leche_batidos_categorias['leche no liquida bio']+leche_batidos_categorias['leche no liquida no bio']})
leche_batidos_categorias=pd.DataFrame({'comunidades': comunidades, 'batidos bio': total_batidos_bio_2017, 'horchata bio': total_horchata_bio_2017, 'leche liquida bio': total_leche_liquida_bio_2017, 'leche no liquida bio': total_leche_no_liquida_bio_2017, 'batidos no bio': total_batidos_no_bio_2017, 'horchata no bio': total_horchata_no_bio_2017, 'leche liquida no bio': total_leche_liquida_no_bio_2017, 'leche no liquida no bio': total_leche_no_liquida_no_bio_2017, 'tot batidos':leche_batidos_categorias['batidos bio']+leche_batidos_categorias['batidos no bio'], 'tot horchata':leche_batidos_categorias['horchata bio']+leche_batidos_categorias['horchata no bio'], 'tot leche liquida':leche_batidos_categorias['leche liquida bio']+leche_batidos_categorias['leche liquida no bio'], 'tot leche no liquida':leche_batidos_categorias['leche no liquida bio']+leche_batidos_categorias['leche no liquida no bio'], '%batidos': leche_batidos_categorias['tot batidos']/tabla_tot_2017['tot 2017'], '%horchata': leche_batidos_categorias['tot horchata']/tabla_tot_2017['tot 2017'], '%leche liquida': leche_batidos_categorias['tot leche liquida']/tabla_tot_2017['tot 2017'], '%leche no liquida': leche_batidos_categorias['tot leche no liquida']/tabla_tot_2017['tot 2017'], '%batidos bio': leche_batidos_categorias['batidos bio']/tabla_tot_2017['tot 2017'], '%horchata bio': leche_batidos_categorias['horchata bio']/tabla_tot_2017['tot 2017'], '%leche liquida bio': leche_batidos_categorias['leche liquida bio']/tabla_tot_2017['tot 2017'], '%leche no liquida bio': leche_batidos_categorias['leche no liquida bio']/tabla_tot_2017['tot 2017'], '%batidos no bio': leche_batidos_categorias['batidos no bio']/tabla_tot_2017['tot 2017'], '%horchata no bio': leche_batidos_categorias['horchata no bio']/tabla_tot_2017['tot 2017'], '%leche liquida no bio': leche_batidos_categorias['leche liquida no bio']/tabla_tot_2017['tot 2017'], '%leche no liquida no bio': leche_batidos_categorias['leche no liquida no bio']/tabla_tot_2017['tot 2017']})

charcuteria_categorias=pd.DataFrame({'comunidades': comunidades, 'ahumados bio':total_ahumados_bio_2017 , 'charcuteria bio':total_charcuteria_cat_bio_2017 , 'pates refrigerados bio':total_pates_refrig_bio_2017 , 'salazones bio':total_salazones_bio_2017 , 'salchichas bio':total_salchichas_bio_2017, 'sobrasada bio':total_sobrasada_bio_2017, 'ahumados no bio':total_ahumados_no_bio_2017, 'charcuteria no bio':total_charcuteria_cat_no_bio_2017 , 'pates refrigerados no bio':total_pates_refrig_no_bio_2017 , 'salazones no bio':total_salazones_no_bio_2017 , 'salchichas no bio':total_salchichas_no_bio_2017, 'sobrasada no bio':total_sobrasada_no_bio_2017})
charcuteria_categorias=pd.DataFrame({'comunidades': comunidades, 'ahumados bio':total_ahumados_bio_2017 , 'charcuteria bio':total_charcuteria_cat_bio_2017 , 'pates refrigerados bio':total_pates_refrig_bio_2017 , 'salazones bio':total_salazones_bio_2017 , 'salchichas bio':total_salchichas_bio_2017, 'sobrasada bio':total_sobrasada_bio_2017, 'ahumados no bio':total_ahumados_no_bio_2017, 'charcuteria no bio':total_charcuteria_cat_no_bio_2017 , 'pates refrigerados no bio':total_pates_refrig_no_bio_2017 , 'salazones no bio':total_salazones_no_bio_2017 , 'salchichas no bio':total_salchichas_no_bio_2017, 'sobrasada no bio':total_sobrasada_no_bio_2017, 'tot ahumados':charcuteria_categorias['ahumados bio']+charcuteria_categorias['ahumados no bio'], 'tot charcuteria':charcuteria_categorias['charcuteria bio']+charcuteria_categorias['charcuteria no bio'], 'tot pates refrigerados':charcuteria_categorias['pates refrigerados bio']+charcuteria_categorias['pates refrigerados no bio'], 'tot salazones':charcuteria_categorias['salazones bio']+charcuteria_categorias['salazones no bio'], 'tot salchichas':charcuteria_categorias['salchichas bio']+charcuteria_categorias['salchichas no bio'], 'tot sobrasada':charcuteria_categorias['sobrasada bio']+charcuteria_categorias['sobrasada no bio']})
charcuteria_categorias=pd.DataFrame({'comunidades': comunidades, 'ahumados bio':total_ahumados_bio_2017 , 'charcuteria bio':total_charcuteria_cat_bio_2017 , 'pates refrigerados bio':total_pates_refrig_bio_2017 , 'salazones bio':total_salazones_bio_2017 , 'salchichas bio':total_salchichas_bio_2017, 'sobrasada bio':total_sobrasada_bio_2017, 'ahumados no bio':total_ahumados_no_bio_2017, 'charcuteria no bio':total_charcuteria_cat_no_bio_2017 , 'pates refrigerados no bio':total_pates_refrig_no_bio_2017 , 'salazones no bio':total_salazones_no_bio_2017 , 'salchichas no bio':total_salchichas_no_bio_2017, 'sobrasada no bio':total_sobrasada_no_bio_2017, 'tot ahumados':charcuteria_categorias['ahumados bio']+charcuteria_categorias['ahumados no bio'], 'tot charcuteria':charcuteria_categorias['charcuteria bio']+charcuteria_categorias['charcuteria no bio'], 'tot pates refrigerados':charcuteria_categorias['pates refrigerados bio']+charcuteria_categorias['pates refrigerados no bio'], 'tot salazones':charcuteria_categorias['salazones bio']+charcuteria_categorias['salazones no bio'], 'tot salchichas':charcuteria_categorias['salchichas bio']+charcuteria_categorias['salchichas no bio'], 'tot sobrasada':charcuteria_categorias['sobrasada bio']+charcuteria_categorias['sobrasada no bio'], '%ahumados': charcuteria_categorias['tot ahumados']/tabla_tot_2017['tot 2017'], '%charcuteria': charcuteria_categorias['tot charcuteria']/tabla_tot_2017['tot 2017'], '%pates refrigerados': charcuteria_categorias['tot pates refrigerados']/tabla_tot_2017['tot 2017'], '%salazones': charcuteria_categorias['tot salazones']/tabla_tot_2017['tot 2017'], '%salchichas': charcuteria_categorias['tot salchichas']/tabla_tot_2017['tot 2017'], '%sobrasada': charcuteria_categorias['tot sobrasada']/tabla_tot_2017['tot 2017'], '%ahumados bio': charcuteria_categorias['ahumados bio']/tabla_tot_2017['tot 2017'], '%charcuteria bio': charcuteria_categorias['charcuteria bio']/tabla_tot_2017['tot 2017'], '%pates refrigerados bio': charcuteria_categorias['pates refrigerados bio']/tabla_tot_2017['tot 2017'], '%salazones bio': charcuteria_categorias['salazones bio']/tabla_tot_2017['tot 2017'], '%salchichas bio': charcuteria_categorias['salchichas bio']/tabla_tot_2017['tot 2017'], '%sobrasada bio': charcuteria_categorias['sobrasada bio']/tabla_tot_2017['tot 2017'], '%ahumados no bio': charcuteria_categorias['ahumados no bio']/tabla_tot_2017['tot 2017'], '%charcuteria no bio': charcuteria_categorias['charcuteria no bio']/tabla_tot_2017['tot 2017'], '%pates refrigerados no bio': charcuteria_categorias['pates refrigerados no bio']/tabla_tot_2017['tot 2017'], '%salazones no bio': charcuteria_categorias['salazones no bio']/tabla_tot_2017['tot 2017'], '%salchichas no bio': charcuteria_categorias['salchichas no bio']/tabla_tot_2017['tot 2017'], '%sobrasada no bio': charcuteria_categorias['sobrasada no bio']/tabla_tot_2017['tot 2017']})

congelados_categorias=pd.DataFrame({'comunidades': comunidades, 'helados bio':total_helados_bio_2017, 'otros congelados bio':total_otros_congelados_bio_2017, 'pescados bio':total_pescados_bio_2017, 'pescados preparados bio':total_pescados_prep_bio_2017, 'platos prep congelados bio':total_platos_prep_conge_bio_2017, 'verduras congeladas bio':total_verduras_congeladas_bio_2017, 'helados no bio': total_helados_no_bio_2017, 'otros congelados no bio':total_otros_congelados_no_bio_2017,  'pescados no bio':total_pescados_no_bio_2017, 'pescados preparados no bio':total_pescados_prep_no_bio_2017, 'platos prep congelados no bio': total_platos_prep_conge_no_bio_2017, 'verduras congeladas no bio': total_verduras_congeladas_no_bio_2017})
congelados_categorias=pd.DataFrame({'comunidades': comunidades, 'helados bio':total_helados_bio_2017, 'otros congelados bio':total_otros_congelados_bio_2017, 'pescados bio':total_pescados_bio_2017, 'pescados preparados bio':total_pescados_prep_bio_2017, 'platos prep congelados bio':total_platos_prep_conge_bio_2017, 'verduras congeladas bio':total_verduras_congeladas_bio_2017, 'helados no bio': total_helados_no_bio_2017, 'otros congelados no bio':total_otros_congelados_no_bio_2017,  'pescados no bio':total_pescados_no_bio_2017, 'pescados preparados no bio':total_pescados_prep_no_bio_2017, 'platos prep congelados no bio': total_platos_prep_conge_no_bio_2017, 'verduras congeladas no bio': total_verduras_congeladas_no_bio_2017, 'tot helados':congelados_categorias['helados bio']+congelados_categorias['helados no bio'], 'tot otros congelados':congelados_categorias['otros congelados bio']+congelados_categorias['otros congelados no bio'], 'tot pescados':congelados_categorias['pescados bio']+congelados_categorias['pescados no bio'], 'tot pescados preparados':congelados_categorias['pescados preparados bio']+congelados_categorias['pescados preparados no bio'], 'tot platos prep congelados':congelados_categorias['platos prep congelados bio']+congelados_categorias['platos prep congelados no bio'], 'tot verduras congeladas':congelados_categorias['verduras congeladas bio']+congelados_categorias['verduras congeladas no bio']})
congelados_categorias=pd.DataFrame({'comunidades': comunidades, 'helados bio':total_helados_bio_2017, 'otros congelados bio':total_otros_congelados_bio_2017, 'pescados bio':total_pescados_bio_2017, 'pescados preparados bio':total_pescados_prep_bio_2017, 'platos prep congelados bio':total_platos_prep_conge_bio_2017, 'verduras congeladas bio':total_verduras_congeladas_bio_2017, 'helados no bio': total_helados_no_bio_2017, 'otros congelados no bio':total_otros_congelados_no_bio_2017,  'pescados no bio':total_pescados_no_bio_2017, 'pescados preparados no bio':total_pescados_prep_no_bio_2017, 'platos prep congelados no bio': total_platos_prep_conge_no_bio_2017, 'verduras congeladas no bio': total_verduras_congeladas_no_bio_2017, 'tot helados':congelados_categorias['helados bio']+congelados_categorias['helados no bio'], 'tot otros congelados':congelados_categorias['otros congelados bio']+congelados_categorias['otros congelados no bio'], 'tot pescados':congelados_categorias['pescados bio']+congelados_categorias['pescados no bio'], 'tot pescados preparados':congelados_categorias['pescados preparados bio']+congelados_categorias['pescados preparados no bio'], 'tot platos prep congelados':congelados_categorias['platos prep congelados bio']+congelados_categorias['platos prep congelados no bio'], 'tot verduras congeladas':congelados_categorias['verduras congeladas bio']+congelados_categorias['verduras congeladas no bio'], '%helados': congelados_categorias['tot helados']/tabla_tot_2017['tot 2017'], '%otros congelados': congelados_categorias['tot otros congelados']/tabla_tot_2017['tot 2017'], '%pescados': congelados_categorias['tot pescados']/tabla_tot_2017['tot 2017'], '%pescados preparados': congelados_categorias['tot pescados preparados']/tabla_tot_2017['tot 2017'], '%platos prep congelados': congelados_categorias['tot platos prep congelados']/tabla_tot_2017['tot 2017'], '%verduras congeladas': congelados_categorias['tot verduras congeladas']/tabla_tot_2017['tot 2017'], '%helados bio': congelados_categorias['helados bio']/tabla_tot_2017['tot 2017'], '%otros congelados bio': congelados_categorias['otros congelados bio']/tabla_tot_2017['tot 2017'], '%pescados bio': congelados_categorias['pescados bio']/tabla_tot_2017['tot 2017'], '%pescados preparados bio': congelados_categorias['pescados preparados bio']/tabla_tot_2017['tot 2017'], '%platos prep congelados bio': congelados_categorias['platos prep congelados bio']/tabla_tot_2017['tot 2017'], '%verduras congeladas bio': congelados_categorias['verduras congeladas bio']/tabla_tot_2017['tot 2017'], '%helados no bio': congelados_categorias['helados no bio']/tabla_tot_2017['tot 2017'], '%otros congelados no bio': congelados_categorias['otros congelados no bio']/tabla_tot_2017['tot 2017'], '%pescados no bio': congelados_categorias['pescados no bio']/tabla_tot_2017['tot 2017'], '%pescados preparados no bio': congelados_categorias['pescados preparados no bio']/tabla_tot_2017['tot 2017'], '%platos prep congelados no bio': congelados_categorias['platos prep congelados no bio']/tabla_tot_2017['tot 2017'], '%verduras congeladas no bio': congelados_categorias['verduras congeladas no bio']/tabla_tot_2017['tot 2017']})

derv_lacteos_categorias=pd.DataFrame({'comunidades':comunidades, 'mantequilla bio': total_mantequilla_bio_2017, 'margarina bio': total_margarina_bio_2017, 'nata bio': total_nata_bio_2017, 'postres preparados bio':total_postres_prep_bio_2017, 'quesos petit bio':total_quesos_petit_bio_2017, 'yogures bio':total_yogures_bio_2017, 'mantequilla no bio':total_mantequilla_no_bio_2017, 'margarina no bio': total_margarina_no_bio_2017, 'nata no bio': total_nata_no_bio_2017, 'postres preparados no bio': total_postres_prep_no_bio_2017, 'quesos petit no bio': total_quesos_petit_no_bio_2017, 'yogures no bio':total_yogures_no_bio_2017})
derv_lacteos_categorias=pd.DataFrame({'comunidades':comunidades, 'mantequilla bio': total_mantequilla_bio_2017, 'margarina bio': total_margarina_bio_2017, 'nata bio': total_nata_bio_2017, 'postres preparados bio':total_postres_prep_bio_2017, 'quesos petit bio':total_quesos_petit_bio_2017, 'yogures bio':total_yogures_bio_2017, 'mantequilla no bio':total_mantequilla_no_bio_2017, 'margarina no bio': total_margarina_no_bio_2017, 'nata no bio': total_nata_no_bio_2017, 'postres preparados no bio': total_postres_prep_no_bio_2017, 'quesos petit no bio': total_quesos_petit_no_bio_2017, 'yogures no bio':total_yogures_no_bio_2017, 'tot mantequilla':derv_lacteos_categorias['mantequilla bio']+derv_lacteos_categorias['mantequilla no bio'], 'tot margarina':derv_lacteos_categorias['margarina bio']+derv_lacteos_categorias['margarina no bio'], 'tot nata':derv_lacteos_categorias['nata bio']+derv_lacteos_categorias['nata no bio'], 'tot postres preparados':derv_lacteos_categorias['postres preparados bio']+derv_lacteos_categorias['postres preparados no bio'], 'tot quesos petit':derv_lacteos_categorias['quesos petit bio']+derv_lacteos_categorias['quesos petit no bio'], 'tot yogures':derv_lacteos_categorias['yogures bio']+derv_lacteos_categorias['yogures no bio']})
derv_lacteos_categorias=pd.DataFrame({'comunidades':comunidades, 'mantequilla bio': total_mantequilla_bio_2017, 'margarina bio': total_margarina_bio_2017, 'nata bio': total_nata_bio_2017, 'postres preparados bio':total_postres_prep_bio_2017, 'quesos petit bio':total_quesos_petit_bio_2017, 'yogures bio':total_yogures_bio_2017, 'mantequilla no bio':total_mantequilla_no_bio_2017, 'margarina no bio': total_margarina_no_bio_2017, 'nata no bio': total_nata_no_bio_2017, 'postres preparados no bio': total_postres_prep_no_bio_2017, 'quesos petit no bio': total_quesos_petit_no_bio_2017, 'yogures no bio':total_yogures_no_bio_2017, 'tot mantequilla':derv_lacteos_categorias['mantequilla bio']+derv_lacteos_categorias['mantequilla no bio'], 'tot margarina':derv_lacteos_categorias['margarina bio']+derv_lacteos_categorias['margarina no bio'], 'tot nata':derv_lacteos_categorias['nata bio']+derv_lacteos_categorias['nata no bio'], 'tot postres preparados':derv_lacteos_categorias['postres preparados bio']+derv_lacteos_categorias['postres preparados no bio'], 'tot quesos petit':derv_lacteos_categorias['quesos petit bio']+derv_lacteos_categorias['quesos petit no bio'], 'tot yogures':derv_lacteos_categorias['yogures bio']+derv_lacteos_categorias['yogures no bio'], '%mantequilla': derv_lacteos_categorias['tot mantequilla']/tabla_tot_2017['tot 2017'], '%margarina': derv_lacteos_categorias['tot margarina']/tabla_tot_2017['tot 2017'], '%nata': derv_lacteos_categorias['tot nata']/tabla_tot_2017['tot 2017'], '%postres preparados': derv_lacteos_categorias['tot postres preparados']/tabla_tot_2017['tot 2017'], '%quesos petit': derv_lacteos_categorias['tot quesos petit']/tabla_tot_2017['tot 2017'], '%yogures': derv_lacteos_categorias['tot yogures']/tabla_tot_2017['tot 2017'], '%mantequilla bio': derv_lacteos_categorias['mantequilla bio']/tabla_tot_2017['tot 2017'], '%margarina bio': derv_lacteos_categorias['margarina bio']/tabla_tot_2017['tot 2017'], '%nata bio': derv_lacteos_categorias['nata bio']/tabla_tot_2017['tot 2017'], '%postres preparados bio': derv_lacteos_categorias['postres preparados bio']/tabla_tot_2017['tot 2017'], '%quesos petit bio': derv_lacteos_categorias['quesos petit bio']/tabla_tot_2017['tot 2017'], '%yogures bio': derv_lacteos_categorias['yogures bio']/tabla_tot_2017['tot 2017'], '%mantequilla no bio': derv_lacteos_categorias['mantequilla no bio']/tabla_tot_2017['tot 2017'], '%margarina no bio': derv_lacteos_categorias['margarina no bio']/tabla_tot_2017['tot 2017'], '%nata no bio': derv_lacteos_categorias['nata no bio']/tabla_tot_2017['tot 2017'], '%postres preparados no bio': derv_lacteos_categorias['postres preparados no bio']/tabla_tot_2017['tot 2017'], '%quesos petit no bio': derv_lacteos_categorias['quesos petit no bio']/tabla_tot_2017['tot 2017'], '%yogures no bio': derv_lacteos_categorias['yogures no bio']/tabla_tot_2017['tot 2017']})

precocinados_categorias=pd.DataFrame({'comunidades': comunidades, 'platos prep refrigerados bio':total_platos_prep_refrig_bio_2017, 'platos prep refrigerados no bio':total_platos_prep_refrig_no_bio_2017})
precocinados_categorias=pd.DataFrame({'comunidades': comunidades, 'platos prep refrigerados bio':total_platos_prep_refrig_bio_2017, 'platos prep refrigerados no bio':total_platos_prep_refrig_no_bio_2017, 'tot platos prep refrigerados':precocinados_categorias['platos prep refrigerados bio']+precocinados_categorias['platos prep refrigerados no bio']})
precocinados_categorias=pd.DataFrame({'comunidades': comunidades, 'platos prep refrigerados bio':total_platos_prep_refrig_bio_2017, 'platos prep refrigerados no bio':total_platos_prep_refrig_no_bio_2017, 'tot platos prep refrigerados':precocinados_categorias['platos prep refrigerados bio']+precocinados_categorias['platos prep refrigerados no bio'], '%platos prep refrigerados': precocinados_categorias['tot platos prep refrigerados']/tabla_tot_2017['tot 2017'], '%platos prep refrigerados bio': precocinados_categorias['platos prep refrigerados bio']/tabla_tot_2017['tot 2017'], '%platos prep refrigerados no bio': precocinados_categorias['platos prep refrigerados no bio']/tabla_tot_2017['tot 2017']})

quesos_categorias=pd.DataFrame({'comunidades': comunidades, 'queso azul bio':total_queso_azul_bio_2017, 'queso bola bio':total_queso_bola_bio_2017, 'queso fresco bio':total_queso_fresco_bio_2017, 'queso fundido bio':total_queso_fundido_bio_2017, 'queso pasta blanda bio':total_queso_pasta_blanda_bio_2017, 'queso rallado bio': total_queso_rallado_bio_2017, 'queso tradicional bio': total_queso_tradicional_bio_2017, 'queso blanco past bio': total_queso_blanco_past_bio_2017, 'requeson bio': total_requeson_bio_2017, 'resto quesos bio': total_resto_quesos_bio_2017, 'queso azul no bio':total_queso_azul_no_bio_2017, 'queso bola no bio':total_queso_bola_no_bio_2017, 'queso fresco no bio': total_queso_fresco_no_bio_2017, 'queso fundido no bio': total_queso_fundido_no_bio_2017, 'queso pasta blanda no bio':total_queso_pasta_blanda_no_bio_2017, 'queso rallado no bio': total_queso_rallado_no_bio_2017, 'queso tradicional no bio': total_queso_tradicional_no_bio_2017, 'queso blanco past no bio': total_queso_blanco_past_no_bio_2017, 'requeson no bio':total_requeson_no_bio_2017, 'resto quesos no bio':total_resto_quesos_no_bio_2017})
quesos_categorias=pd.DataFrame({'comunidades': comunidades, 'queso azul bio':total_queso_azul_bio_2017, 'queso bola bio':total_queso_bola_bio_2017, 'queso fresco bio':total_queso_fresco_bio_2017, 'queso fundido bio':total_queso_fundido_bio_2017, 'queso pasta blanda bio':total_queso_pasta_blanda_bio_2017, 'queso rallado bio': total_queso_rallado_bio_2017, 'queso tradicional bio': total_queso_tradicional_bio_2017, 'queso blanco past bio': total_queso_blanco_past_bio_2017, 'requeson bio': total_requeson_bio_2017, 'resto quesos bio': total_resto_quesos_bio_2017, 'queso azul no bio':total_queso_azul_no_bio_2017, 'queso bola no bio':total_queso_bola_no_bio_2017, 'queso fresco no bio': total_queso_fresco_no_bio_2017, 'queso fundido no bio': total_queso_fundido_no_bio_2017, 'queso pasta blanda no bio':total_queso_pasta_blanda_no_bio_2017, 'queso rallado no bio': total_queso_rallado_no_bio_2017, 'queso tradicional no bio': total_queso_tradicional_no_bio_2017, 'queso blanco past no bio': total_queso_blanco_past_no_bio_2017, 'requeson no bio':total_requeson_no_bio_2017, 'resto quesos no bio':total_resto_quesos_no_bio_2017, 'tot queso azul':quesos_categorias['queso azul bio']+quesos_categorias['queso azul no bio'], 'tot queso bola':quesos_categorias['queso bola bio']+quesos_categorias['queso bola no bio'], 'tot queso fresco':quesos_categorias['queso fresco bio']+quesos_categorias['queso fresco no bio'], 'tot queso fundido':quesos_categorias['queso fundido bio']+quesos_categorias['queso fundido no bio'], 'tot queso pasta blanda':quesos_categorias['queso pasta blanda bio']+quesos_categorias['queso pasta blanda no bio'], 'tot queso rallado':quesos_categorias['queso rallado bio']+quesos_categorias['queso rallado no bio'], 'tot queso tradicional':quesos_categorias['queso tradicional bio']+quesos_categorias['queso tradicional no bio'], 'tot queso blanco past':quesos_categorias['queso blanco past bio']+quesos_categorias['queso blanco past no bio'], 'tot requeson':quesos_categorias['requeson bio']+quesos_categorias['requeson no bio'], 'tot resto quesos':quesos_categorias['resto quesos bio']+quesos_categorias['resto quesos no bio']})
quesos_categorias=pd.DataFrame({'comunidades': comunidades, 'queso azul bio':total_queso_azul_bio_2017, 'queso bola bio':total_queso_bola_bio_2017, 'queso fresco bio':total_queso_fresco_bio_2017, 'queso fundido bio':total_queso_fundido_bio_2017, 'queso pasta blanda bio':total_queso_pasta_blanda_bio_2017, 'queso rallado bio': total_queso_rallado_bio_2017, 'queso tradicional bio': total_queso_tradicional_bio_2017, 'queso blanco past bio': total_queso_blanco_past_bio_2017, 'requeson bio': total_requeson_bio_2017, 'resto quesos bio': total_resto_quesos_bio_2017, 'queso azul no bio':total_queso_azul_no_bio_2017, 'queso bola no bio':total_queso_bola_no_bio_2017, 'queso fresco no bio': total_queso_fresco_no_bio_2017, 'queso fundido no bio': total_queso_fundido_no_bio_2017, 'queso pasta blanda no bio':total_queso_pasta_blanda_no_bio_2017, 'queso rallado no bio': total_queso_rallado_no_bio_2017, 'queso tradicional no bio': total_queso_tradicional_no_bio_2017, 'queso blanco past no bio': total_queso_blanco_past_no_bio_2017, 'requeson no bio':total_requeson_no_bio_2017, 'resto quesos no bio':total_resto_quesos_no_bio_2017, 'tot queso azul':quesos_categorias['queso azul bio']+quesos_categorias['queso azul no bio'], 'tot queso bola':quesos_categorias['queso bola bio']+quesos_categorias['queso bola no bio'], 'tot queso fresco':quesos_categorias['queso fresco bio']+quesos_categorias['queso fresco no bio'], 'tot queso fundido':quesos_categorias['queso fundido bio']+quesos_categorias['queso fundido no bio'], 'tot queso pasta blanda':quesos_categorias['queso pasta blanda bio']+quesos_categorias['queso pasta blanda no bio'], 'tot queso rallado':quesos_categorias['queso rallado bio']+quesos_categorias['queso rallado no bio'], 'tot queso tradicional':quesos_categorias['queso tradicional bio']+quesos_categorias['queso tradicional no bio'], 'tot queso blanco past':quesos_categorias['queso blanco past bio']+quesos_categorias['queso blanco past no bio'], 'tot requeson':quesos_categorias['requeson bio']+quesos_categorias['requeson no bio'], 'tot resto quesos':quesos_categorias['resto quesos bio']+quesos_categorias['resto quesos no bio'], '%queso azul': quesos_categorias['tot queso azul']/tabla_tot_2017['tot 2017'], '%queso bola': quesos_categorias['tot queso bola']/tabla_tot_2017['tot 2017'], '%queso fresco': quesos_categorias['tot queso fresco']/tabla_tot_2017['tot 2017'], '%queso fundido': quesos_categorias['tot queso fundido']/tabla_tot_2017['tot 2017'], '%queso pasta blanda': quesos_categorias['tot queso pasta blanda']/tabla_tot_2017['tot 2017'], '%queso rallado': quesos_categorias['tot queso rallado']/tabla_tot_2017['tot 2017'], '%queso tradicional': quesos_categorias['tot queso tradicional']/tabla_tot_2017['tot 2017'], '%queso blanco past': quesos_categorias['tot queso blanco past']/tabla_tot_2017['tot 2017'], '%requeson': quesos_categorias['tot requeson']/tabla_tot_2017['tot 2017'], '%resto quesos': quesos_categorias['tot resto quesos']/tabla_tot_2017['tot 2017'], '%queso azul bio': quesos_categorias['queso azul bio']/tabla_tot_2017['tot 2017'], '%queso bola bio': quesos_categorias['queso bola bio']/tabla_tot_2017['tot 2017'], '%queso fresco bio': quesos_categorias['queso fresco bio']/tabla_tot_2017['tot 2017'], '%queso fundido bio': quesos_categorias['queso fundido bio']/tabla_tot_2017['tot 2017'], '%queso pasta blanda bio': quesos_categorias['queso pasta blanda bio']/tabla_tot_2017['tot 2017'], '%queso rallado bio': quesos_categorias['queso rallado bio']/tabla_tot_2017['tot 2017'], '%queso tradicional bio': quesos_categorias['queso tradicional bio']/tabla_tot_2017['tot 2017'], '%queso blanco past bio': quesos_categorias['queso blanco past bio']/tabla_tot_2017['tot 2017'], '%requeson bio': quesos_categorias['requeson bio']/tabla_tot_2017['tot 2017'], '%resto quesos bio': quesos_categorias['resto quesos bio']/tabla_tot_2017['tot 2017'], '%queso azul no bio': quesos_categorias['queso azul no bio']/tabla_tot_2017['tot 2017'], '%queso bola no bio': quesos_categorias['queso bola no bio']/tabla_tot_2017['tot 2017'], '%queso fresco no bio': quesos_categorias['queso fresco no bio']/tabla_tot_2017['tot 2017'], '%queso fundido no bio': quesos_categorias['queso fundido no bio']/tabla_tot_2017['tot 2017'], '%queso pasta blanda no bio': quesos_categorias['queso pasta blanda no bio']/tabla_tot_2017['tot 2017'], '%queso rallado no bio': quesos_categorias['queso rallado no bio']/tabla_tot_2017['tot 2017'], '%queso tradicional no bio': quesos_categorias['queso tradicional no bio']/tabla_tot_2017['tot 2017'], '%queso blanco past no bio': quesos_categorias['queso blanco past no bio']/tabla_tot_2017['tot 2017'], '%requeson no bio': quesos_categorias['requeson no bio']/tabla_tot_2017['tot 2017'], '%resto quesos no bio': quesos_categorias['resto quesos no bio']/tabla_tot_2017['tot 2017']})

alim_seca_categorias
# Out:
#            comunidades  aceite bio  aditivos bio  alim infantiles bio  \
# 0            Andalucia     1166.79        472.96              2064.26
# 1               Aragon      186.35        114.65               154.86
# 2             Asturias      217.70        114.36               242.58
# 3             Baleares      418.68        310.07               316.45
# 4         C_Valenciana      619.91        309.06              1249.05
# 5             Canarias      713.34        394.38               708.21
# 6            Cantabria      137.79         78.60               128.63
# 7   Castilla_La_Mancha      130.06         79.43               317.76
# 8        Castilla_Leon      297.82        127.10               348.55
# 9            Catalunya     1081.64        652.62              1275.56
# 10       Ceuta_Melilla       15.80          6.20                14.64
# 11         Extremadura       62.59         33.67               199.98
# ...

# %%
#Hago gráfica paraa ver el %de gasto medio de cada categoria
etiquetas=alim_seca+bebidas+conservas+leche_batidos+charcuteria+congelados+derv_lacteos+precocinados+quesos
todas_categorias=pd.concat([alim_seca_categorias.loc[:,'%aceite':'%sopas deshid'], bebidas_categorias.loc[:,'%aguas':'%zumos'], conservas_categorias.loc[:,'%aceitunas':'%platos preparados'], leche_batidos_categorias.loc[:,'%batidos':'%leche no liquida'], charcuteria_categorias.loc[:,'%ahumados':'%sobrasada'], congelados_categorias.loc[:,'%helados':'%verduras congeladas'], derv_lacteos_categorias.loc[:,'%mantequilla':'%yogures'], precocinados_categorias.loc[:,'%platos prep refrigerados'], quesos_categorias.loc[:,'%queso azul':'%resto quesos']], axis=1,)
todas_categorias=pd.DataFrame({'etiquetas':etiquetas, 'categorias':todas_categorias.mean().values})

plt.figure(figsize=(27,25))
gasto_todas_categorias= sns.barplot(x=todas_categorias.sort_values(by=['categorias'])['categorias'], y=todas_categorias.sort_values(by=['categorias'])['etiquetas'] , data=todas_categorias.sort_values(by=['categorias']))

# %%
a=pd.concat([alim_seca_categorias.loc[:,'%aceite':'%sopas deshid'], bebidas_categorias.loc[:,'%aguas':'%zumos'], conservas_categorias.loc[:,'%aceitunas':'%platos preparados'], leche_batidos_categorias.loc[:,'%batidos':'%leche no liquida'], charcuteria_categorias.loc[:,'%ahumados':'%sobrasada'], congelados_categorias.loc[:,'%helados':'%verduras congeladas'], derv_lacteos_categorias.loc[:,'%mantequilla':'%yogures'], precocinados_categorias.loc[:,'%platos prep refrigerados'], quesos_categorias.loc[:,'%queso azul':'%resto quesos']], axis=1,)
a.describe()
# Out:
#          %aceite  %aditivos  %alim infantiles  %aperitivos     %arroz  \
# count  18.000000  18.000000         18.000000    18.000000  18.000000
# mean    0.035893   0.008626          0.007322     0.017151   0.005462
# std     0.006902   0.001071          0.002517     0.002255   0.001184
# min     0.025970   0.006861          0.004801     0.013088   0.004090
# 25%     0.030421   0.007969          0.005741     0.015571   0.004967
# 50%     0.034715   0.008553          0.006041     0.017649   0.005136
# 75%     0.041187   0.009334          0.008284     0.018998   0.005746
# max     0.046803   0.011067          0.013760     0.020285   0.009737
#
#          %azucar  %bolleria inds     %cacao     %cafes  %cereales desayuno  \
# count  18.000000       18.000000  18.000000  18.000000           18.000000
# mean    0.005087        0.027606   0.009705   0.022450            0.009348
# std     0.000505        0.002523   0.001262   0.002112            0.001060
# ...

# %%
#Hago gráfica paraa ver el %de gasto medio de cada categoria
etiquetas=alim_seca+bebidas+conservas+leche_batidos+charcuteria+congelados+derv_lacteos+precocinados+quesos
todas_categorias_bio=pd.concat([alim_seca_categorias.loc[:,'%aceite bio':'%sopas deshid bio'], bebidas_categorias.loc[:,'%aguas bio':'%zumos bio'], conservas_categorias.loc[:,'%aceitunas bio':'%platos preparados bio'], leche_batidos_categorias.loc[:,'%batidos bio':'%leche no liquida bio'], charcuteria_categorias.loc[:,'%ahumados bio':'%sobrasada bio'], congelados_categorias.loc[:,'%helados bio':'%verduras congeladas bio'], derv_lacteos_categorias.loc[:,'%mantequilla bio':'%yogures bio'], precocinados_categorias.loc[:,'%platos prep refrigerados bio'], quesos_categorias.loc[:,'%queso azul bio':'%resto quesos bio']], axis=1,)
todas_categorias_bio=pd.DataFrame({'etiquetas':etiquetas, 'categorias':todas_categorias_bio.mean().values})

plt.figure(figsize=(20,18))
gasto_todas_categorias_bio= sns.barplot(x=todas_categorias_bio.sort_values(by=['categorias'])['categorias'], y=todas_categorias_bio.sort_values(by=['categorias'])['etiquetas'] , data=todas_categorias_bio.sort_values(by=['categorias']))

# %%
a=todas_categorias_bio.sort_values(by=['categorias'])
a.describe()
#a.quantile(0.25)
# Out:
#        categorias
# count   69.000000
# mean     0.000082
# std      0.000137
# min      0.000000
# 25%      0.000005
# 50%      0.000028
# 75%      0.000104
# max      0.000861

# %%
a.iloc[10:20,:]
# Out:
#               etiquetas    categorias
# 45            sobrasada  4.589307e-07
# 44           salchichas  4.752296e-07
# 56         quesos petit  8.429430e-07
# 51  verduras congeladas  1.075209e-06
# 64        queso rallado  1.142693e-06
# 59           queso azul  2.076423e-06
# 53            margarina  2.097751e-06
# 46              helados  4.809697e-06
# 48             pescados  6.338891e-06
# 37             horchata  6.591525e-06

# %%
#GRAFICO GASTO BIO POR COMUNIDADES
plt.figure(figsize=(8,5))
plt.title('Porcentaje gasto BIO por CCAA')
gasto_total_BIO = sns.barplot(x=tabla_tot_2017.sort_values(by=['%BIO 2017'])['%BIO 2017'],y=tabla_tot_2017.sort_values(by=['%BIO 2017'])['comunidades'], data=tabla_tot_2017.sort_values(by=['%BIO 2017']))

# %% [markdown]
# ### Análisis SECCION
# #### Primero hago las matrices de correlación por sección total, bio y no bio

# %%
seccion_enfermedades=pd.DataFrame({'comunidades':comunidades,'%alim seca 2017':tabla_seccion_2017['tot alim seca 2017']/tabla_tot_2017['tot 2017'],'%bebidas 2017': tabla_seccion_2017['tot bebidas 2017']/tabla_tot_2017['tot 2017'], '%conservas 2017':tabla_seccion_2017['tot conservas 2017']/tabla_tot_2017['tot 2017'], '%leche y batidos 2017':tabla_seccion_2017['tot leche y batidos 2017']/tabla_tot_2017['tot 2017'], '%charcuteria 2017':tabla_seccion_2017['tot charcuteria 2017']/tabla_tot_2017['tot 2017'], '%congelados 2017':tabla_seccion_2017['tot congelados 2017']/tabla_tot_2017['tot 2017'], '%derv lacteos 2017':tabla_seccion_2017['tot derv lacteos 2017']/tabla_tot_2017['tot 2017'], '%precocinados 2017':tabla_seccion_2017['tot precocinados 2017']/tabla_tot_2017['tot 2017'],'%quesos 2017':tabla_seccion_2017['tot quesos 2017']/tabla_tot_2017['tot 2017'], 'hipertension': hipertension_p, 'diabetes': diabetes_p, 'colesterol': colesterol_p, 'obesidad':obesidad_p})
seccion_enfermedades
 
plt.figure(figsize=(15, 10))
seccion_enfermedades_cor = seccion_enfermedades.corr()
sns.heatmap(seccion_enfermedades_cor, 
            annot=True,
            xticklabels=seccion_enfermedades_cor.columns.values,
            yticklabels=seccion_enfermedades_cor.columns.values)
plt.savefig("Tabla correlación seccion enfermedades.jpg")

# %%
seccion_bio_enfermedades=pd.DataFrame({'comunidades':comunidades,'%alim seca BIO 2017':tabla_seccion_2017['%alim seca BIO 2017'],'%bebidas BIO 2017': tabla_seccion_2017['%bebidas BIO 2017'], '%conservas BIO 2017':tabla_seccion_2017['%conservas BIO 2017'], '%leche y batidos BIO 2017':tabla_seccion_2017['%leche y batidos BIO 2017'], '%charcuteria BIO 2017':tabla_seccion_2017['%charcuteria BIO 2017'], '%congelados BIO 2017':tabla_seccion_2017['%congelados BIO 2017'], '%derv lacteos BIO 2017':tabla_seccion_2017['%derv lacteos BIO 2017'], '%precocinados BIO 2017':tabla_seccion_2017['%precocinados BIO 2017'],'%quesos BIO 2017':tabla_seccion_2017['%quesos BIO 2017'], 'hipertension': hipertension_p, 'diabetes': diabetes_p, 'colesterol': colesterol_p, 'obesidad':obesidad_p})
seccion_bio_enfermedades

plt.figure(figsize=(15, 10))
seccion_bio_enfermedades_cor = seccion_bio_enfermedades.corr()
sns.heatmap(seccion_bio_enfermedades_cor, 
            annot=True,
            xticklabels=seccion_bio_enfermedades_cor.columns.values,
            yticklabels=seccion_bio_enfermedades_cor.columns.values)
plt.savefig("Tabla correlación seccion BIO enfermedades.jpg")

# %%
seccion_no_bio_enfermedades=pd.DataFrame({'comunidades':comunidades,'%alim seca NO BIO 2017':tabla_seccion_2017['%alim seca NO BIO 2017'],'%bebidas NO BIO 2017': tabla_seccion_2017['%bebidas NO BIO 2017'], '%conservas NO BIO 2017':tabla_seccion_2017['%conservas NO BIO 2017'], '%leche y batidos NO BIO 2017':tabla_seccion_2017['%leche y batidos NO BIO 2017'], '%charcuteria NO BIO 2017':tabla_seccion_2017['%charcuteria NO BIO 2017'], '%congelados NO BIO 2017':tabla_seccion_2017['%congelados NO BIO 2017'], '%derv lacteos NO BIO 2017':tabla_seccion_2017['%derv lacteos NO BIO 2017'], '%precocinados NO BIO 2017':tabla_seccion_2017['%precocinados NO BIO 2017'],'%quesos NO BIO 2017':tabla_seccion_2017['%quesos NO BIO 2017'], 'hipertension': hipertension_p, 'diabetes': diabetes_p, 'colesterol': colesterol_p, 'obesidad':obesidad_p})
seccion_no_bio_enfermedades

plt.figure(figsize=(15, 10))
seccion_no_bio_enfermedades_cor = seccion_no_bio_enfermedades.corr()
sns.heatmap(seccion_no_bio_enfermedades_cor, 
            annot=True,
            xticklabels=seccion_no_bio_enfermedades_cor.columns.values,
            yticklabels=seccion_no_bio_enfermedades_cor.columns.values)
plt.savefig("Tabla correlación seccion BIO enfermedades.jpg")

# %%
#charcuteria e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(seccion_bio_enfermedades["%charcuteria BIO 2017"],seccion_bio_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(seccion_bio_enfermedades["%charcuteria BIO 2017"], seccion_bio_enfermedades["hipertension"], 'o', label='original data')
plt.plot(seccion_bio_enfermedades["%charcuteria BIO 2017"], ordenada + pendiente*seccion_bio_enfermedades["%charcuteria BIO 2017"], 'r', label='fitted line')
plt.xlabel("%charcuteria BIO 2017")
plt.ylabel("hipertension")
plt.legend()

#charcuteria y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(seccion_bio_enfermedades["%charcuteria BIO 2017"],seccion_bio_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(seccion_bio_enfermedades["%charcuteria BIO 2017"], seccion_bio_enfermedades["diabetes"], 'o', label='original data')
plt.plot(seccion_bio_enfermedades["%charcuteria BIO 2017"], ordenada + pendiente*seccion_bio_enfermedades["%charcuteria BIO 2017"], 'r', label='fitted line')
plt.xlabel("%charcuteria BIO 2017")
plt.ylabel("diabetes")
plt.legend()

#charcuteria y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(seccion_bio_enfermedades["%charcuteria BIO 2017"],seccion_bio_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(seccion_bio_enfermedades["%charcuteria BIO 2017"], seccion_bio_enfermedades["colesterol"], 'o', label='original data')
plt.plot(seccion_bio_enfermedades["%charcuteria BIO 2017"], ordenada + pendiente*seccion_bio_enfermedades["%charcuteria BIO 2017"], 'r', label='fitted line')
plt.xlabel("%charcuteria BIO 2017")
plt.ylabel("colesterol")
plt.legend()

#charcuteria y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(seccion_bio_enfermedades["%charcuteria BIO 2017"],seccion_bio_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(seccion_bio_enfermedades["%charcuteria BIO 2017"], seccion_bio_enfermedades["obesidad"], 'o', label='original data')
plt.plot(seccion_bio_enfermedades["%charcuteria BIO 2017"], ordenada + pendiente*seccion_bio_enfermedades["%charcuteria BIO 2017"], 'r', label='fitted line')
plt.xlabel("%charcuteria BIO 2017")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.09134416063081106
# p_value colesterol:  0.36112743794720814
# p_value diabetes:  0.008699824291830777
# p_value obesidad:  0.25832863264668166

# %%
#charcuteria e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"],seccion_no_bio_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"], seccion_no_bio_enfermedades["hipertension"], 'o', label='original data')
plt.plot(seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"], ordenada + pendiente*seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"], 'r', label='fitted line')
plt.xlabel("%charcuteria NO BIO 2017")
plt.ylabel("hipertension")
plt.legend()

#charcuteria y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"],seccion_no_bio_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"], seccion_no_bio_enfermedades["diabetes"], 'o', label='original data')
plt.plot(seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"], ordenada + pendiente*seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"], 'r', label='fitted line')
plt.xlabel("%charcuteria NO BIO 2017")
plt.ylabel("diabetes")
plt.legend()

#charcuteria y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"],seccion_no_bio_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"], seccion_no_bio_enfermedades["colesterol"], 'o', label='original data')
plt.plot(seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"], ordenada + pendiente*seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"], 'r', label='fitted line')
plt.xlabel("%charcuteria NO BIO 2017")
plt.ylabel("colesterol")
plt.legend()

#charcuteria y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"],seccion_no_bio_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"], seccion_no_bio_enfermedades["obesidad"], 'o', label='original data')
plt.plot(seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"], ordenada + pendiente*seccion_no_bio_enfermedades["%charcuteria NO BIO 2017"], 'r', label='fitted line')
plt.xlabel("%charcuteria NO BIO 2017")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.07995166483625443
# p_value colesterol:  0.6105499014574572
# p_value diabetes:  0.9462085384023768
# p_value obesidad:  0.9132585588913743

# %% [markdown]
# ### Análisis CATEGORIAS
# #### Primero hago las matrices de correlación por sección total, bio y no bio

# %% [markdown]
# ### ALIM SECA

# %%
media_rel_alim_seca_bio=pd.DataFrame({'alim seca':alim_seca, '%gasto': alim_seca_categorias.loc[:,'%aceite bio':'%sopas deshid bio'].mean().values})
media_rel_alim_seca_bio.sort_values(by=['%gasto'])
 
plt.figure(figsize=(8,5))
#plt.title('Porcentaje gasto BIO por CCAA')
gasto_total_BIO = sns.barplot(x=media_rel_alim_seca_bio.sort_values(by=['%gasto'])['%gasto'], y=media_rel_alim_seca_bio.sort_values(by=['%gasto'])['alim seca'] , data=media_rel_alim_seca_bio.sort_values(by=['%gasto']))

# %%
#Matriz de correlacion de las categorías de ALIM SECA
##Para el análisis quito GOLOSINAS porque es una de las catedorías con % gasto casi nulo

alim_seca_bio_categorias_vs_enfermedades=pd.DataFrame({'comunidades':comunidades,'%aceite bio':alim_seca_categorias['%aceite bio'],'%aditivos bio': alim_seca_categorias['%aditivos bio'], '%alim infantiles bio':alim_seca_categorias['%alim infantiles bio'], '%aperitivos bio':alim_seca_categorias['%aperitivos bio'], '%arroz bio':alim_seca_categorias['%arroz bio'], '%azucar bio':alim_seca_categorias['%azucar bio'], '%bolleria inds bio':alim_seca_categorias['%bolleria inds bio'], '%cacao bio':alim_seca_categorias['%cacao bio'], '%cafes bio':alim_seca_categorias['%cafes bio'], '%cereales desayuno bio':alim_seca_categorias['%cereales desayuno bio'], '%chocolates bio':alim_seca_categorias['%chocolates bio'],'%dieteticos bio': alim_seca_categorias['%dieteticos bio'], '%dulces navidad bio':alim_seca_categorias['%dulces navidad bio'], '%frutos secos bio':alim_seca_categorias['%frutos secos bio'], '%galletas bio':alim_seca_categorias['%galletas bio'], '%infusiones bio':alim_seca_categorias['%infusiones bio'], '%legumbres bio':alim_seca_categorias['%legumbres bio'], '%panaderia bio':alim_seca_categorias['%panaderia bio'], '%pastas bio':alim_seca_categorias['%pastas bio'], '%reposteria bio':alim_seca_categorias['%reposteria bio'], '%salsas bio':alim_seca_categorias['%salsas bio'], '%sopas deshid bio':alim_seca_categorias['%sopas deshid bio'], 'hipertension': hipertension_p, 'diabetes': diabetes_p, 'colesterol': colesterol_p, 'obesidad':obesidad_p})
alim_seca_bio_categorias_vs_enfermedades

plt.figure(figsize=(15, 10))
alim_seca_bio_categorias_vs_enfermedades_cor = alim_seca_bio_categorias_vs_enfermedades.corr()
sns.heatmap(alim_seca_bio_categorias_vs_enfermedades_cor, 
            annot=True,
            annot_kws={"size": 10},
            xticklabels=alim_seca_bio_categorias_vs_enfermedades_cor.columns.values,
            yticklabels=alim_seca_bio_categorias_vs_enfermedades_cor.columns.values)

# %% [markdown]
# #### Regresiones lineales

# %%
#aceite e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%aceite bio"],alim_seca_bio_categorias_vs_enfermedades["hipertension"])
 
plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aceite bio"], alim_seca_bio_categorias_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aceite bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%aceite bio"], 'r', label='fitted line')
plt.xlabel("%aceite bio")
plt.ylabel("hipertension")
plt.legend()
 
#aceite y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%aceite bio"],alim_seca_bio_categorias_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aceite bio"], alim_seca_bio_categorias_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aceite bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%aceite bio"], 'r', label='fitted line')
plt.xlabel("%aceite bio")
plt.ylabel("diabetes")
plt.legend()
 
#aceite y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%aceite bio"],alim_seca_bio_categorias_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aceite bio"], alim_seca_bio_categorias_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aceite bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%aceite bio"], 'r', label='fitted line')
plt.xlabel("%aceite bio")
plt.ylabel("colesterol")
plt.legend()
 
#aceite y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%aceite bio"],alim_seca_bio_categorias_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aceite bio"], alim_seca_bio_categorias_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aceite bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%aceite bio"], 'r', label='fitted line')
plt.xlabel("%aceite bio")
plt.ylabel("obesidad")
plt.legend()
 
plt.show()
 
if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)
 
if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)
 
if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)
 
if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.26794103363720206
# p_value colesterol:  0.8223849664022891
# p_value diabetes:  0.9236522114683843
# p_value obesidad:  0.921535770900322

# %%
#alim infantiles e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"],alim_seca_bio_categorias_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"], alim_seca_bio_categorias_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"], 'r', label='fitted line')
plt.xlabel("%alim infantiles bio")
plt.ylabel("hipertension")
plt.legend()

#alim infantiles y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"],alim_seca_bio_categorias_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"], alim_seca_bio_categorias_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"], 'r', label='fitted line')
plt.xlabel("%alim infantiles bio")
plt.ylabel("diabetes")
plt.legend()

#alim infantiles y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"],alim_seca_bio_categorias_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"], alim_seca_bio_categorias_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"], 'r', label='fitted line')
plt.xlabel("%alim infantiles bio")
plt.ylabel("colesterol")
plt.legend()

#alim infantiles y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"],alim_seca_bio_categorias_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"], alim_seca_bio_categorias_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%alim infantiles bio"], 'r', label='fitted line')
plt.xlabel("%alim infantiles bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.8416281205177137
# p_value colesterol:  0.8205767330544288
# p_value diabetes:  0.03809743828947535
# p_value obesidad:  0.026712375405887986

# %%
#aperitivos e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"],alim_seca_bio_categorias_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"], alim_seca_bio_categorias_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"], 'r', label='fitted line')
plt.xlabel("%aperitivos bio")
plt.ylabel("hipertension")
plt.legend()

#aperitivos y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"],alim_seca_bio_categorias_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"], alim_seca_bio_categorias_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"], 'r', label='fitted line')
plt.xlabel("%aperitivos bio")
plt.ylabel("diabetes")
plt.legend()

#aperitivos y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"],alim_seca_bio_categorias_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"], alim_seca_bio_categorias_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"], 'r', label='fitted line')
plt.xlabel("%aperitivos bio")
plt.ylabel("colesterol")
plt.legend()

#aperitivos y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"],alim_seca_bio_categorias_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"], alim_seca_bio_categorias_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%aperitivos bio"], 'r', label='fitted line')
plt.xlabel("%aperitivos bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.20874589335014013
# p_value colesterol:  0.6209125455006781
# p_value diabetes:  0.056381924921276506
# p_value obesidad:  0.01456222617570619

# %%
#arroz e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%arroz bio"],alim_seca_bio_categorias_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%arroz bio"], alim_seca_bio_categorias_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%arroz bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%arroz bio"], 'r', label='fitted line')
plt.xlabel("%arroz bio")
plt.ylabel("hipertension")
plt.legend()

#arroz y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%arroz bio"],alim_seca_bio_categorias_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%arroz bio"], alim_seca_bio_categorias_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%arroz bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%arroz bio"], 'r', label='fitted line')
plt.xlabel("%arroz bio")
plt.ylabel("diabetes")
plt.legend()

#arroz y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%arroz bio"],alim_seca_bio_categorias_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%arroz bio"], alim_seca_bio_categorias_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%arroz bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%arroz bio"], 'r', label='fitted line')
plt.xlabel("%arroz bio")
plt.ylabel("colesterol")
plt.legend()

#arroz y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%arroz bio"],alim_seca_bio_categorias_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%arroz bio"], alim_seca_bio_categorias_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%arroz bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%arroz bio"], 'r', label='fitted line')
plt.xlabel("%arroz bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.12717520619717312
# p_value colesterol:  0.8044185809521183
# p_value diabetes:  0.19495091912214293
# p_value obesidad:  0.04420714954467591

# %%
#bolleria inds e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"],alim_seca_bio_categorias_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"], alim_seca_bio_categorias_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"], 'r', label='fitted line')
plt.xlabel("%bolleria inds bio")
plt.ylabel("hipertension")
plt.legend()

#bolleria inds y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"],alim_seca_bio_categorias_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"], alim_seca_bio_categorias_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"], 'r', label='fitted line')
plt.xlabel("%bolleria inds bio")
plt.ylabel("diabetes")
plt.legend()

#bolleria indus y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"],alim_seca_bio_categorias_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"], alim_seca_bio_categorias_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"], 'r', label='fitted line')
plt.xlabel("%bolleria inds bio")
plt.ylabel("colesterol")
plt.legend()

#bolleria inds y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"],alim_seca_bio_categorias_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"], alim_seca_bio_categorias_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%bolleria inds bio"], 'r', label='fitted line')
plt.xlabel("%bolleria inds bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.08329347412035591
# p_value colesterol:  0.18557587067647238
# p_value diabetes:  0.5536509828139754
# p_value obesidad:  0.06512730893770396

# %%
#chocolates e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"],alim_seca_bio_categorias_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"], alim_seca_bio_categorias_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"], 'r', label='fitted line')
plt.xlabel("%chocolates bio")
plt.ylabel("hipertension")
plt.legend()

#chocolates y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"],alim_seca_bio_categorias_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"], alim_seca_bio_categorias_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"], 'r', label='fitted line')
plt.xlabel("%chocolates bio")
plt.ylabel("diabetes")
plt.legend()

#chocolates y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"],alim_seca_bio_categorias_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"], alim_seca_bio_categorias_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"], 'r', label='fitted line')
plt.xlabel("%chocolates bio")
plt.ylabel("colesterol")
plt.legend()

#chocolates y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"],alim_seca_bio_categorias_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"], alim_seca_bio_categorias_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%chocolates bio"], 'r', label='fitted line')
plt.xlabel("%chocolates bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.18331448304374107
# p_value colesterol:  0.607255659406488
# p_value diabetes:  0.6556876618384055
# p_value obesidad:  0.06180733138551777

# %%
#dulces navidad e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"],alim_seca_bio_categorias_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"], alim_seca_bio_categorias_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"], 'r', label='fitted line')
plt.xlabel("%dulces navidad bio")
plt.ylabel("hipertension")
plt.legend()

#dulces navidad y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"],alim_seca_bio_categorias_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"], alim_seca_bio_categorias_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"], 'r', label='fitted line')
plt.xlabel("%dulces navidad bio")
plt.ylabel("diabetes")
plt.legend()

#dulces navidad y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"],alim_seca_bio_categorias_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"], alim_seca_bio_categorias_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"], 'r', label='fitted line')
plt.xlabel("%dulces navidad bio")
plt.ylabel("colesterol")
plt.legend()

#dulces navidad y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"],alim_seca_bio_categorias_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"], alim_seca_bio_categorias_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%dulces navidad bio"], 'r', label='fitted line')
plt.xlabel("%dulces navidad bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.1956306213636917
# p_value colesterol:  0.0061257505445479424
# p_value diabetes:  0.8347043357128248
# p_value obesidad:  0.36640980562822767

# %%
#galletas e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%galletas bio"],alim_seca_bio_categorias_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%galletas bio"], alim_seca_bio_categorias_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%galletas bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%galletas bio"], 'r', label='fitted line')
plt.xlabel("%galletas bio")
plt.ylabel("hipertension")
plt.legend()

#galletas y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%galletas bio"],alim_seca_bio_categorias_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%galletas bio"], alim_seca_bio_categorias_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%galletas bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%galletas bio"], 'r', label='fitted line')
plt.xlabel("%galletas bio")
plt.ylabel("diabetes")
plt.legend()

#galletas y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%galletas bio"],alim_seca_bio_categorias_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%galletas bio"], alim_seca_bio_categorias_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%galletas bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%galletas bio"], 'r', label='fitted line')
plt.xlabel("%galletas bio")
plt.ylabel("colesterol")
plt.legend()

#galletas y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%galletas bio"],alim_seca_bio_categorias_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%galletas bio"], alim_seca_bio_categorias_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%galletas bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%galletas bio"], 'r', label='fitted line')
plt.xlabel("%galletas bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.377394208608375
# p_value colesterol:  0.9639029771280495
# p_value diabetes:  0.21167235951040428
# p_value obesidad:  0.07190626730385237

# %%
#reposteria e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"],alim_seca_bio_categorias_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"], alim_seca_bio_categorias_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"], 'r', label='fitted line')
plt.xlabel("%reposteria bio")
plt.ylabel("hipertension")
plt.legend()

#reposteria y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"],alim_seca_bio_categorias_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"], alim_seca_bio_categorias_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"], 'r', label='fitted line')
plt.xlabel("%reposteria bio")
plt.ylabel("diabetes")
plt.legend()

#reposteria y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"],alim_seca_bio_categorias_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"], alim_seca_bio_categorias_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"], 'r', label='fitted line')
plt.xlabel("%reposteria bio")
plt.ylabel("colesterol")
plt.legend()

#reposteria y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"],alim_seca_bio_categorias_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"], alim_seca_bio_categorias_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"], ordenada + pendiente*alim_seca_bio_categorias_vs_enfermedades["%reposteria bio"], 'r', label='fitted line')
plt.xlabel("%reposteria bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.008462018840331922
# p_value colesterol:  0.09357340332785985
# p_value diabetes:  0.32201110518998427
# p_value obesidad:  0.48299939764787825

# %% [markdown]
# ### BEBIDAS

# %%
media_rel_bebidas_bio=pd.DataFrame({'bebidas':bebidas, '%gasto': bebidas_categorias.loc[:,'%aguas bio':'%zumos bio'].mean().values})
media_rel_bebidas_bio.sort_values(by=['%gasto'])

plt.figure(figsize=(8,5))
#plt.title('Porcentaje gasto BIO por CCAA')
gasto_total_BIO = sns.barplot(x=media_rel_bebidas_bio.sort_values(by=['%gasto'])['%gasto'], y=media_rel_bebidas_bio.sort_values(by=['%gasto'])['bebidas'] , data=media_rel_bebidas_bio.sort_values(by=['%gasto']))

# %%
#Matriz de correlacion de las categorías de BEBIDAS
##AGUAS BIO??
##Elimino bebidas alcohólicas por el bajo % de gasto

bebidas_categorias_bio_vs_enfermedades=pd.DataFrame({'comunidades':comunidades,'%aguas bio':bebidas_categorias['%aguas bio'], '%refrescos bio':bebidas_categorias['%refrescos bio'], '%cerveza bio':bebidas_categorias['%cerveza bio'], '%espumosos bio':bebidas_categorias['%espumosos bio'], '%vinos bio':bebidas_categorias['%vinos bio'], '%zumos bio':bebidas_categorias['%zumos bio'], 'hipertension': hipertension_p, 'diabetes': diabetes_p, 'colesterol': colesterol_p, 'obesidad':obesidad_p})
bebidas_categorias_bio_vs_enfermedades

plt.figure(figsize=(10, 5))
bebidas_categorias_bio_vs_enfermedades_cor = bebidas_categorias_bio_vs_enfermedades.corr()
sns.heatmap(bebidas_categorias_bio_vs_enfermedades_cor, 
            annot=True,
            xticklabels=bebidas_categorias_bio_vs_enfermedades_cor.columns.values,
            yticklabels=bebidas_categorias_bio_vs_enfermedades_cor.columns.values)

# %%
#aguas e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%aguas bio"],bebidas_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%aguas bio"], bebidas_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%aguas bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%aguas bio"], 'r', label='fitted line')
plt.xlabel("%aguas bio")
plt.ylabel("hipertension")
plt.legend()

#aguas y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%aguas bio"],bebidas_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%aguas bio"], bebidas_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%aguas bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%aguas bio"], 'r', label='fitted line')
plt.xlabel("%aguas bio")
plt.ylabel("diabetes")
plt.legend()

#aguas y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%aguas bio"],bebidas_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%aguas bio"], bebidas_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%aguas bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%aguas bio"], 'r', label='fitted line')
plt.xlabel("%aguas bio")
plt.ylabel("colesterol")
plt.legend()

#aguas y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%aguas bio"],bebidas_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%aguas bio"], bebidas_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%aguas bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%aguas bio"], 'r', label='fitted line')
plt.xlabel("%aguas bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.05933796814295844
# p_value colesterol:  0.08542291891984624
# p_value diabetes:  0.2450313137496652
# p_value obesidad:  0.12196598799204647

# %%
#refrescos e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%refrescos bio"],bebidas_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%refrescos bio"], bebidas_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%refrescos bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%refrescos bio"], 'r', label='fitted line')
plt.xlabel("%refrescos bio")
plt.ylabel("hipertension")
plt.legend()

#refrescos y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%refrescos bio"],bebidas_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%refrescos bio"], bebidas_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%refrescos bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%refrescos bio"], 'r', label='fitted line')
plt.xlabel("%refrescos bio")
plt.ylabel("diabetes")
plt.legend()

#refrescos y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%refrescos bio"],bebidas_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%refrescos bio"], bebidas_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%refrescos bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%refrescos bio"], 'r', label='fitted line')
plt.xlabel("%refrescos bio")
plt.ylabel("colesterol")
plt.legend()

#refrescos y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%refrescos bio"],bebidas_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%refrescos bio"], bebidas_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%refrescos bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%refrescos bio"], 'r', label='fitted line')
plt.xlabel("%refrescos bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.9088144381478842
# p_value colesterol:  0.6431073265373424
# p_value diabetes:  0.004045257869043087
# p_value obesidad:  0.23405537953600486

# %%
#Miro cual es la CA con mayor %gasto en refrescos
bebidas_categorias_bio_vs_enfermedades.loc[:,('comunidades',"%refrescos bio")].sort_values(by=['%refrescos bio'])
# Out:
#            comunidades  %refrescos bio
# 9            Catalunya        0.000022
# 3             Baleares        0.000025
# 15              Murcia        0.000031
# 4         C_Valenciana        0.000041
# 12             Galicia        0.000043
# 1               Aragon        0.000043
# 13            La_Rioja        0.000044
# 7   Castilla_La_Mancha        0.000051
# 14              Madrid        0.000057
# 6            Cantabria        0.000061
# 11         Extremadura        0.000066
# 0            Andalucia        0.000075
# 8        Castilla_Leon        0.000086
# 17          Pais_Vasco        0.000092
# 10       Ceuta_Melilla        0.000158
# 16             Navarra        0.000184
# 2             Asturias        0.000509
# 5             Canarias        0.001494

# %%
#elimino Canarias
sin_canarias_bebidas_bio=bebidas_categorias_bio_vs_enfermedades.drop(bebidas_categorias_bio_vs_enfermedades[bebidas_categorias_bio_vs_enfermedades['comunidades']=='Canarias'].index)

# %%
#Vuelvo a hacer las regresiones lineales pero sin Canarias

#refrescos e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(sin_canarias_bebidas_bio["%refrescos bio"],sin_canarias_bebidas_bio["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(sin_canarias_bebidas_bio["%refrescos bio"], sin_canarias_bebidas_bio["hipertension"], 'o', label='original data')
plt.plot(sin_canarias_bebidas_bio["%refrescos bio"], ordenada + pendiente*sin_canarias_bebidas_bio["%refrescos bio"], 'r', label='fitted line')
plt.xlabel("%refrescos bio")
plt.ylabel("hipertension")
plt.legend()

#refrescos y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(sin_canarias_bebidas_bio["%refrescos bio"],sin_canarias_bebidas_bio["diabetes"])
plt.subplot(222)
plt.plot(sin_canarias_bebidas_bio["%refrescos bio"], sin_canarias_bebidas_bio["diabetes"], 'o', label='original data')
plt.plot(sin_canarias_bebidas_bio["%refrescos bio"], ordenada + pendiente*sin_canarias_bebidas_bio["%refrescos bio"], 'r', label='fitted line')
plt.xlabel("%refrescos bio")
plt.ylabel("diabetes")
plt.legend()

#refrescos y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(sin_canarias_bebidas_bio["%refrescos bio"],sin_canarias_bebidas_bio["colesterol"])
plt.subplot(223)
plt.plot(sin_canarias_bebidas_bio["%refrescos bio"], sin_canarias_bebidas_bio["colesterol"], 'o', label='original data')
plt.plot(sin_canarias_bebidas_bio["%refrescos bio"], ordenada + pendiente*sin_canarias_bebidas_bio["%refrescos bio"], 'r', label='fitted line')
plt.xlabel("%refrescos bio")
plt.ylabel("colesterol")
plt.legend()

#refrescos y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(sin_canarias_bebidas_bio["%refrescos bio"],sin_canarias_bebidas_bio["obesidad"])
plt.subplot(224)
plt.plot(sin_canarias_bebidas_bio["%refrescos bio"], sin_canarias_bebidas_bio["obesidad"], 'o', label='original data')
plt.plot(sin_canarias_bebidas_bio["%refrescos bio"], ordenada + pendiente*sin_canarias_bebidas_bio["%refrescos bio"], 'r', label='fitted line')
plt.xlabel("%refrescos bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.27577216522588655
# p_value colesterol:  0.2320601088210896
# p_value diabetes:  0.19889661239187745
# p_value obesidad:  0.08526937615540653

# %%
#cerveza e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%cerveza bio"],bebidas_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%cerveza bio"], bebidas_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%cerveza bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%cerveza bio"], 'r', label='fitted line')
plt.xlabel("%cerveza bio")
plt.ylabel("hipertension")
plt.legend()

#cerveza y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%cerveza bio"],bebidas_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%cerveza bio"], bebidas_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%cerveza bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%cerveza bio"], 'r', label='fitted line')
plt.xlabel("%cerveza bio")
plt.ylabel("diabetes")
plt.legend()

#cerveza y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%cerveza bio"],bebidas_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%cerveza bio"], bebidas_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%cerveza bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%cerveza bio"], 'r', label='fitted line')
plt.xlabel("%cerveza bio")
plt.ylabel("colesterol")
plt.legend()

#cerveza y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%cerveza bio"],bebidas_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%cerveza bio"], bebidas_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%cerveza bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%cerveza bio"], 'r', label='fitted line')
plt.xlabel("%cerveza bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.31327560203186106
# p_value colesterol:  0.5685000002022853
# p_value diabetes:  0.0627298108685849
# p_value obesidad:  0.08799491923218755

# %%
#espumosos e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%espumosos bio"],bebidas_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%espumosos bio"], bebidas_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%espumosos bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%espumosos bio"], 'r', label='fitted line')
plt.xlabel("%espumosos bio")
plt.ylabel("hipertension")
plt.legend()

#espumosos y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%espumosos bio"],bebidas_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%espumosos bio"], bebidas_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%espumosos bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%espumosos bio"], 'r', label='fitted line')
plt.xlabel("%espumosos bio")
plt.ylabel("diabetes")
plt.legend()

#espumosos y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%espumosos bio"],bebidas_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%espumosos bio"], bebidas_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%espumosos bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%espumosos bio"], 'r', label='fitted line')
plt.xlabel("%espumosos bio")
plt.ylabel("colesterol")
plt.legend()

#espumosos y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%espumosos bio"],bebidas_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%espumosos bio"], bebidas_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%espumosos bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%espumosos bio"], 'r', label='fitted line')
plt.xlabel("%espumosos bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.21902449209723693
# p_value colesterol:  0.0035081139090154647
# p_value diabetes:  0.430001656151642
# p_value obesidad:  0.7969158907687726

# %%
#Miro cual es la CA con mayor %gasto en refrescos
bebidas_categorias_bio_vs_enfermedades.loc[:,('comunidades',"%refrescos bio")].sort_values(by=['%refrescos bio'])
# Out:
#            comunidades  %refrescos bio
# 9            Catalunya        0.000022
# 3             Baleares        0.000025
# 15              Murcia        0.000031
# 4         C_Valenciana        0.000041
# 12             Galicia        0.000043
# 1               Aragon        0.000043
# 13            La_Rioja        0.000044
# 7   Castilla_La_Mancha        0.000051
# 14              Madrid        0.000057
# 6            Cantabria        0.000061
# 11         Extremadura        0.000066
# 0            Andalucia        0.000075
# 8        Castilla_Leon        0.000086
# 17          Pais_Vasco        0.000092
# 10       Ceuta_Melilla        0.000158
# 16             Navarra        0.000184
# 2             Asturias        0.000509
# 5             Canarias        0.001494

# %%
#elimino Galicia
sin_galicia_bebidas_bio=bebidas_categorias_bio_vs_enfermedades.drop(bebidas_categorias_bio_vs_enfermedades[bebidas_categorias_bio_vs_enfermedades['comunidades']=='Galicia'].index)

# %%
#espumosos e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(sin_galicia_bebidas_bio["%espumosos bio"],sin_galicia_bebidas_bio["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(sin_galicia_bebidas_bio["%espumosos bio"], sin_galicia_bebidas_bio["hipertension"], 'o', label='original data')
plt.plot(sin_galicia_bebidas_bio["%espumosos bio"], ordenada + pendiente*sin_galicia_bebidas_bio["%espumosos bio"], 'r', label='fitted line')
plt.xlabel("%espumosos bio")
plt.ylabel("hipertension")
plt.legend()

#espumosos y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(sin_galicia_bebidas_bio["%espumosos bio"],sin_galicia_bebidas_bio["diabetes"])
plt.subplot(222)
plt.plot(sin_galicia_bebidas_bio["%espumosos bio"], sin_galicia_bebidas_bio["diabetes"], 'o', label='original data')
plt.plot(sin_galicia_bebidas_bio["%espumosos bio"], ordenada + pendiente*sin_galicia_bebidas_bio["%espumosos bio"], 'r', label='fitted line')
plt.xlabel("%espumosos bio")
plt.ylabel("diabetes")
plt.legend()

#espumosos y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(sin_galicia_bebidas_bio["%espumosos bio"],sin_galicia_bebidas_bio["colesterol"])
plt.subplot(223)
plt.plot(sin_galicia_bebidas_bio["%espumosos bio"], sin_galicia_bebidas_bio["colesterol"], 'o', label='original data')
plt.plot(sin_galicia_bebidas_bio["%espumosos bio"], ordenada + pendiente*sin_galicia_bebidas_bio["%espumosos bio"], 'r', label='fitted line')
plt.xlabel("%espumosos bio")
plt.ylabel("colesterol")
plt.legend()

#espumosos y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(sin_galicia_bebidas_bio["%espumosos bio"],sin_galicia_bebidas_bio["obesidad"])
plt.subplot(224)
plt.plot(sin_galicia_bebidas_bio["%espumosos bio"], sin_galicia_bebidas_bio["obesidad"], 'o', label='original data')
plt.plot(sin_galicia_bebidas_bio["%espumosos bio"], ordenada + pendiente*sin_galicia_bebidas_bio["%espumosos bio"], 'r', label='fitted line')
plt.xlabel("%espumosos bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.6882812948750725
# p_value colesterol:  0.8271399358128564
# p_value diabetes:  0.6363210941152185
# p_value obesidad:  0.11525445650647069

# %%
#zumos e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%zumos bio"],bebidas_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%zumos bio"], bebidas_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%zumos bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%zumos bio"], 'r', label='fitted line')
plt.xlabel("%zumos bio")
plt.ylabel("hipertension")
plt.legend()

#zumos y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%zumos bio"],bebidas_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%zumos bio"], bebidas_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%zumos bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%zumos bio"], 'r', label='fitted line')
plt.xlabel("%zumos bio")
plt.ylabel("diabetes")
plt.legend()

#zumos y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%zumos bio"],bebidas_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%zumos bio"], bebidas_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%zumos bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%zumos bio"], 'r', label='fitted line')
plt.xlabel("%zumos bio")
plt.ylabel("colesterol")
plt.legend()

#zumos y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(bebidas_categorias_bio_vs_enfermedades["%zumos bio"],bebidas_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(bebidas_categorias_bio_vs_enfermedades["%zumos bio"], bebidas_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(bebidas_categorias_bio_vs_enfermedades["%zumos bio"], ordenada + pendiente*bebidas_categorias_bio_vs_enfermedades["%zumos bio"], 'r', label='fitted line')
plt.xlabel("%zumos bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.05837306563980888
# p_value colesterol:  0.42619981496790293
# p_value diabetes:  0.11283374673622193
# p_value obesidad:  0.04729726320317788

# %%
#elimino Galicia
sin_pais_vasco_bebidas_bio=bebidas_categorias_bio_vs_enfermedades.drop(bebidas_categorias_bio_vs_enfermedades[bebidas_categorias_bio_vs_enfermedades['comunidades']=='Pais_Vasco'].index)

# %% [markdown]
# ### CONSERVAS

# %%
#Matriz de correlacion de las categorías de CONSERVAS
conservas_categorias_bio_vs_enfermedades=pd.DataFrame({'comunidades':comunidades,'%aceitunas bio' :conservas_categorias['%aceitunas bio'],'%conservas carne bio': conservas_categorias['%conservas carne bio'], '%conservas frutas y dulces bio':conservas_categorias['%conservas frutas y dulces bio'], '%conservas pescado bio':conservas_categorias['%conservas pescado bio'], '%conservas vegetales bio':conservas_categorias['%conservas vegetales bio'], '%platos preparados bio':conservas_categorias['%platos preparados bio'], 'hipertension': hipertension_p, 'diabetes': diabetes_p, 'colesterol': colesterol_p, 'obesidad':obesidad_p})
conservas_categorias_bio_vs_enfermedades

plt.figure(figsize=(10, 5))
conservas_categorias_bio_vs_enfermedades_cor = conservas_categorias_bio_vs_enfermedades.corr()
sns.heatmap(conservas_categorias_bio_vs_enfermedades_cor, 
            annot=True,
            xticklabels=conservas_categorias_bio_vs_enfermedades_cor.columns.values,
            yticklabels=conservas_categorias_bio_vs_enfermedades_cor.columns.values)

# %%
#aceitunas e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%aceitunas bio"],conservas_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(conservas_categorias_bio_vs_enfermedades["%aceitunas bio"], conservas_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%aceitunas bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%aceitunas bio"], 'r', label='fitted line')
plt.xlabel("%aceitunas bio")
plt.ylabel("hipertension")
plt.legend()

#aceitunas y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%aceitunas bio"],conservas_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(conservas_categorias_bio_vs_enfermedades["%aceitunas bio"], conservas_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%aceitunas bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%aceitunas bio"], 'r', label='fitted line')
plt.xlabel("%aceitunas bio")
plt.ylabel("diabetes")
plt.legend()

#aceitunas y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%aceitunas bio"],conservas_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(conservas_categorias_bio_vs_enfermedades["%aceitunas bio"], conservas_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%aceitunas bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%aceitunas bio"], 'r', label='fitted line')
plt.xlabel("%aceitunas bio")
plt.ylabel("colesterol")
plt.legend()

#aceitunas y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%aceitunas bio"],conservas_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(conservas_categorias_bio_vs_enfermedades["%aceitunas bio"], conservas_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%aceitunas bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%aceitunas bio"], 'r', label='fitted line')
plt.xlabel("%aceitunas bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.000892098777237811
# p_value colesterol:  0.1928027185724848
# p_value diabetes:  0.052416857928209694
# p_value obesidad:  0.27699983245532817

# %%
#Miro cual es la CA con mayor %gasto en aceitunas
conservas_categorias_bio_vs_enfermedades.loc[:,('comunidades',"%aceitunas bio")].sort_values(by=['%aceitunas bio'])
# Out:
#            comunidades  %aceitunas bio
# 11         Extremadura        0.000005
# 7   Castilla_La_Mancha        0.000005
# 8        Castilla_Leon        0.000009
# 15              Murcia        0.000010
# 6            Cantabria        0.000011
# 4         C_Valenciana        0.000011
# 16             Navarra        0.000012
# 1               Aragon        0.000012
# 12             Galicia        0.000013
# 0            Andalucia        0.000013
# 5             Canarias        0.000014
# 2             Asturias        0.000015
# 9            Catalunya        0.000016
# 14              Madrid        0.000018
# 13            La_Rioja        0.000018
# 10       Ceuta_Melilla        0.000018
# 17          Pais_Vasco        0.000021
# 3             Baleares        0.000031

# %%
#elimino Galicia
sin_baleares_conservas_bio=conservas_categorias_bio_vs_enfermedades.drop(conservas_categorias_bio_vs_enfermedades[conservas_categorias_bio_vs_enfermedades['comunidades']=='Baleares'].index)

# %%
#aceitunas e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(sin_baleares_conservas_bio["%aceitunas bio"],sin_baleares_conservas_bio["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(sin_baleares_conservas_bio["%aceitunas bio"], sin_baleares_conservas_bio["hipertension"], 'o', label='original data')
plt.plot(sin_baleares_conservas_bio["%aceitunas bio"], ordenada + pendiente*sin_baleares_conservas_bio["%aceitunas bio"], 'r', label='fitted line')
plt.xlabel("%aceitunas bio")
plt.ylabel("hipertension")
plt.legend()

#aceitunas y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(sin_baleares_conservas_bio["%aceitunas bio"],sin_baleares_conservas_bio["diabetes"])
plt.subplot(222)
plt.plot(sin_baleares_conservas_bio["%aceitunas bio"], sin_baleares_conservas_bio["diabetes"], 'o', label='original data')
plt.plot(sin_baleares_conservas_bio["%aceitunas bio"], ordenada + pendiente*sin_baleares_conservas_bio["%aceitunas bio"], 'r', label='fitted line')
plt.xlabel("%aceitunas bio")
plt.ylabel("diabetes")
plt.legend()

#aceitunas y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(sin_baleares_conservas_bio["%aceitunas bio"],sin_baleares_conservas_bio["colesterol"])
plt.subplot(223)
plt.plot(sin_baleares_conservas_bio["%aceitunas bio"], sin_baleares_conservas_bio["colesterol"], 'o', label='original data')
plt.plot(sin_baleares_conservas_bio["%aceitunas bio"], ordenada + pendiente*sin_baleares_conservas_bio["%aceitunas bio"], 'r', label='fitted line')
plt.xlabel("%aceitunas bio")
plt.ylabel("colesterol")
plt.legend()

#aceitunas y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(sin_baleares_conservas_bio["%aceitunas bio"],sin_baleares_conservas_bio["obesidad"])
plt.subplot(224)
plt.plot(sin_baleares_conservas_bio["%aceitunas bio"], sin_baleares_conservas_bio["obesidad"], 'o', label='original data')
plt.plot(sin_baleares_conservas_bio["%aceitunas bio"], ordenada + pendiente*sin_baleares_conservas_bio["%aceitunas bio"], 'r', label='fitted line')
plt.xlabel("%aceitunas bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.11582248669023143
# p_value colesterol:  0.915030955269277
# p_value diabetes:  0.4251207594693971
# p_value obesidad:  0.42057126698378566

# %%
#conservas carne e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%conservas carne bio"],conservas_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas carne bio"], conservas_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas carne bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%conservas carne bio"], 'r', label='fitted line')
plt.xlabel("%conservas carne bio")
plt.ylabel("hipertension")
plt.legend()

#conservas carne y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%conservas carne bio"],conservas_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas carne bio"], conservas_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas carne bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%conservas carne bio"], 'r', label='fitted line')
plt.xlabel("%conservas carne bio")
plt.ylabel("diabetes")
plt.legend()

#conservas carne y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%conservas carne bio"],conservas_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas carne bio"], conservas_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas carne bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%conservas carne bio"], 'r', label='fitted line')
plt.xlabel("%conservas carne bio")
plt.ylabel("colesterol")
plt.legend()

#conservas carne y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%conservas carne bio"],conservas_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas carne bio"], conservas_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas carne bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%conservas carne bio"], 'r', label='fitted line')
plt.xlabel("%conservas carne bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.008452009898004249
# p_value colesterol:  0.105845023031968
# p_value diabetes:  0.16340001850819522
# p_value obesidad:  0.07910667348905433

# %%
#Miro cual es la CA con mayor %gasto en conservas carne
conservas_categorias_bio_vs_enfermedades.loc[:,('comunidades',"%conservas carne bio")].sort_values(by=['%conservas carne bio'])
# Out:
#            comunidades  %conservas carne bio
# 7   Castilla_La_Mancha              0.000003
# 11         Extremadura              0.000004
# 12             Galicia              0.000004
# 4         C_Valenciana              0.000004
# 8        Castilla_Leon              0.000004
# 0            Andalucia              0.000004
# 6            Cantabria              0.000007
# 15              Murcia              0.000007
# 2             Asturias              0.000008
# 10       Ceuta_Melilla              0.000008
# 14              Madrid              0.000008
# 13            La_Rioja              0.000011
# 9            Catalunya              0.000011
# 1               Aragon              0.000016
# 16             Navarra              0.000019
# 5             Canarias              0.000020
# 17          Pais_Vasco              0.000028
# 3             Baleares              0.000038

# %%
#SIN BALEARES
#conservas carne e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(sin_baleares_conservas_bio["%conservas carne bio"],sin_baleares_conservas_bio["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(sin_baleares_conservas_bio["%conservas carne bio"], sin_baleares_conservas_bio["hipertension"], 'o', label='original data')
plt.plot(sin_baleares_conservas_bio["%conservas carne bio"], ordenada + pendiente*sin_baleares_conservas_bio["%conservas carne bio"], 'r', label='fitted line')
plt.xlabel("%conservas carne bio")
plt.ylabel("hipertension")
plt.legend()

#conservas carne y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(sin_baleares_conservas_bio["%conservas carne bio"],sin_baleares_conservas_bio["diabetes"])
plt.subplot(222)
plt.plot(sin_baleares_conservas_bio["%conservas carne bio"], sin_baleares_conservas_bio["diabetes"], 'o', label='original data')
plt.plot(sin_baleares_conservas_bio["%conservas carne bio"], ordenada + pendiente*sin_baleares_conservas_bio["%conservas carne bio"], 'r', label='fitted line')
plt.xlabel("%conservas carne bio")
plt.ylabel("diabetes")
plt.legend()

#conservas carne y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(sin_baleares_conservas_bio["%conservas carne bio"],sin_baleares_conservas_bio["colesterol"])
plt.subplot(223)
plt.plot(sin_baleares_conservas_bio["%conservas carne bio"], sin_baleares_conservas_bio["colesterol"], 'o', label='original data')
plt.plot(sin_baleares_conservas_bio["%conservas carne bio"], ordenada + pendiente*sin_baleares_conservas_bio["%conservas carne bio"], 'r', label='fitted line')
plt.xlabel("%conservas carne bio")
plt.ylabel("colesterol")
plt.legend()

#conservas carne y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(sin_baleares_conservas_bio["%conservas carne bio"],sin_baleares_conservas_bio["obesidad"])
plt.subplot(224)
plt.plot(sin_baleares_conservas_bio["%conservas carne bio"], sin_baleares_conservas_bio["obesidad"], 'o', label='original data')
plt.plot(sin_baleares_conservas_bio["%conservas carne bio"], ordenada + pendiente*sin_baleares_conservas_bio["%conservas carne bio"], 'r', label='fitted line')
plt.xlabel("%conservas carne bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.6013913467147348
# p_value colesterol:  0.7616497418291929
# p_value diabetes:  0.9690388799093939
# p_value obesidad:  0.08779868848644884

# %%
#conservas pescado e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"],conservas_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"], conservas_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"], 'r', label='fitted line')
plt.xlabel("%conservas pescado bio")
plt.ylabel("hipertension")
plt.legend()

#conservas pescado y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"],conservas_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"], conservas_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"], 'r', label='fitted line')
plt.xlabel("%conservas pescado bio")
plt.ylabel("diabetes")
plt.legend()

#conservas pescado y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"],conservas_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"], conservas_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"], 'r', label='fitted line')
plt.xlabel("%conservas pescado bio")
plt.ylabel("colesterol")
plt.legend()

#conservas pescado y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"],conservas_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"], conservas_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%conservas pescado bio"], 'r', label='fitted line')
plt.xlabel("%conservas pescado bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.3083763761333508
# p_value colesterol:  0.18452911025330926
# p_value diabetes:  0.3097240376810631
# p_value obesidad:  0.03246611228556705

# %%
#platos preparados e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%platos preparados bio"],conservas_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(conservas_categorias_bio_vs_enfermedades["%platos preparados bio"], conservas_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%platos preparados bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%platos preparados bio"], 'r', label='fitted line')
plt.xlabel("%platos preparados bio")
plt.ylabel("hipertension")
plt.legend()

#platos preparados y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%platos preparados bio"],conservas_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(conservas_categorias_bio_vs_enfermedades["%platos preparados bio"], conservas_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%platos preparados bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%platos preparados bio"], 'r', label='fitted line')
plt.xlabel("%platos preparados bio")
plt.ylabel("diabetes")
plt.legend()

#platos preparados y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%platos preparados bio"],conservas_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(conservas_categorias_bio_vs_enfermedades["%platos preparados bio"], conservas_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%platos preparados bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%platos preparados bio"], 'r', label='fitted line')
plt.xlabel("%platos preparados bio")
plt.ylabel("colesterol")
plt.legend()

#platos preparados y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(conservas_categorias_bio_vs_enfermedades["%platos preparados bio"],conservas_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(conservas_categorias_bio_vs_enfermedades["%platos preparados bio"], conservas_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(conservas_categorias_bio_vs_enfermedades["%platos preparados bio"], ordenada + pendiente*conservas_categorias_bio_vs_enfermedades["%platos preparados bio"], 'r', label='fitted line')
plt.xlabel("%platos preparados bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.15842476561746693
# p_value colesterol:  0.6344096915031308
# p_value diabetes:  0.010692229511444154
# p_value obesidad:  0.012458819512559184

# %% [markdown]
# ### LECHE Y BATIDOS

# %%
#Matriz de correlacion de las categorías de LECHE Y BATIDOS
leche_batidos_categorias_bio_vs_enfermedades=pd.DataFrame({'comunidades':comunidades,'%batidos bio':leche_batidos_categorias['%batidos bio'],'%horchata bio': leche_batidos_categorias['%horchata bio'], '%leche liquida bio':leche_batidos_categorias['%leche liquida bio'], 'hipertension': hipertension_p, 'diabetes': diabetes_p, 'colesterol': colesterol_p, 'obesidad':obesidad_p})
leche_batidos_categorias_bio_vs_enfermedades

plt.figure(figsize=(10, 5))
leche_batidos_categorias_bio_vs_enfermedades_cor = leche_batidos_categorias_bio_vs_enfermedades.corr()
sns.heatmap(leche_batidos_categorias_bio_vs_enfermedades_cor, 
            annot=True,
            xticklabels=leche_batidos_categorias_bio_vs_enfermedades_cor.columns.values,
            yticklabels=leche_batidos_categorias_bio_vs_enfermedades_cor.columns.values)

# %%
#batidos e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"],leche_batidos_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"], leche_batidos_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"], ordenada + pendiente*leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"], 'r', label='fitted line')
plt.xlabel("%batidos bio")
plt.ylabel("hipertension")
plt.legend()

#batidos y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"],leche_batidos_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"], leche_batidos_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"], ordenada + pendiente*leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"], 'r', label='fitted line')
plt.xlabel("%batidos bio")
plt.ylabel("diabetes")
plt.legend()

#batidos y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"],leche_batidos_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"], leche_batidos_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"], ordenada + pendiente*leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"], 'r', label='fitted line')
plt.xlabel("%batidos bio")
plt.ylabel("colesterol")
plt.legend()

#batidos y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"],leche_batidos_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"], leche_batidos_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"], ordenada + pendiente*leche_batidos_categorias_bio_vs_enfermedades["%batidos bio"], 'r', label='fitted line')
plt.xlabel("%batidos bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.8779554371394078
# p_value colesterol:  0.47446624933314885
# p_value diabetes:  0.2938417215902845
# p_value obesidad:  0.015748742052169872

# %%
#Miro cual es la CA con mayor %gasto en batidos
leche_batidos_categorias_bio_vs_enfermedades.loc[:,('comunidades',"%batidos bio")].sort_values(by=['%batidos bio'])
# Out:
#            comunidades  %batidos bio
# 11         Extremadura      0.000008
# 7   Castilla_La_Mancha      0.000015
# 10       Ceuta_Melilla      0.000015
# 0            Andalucia      0.000021
# 4         C_Valenciana      0.000022
# 8        Castilla_Leon      0.000024
# 2             Asturias      0.000029
# 13            La_Rioja      0.000034
# 15              Murcia      0.000034
# 5             Canarias      0.000040
# 6            Cantabria      0.000043
# 1               Aragon      0.000045
# 14              Madrid      0.000047
# 9            Catalunya      0.000066
# 3             Baleares      0.000071
# 12             Galicia      0.000078
# 16             Navarra      0.000083
# 17          Pais_Vasco      0.000142

# %%
#horchata e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"],leche_batidos_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"], leche_batidos_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"], ordenada + pendiente*leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"], 'r', label='fitted line')
plt.xlabel("%horchata bio")
plt.ylabel("hipertension")
plt.legend()

#horchata y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"],leche_batidos_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"], leche_batidos_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"], ordenada + pendiente*leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"], 'r', label='fitted line')
plt.xlabel("%horchata bio")
plt.ylabel("diabetes")
plt.legend()

#horchata y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"],leche_batidos_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"], leche_batidos_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"], ordenada + pendiente*leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"], 'r', label='fitted line')
plt.xlabel("%horchata bio")
plt.ylabel("colesterol")
plt.legend()

#horchata y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"],leche_batidos_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"], leche_batidos_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"], ordenada + pendiente*leche_batidos_categorias_bio_vs_enfermedades["%horchata bio"], 'r', label='fitted line')
plt.xlabel("%horchata bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.2553185744797728
# p_value colesterol:  0.20673889059535527
# p_value diabetes:  0.07214588278734216
# p_value obesidad:  0.12293645871978133

# %%
#leche liquida e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"],leche_batidos_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"], leche_batidos_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"], ordenada + pendiente*leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"], 'r', label='fitted line')
plt.xlabel("%leche liquida bio")
plt.ylabel("hipertension")
plt.legend()

#leche liquida y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"],leche_batidos_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"], leche_batidos_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"], ordenada + pendiente*leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"], 'r', label='fitted line')
plt.xlabel("%leche liquida bio")
plt.ylabel("diabetes")
plt.legend()

#leche liquida y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"],leche_batidos_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"], leche_batidos_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"], ordenada + pendiente*leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"], 'r', label='fitted line')
plt.xlabel("%leche liquida bio")
plt.ylabel("colesterol")
plt.legend()

#leche liquida y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"],leche_batidos_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"], leche_batidos_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"], ordenada + pendiente*leche_batidos_categorias_bio_vs_enfermedades["%leche liquida bio"], 'r', label='fitted line')
plt.xlabel("%leche liquida bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.31705097448571196
# p_value colesterol:  0.6965602883563089
# p_value diabetes:  0.03472695146585117
# p_value obesidad:  0.00234777815631871

# %% [markdown]
# ### CHARCUTERIA

# %%
#Matriz de correlacion de las categorías de CHARCUTERIA
## SIN SALAZONES, SOBRASADA NI SALCHICHAS

charcuteria_categorias_bio_vs_enfermedades=pd.DataFrame({'comunidades':comunidades,'%ahumados bio':charcuteria_categorias['ahumados bio'],'%charcuteria bio': charcuteria_categorias['%charcuteria bio'], '%pates refrigerados bio':charcuteria_categorias['pates refrigerados bio'], 'hipertension': hipertension_p, 'diabetes': diabetes_p, 'colesterol': colesterol_p, 'obesidad':obesidad_p})
charcuteria_categorias_bio_vs_enfermedades

plt.figure(figsize=(10, 5))
charcuteria_categorias_bio_vs_enfermedades_cor = charcuteria_categorias_bio_vs_enfermedades.corr()
sns.heatmap(charcuteria_categorias_bio_vs_enfermedades_cor, 
            annot=True,
            xticklabels=charcuteria_categorias_bio_vs_enfermedades_cor.columns.values,
            yticklabels=charcuteria_categorias_bio_vs_enfermedades_cor.columns.values)

# %%
#charcuteria e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"],charcuteria_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"], charcuteria_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"], ordenada + pendiente*charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"], 'r', label='fitted line')
plt.xlabel("%charcuteria bio")
plt.ylabel("hipertension")
plt.legend()

#charcuteria y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"],charcuteria_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"], charcuteria_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"], ordenada + pendiente*charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"], 'r', label='fitted line')
plt.xlabel("%charcuteria bio")
plt.ylabel("diabetes")
plt.legend()

#charcuteria y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"],charcuteria_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"], charcuteria_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"], ordenada + pendiente*charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"], 'r', label='fitted line')
plt.xlabel("%charcuteria bio")
plt.ylabel("colesterol")
plt.legend()

#charcuteria y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"],charcuteria_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"], charcuteria_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"], ordenada + pendiente*charcuteria_categorias_bio_vs_enfermedades["%charcuteria bio"], 'r', label='fitted line')
plt.xlabel("%charcuteria bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.4937212240875617
# p_value colesterol:  0.7675008492218673
# p_value diabetes:  0.03595928623201006
# p_value obesidad:  0.732059351619234

# %% [markdown]
# ### CONGELADOS

# %%
#Matriz de correlacion de las categorías de CONGELADOS
## SIN HELADOS; OTROS CONGELADOS, VERDURAS CONGELADAS NI PESCADOS PREPARADOS

congelados_categorias_bio_vs_enfermedades=pd.DataFrame({'comunidades':comunidades, '%pescados bio':congelados_categorias['%pescados bio'], '%platos prep congelados bio':congelados_categorias['%platos prep congelados bio'], 'hipertension': hipertension_p, 'diabetes': diabetes_p, 'colesterol': colesterol_p, 'obesidad':obesidad_p})
congelados_categorias_bio_vs_enfermedades


plt.figure(figsize=(10, 5))
congelados_categorias_bio_vs_enfermedades_cor = congelados_categorias_bio_vs_enfermedades.corr()
sns.heatmap(congelados_categorias_bio_vs_enfermedades_cor, 
            annot=True,
            xticklabels=congelados_categorias_bio_vs_enfermedades_cor.columns.values,
            yticklabels=congelados_categorias_bio_vs_enfermedades_cor.columns.values)

# %%
#pescados e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(congelados_categorias_bio_vs_enfermedades["%pescados bio"],congelados_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(congelados_categorias_bio_vs_enfermedades["%pescados bio"], congelados_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(congelados_categorias_bio_vs_enfermedades["%pescados bio"], ordenada + pendiente*congelados_categorias_bio_vs_enfermedades["%pescados bio"], 'r', label='fitted line')
plt.xlabel("%pescados bio")
plt.ylabel("hipertension")
plt.legend()

#pescados y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(congelados_categorias_bio_vs_enfermedades["%pescados bio"],congelados_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(congelados_categorias_bio_vs_enfermedades["%pescados bio"], congelados_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(congelados_categorias_bio_vs_enfermedades["%pescados bio"], ordenada + pendiente*congelados_categorias_bio_vs_enfermedades["%pescados bio"], 'r', label='fitted line')
plt.xlabel("%pescados bio")
plt.ylabel("diabetes")
plt.legend()

#pescados y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(congelados_categorias_bio_vs_enfermedades["%pescados bio"],congelados_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(congelados_categorias_bio_vs_enfermedades["%pescados bio"], congelados_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(congelados_categorias_bio_vs_enfermedades["%pescados bio"], ordenada + pendiente*congelados_categorias_bio_vs_enfermedades["%pescados bio"], 'r', label='fitted line')
plt.xlabel("%pescados bio")
plt.ylabel("colesterol")
plt.legend()

#pescados y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(congelados_categorias_bio_vs_enfermedades["%pescados bio"],congelados_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(congelados_categorias_bio_vs_enfermedades["%pescados bio"], congelados_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(congelados_categorias_bio_vs_enfermedades["%pescados bio"], ordenada + pendiente*congelados_categorias_bio_vs_enfermedades["%pescados bio"], 'r', label='fitted line')
plt.xlabel("%pescados bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.3585488830245891
# p_value colesterol:  0.03013195675143016
# p_value diabetes:  0.29395111155093245
# p_value obesidad:  0.6170632733850434

# %% [markdown]
# ### DERIVADOS LACTEOS

# %%
#Matriz de correlacion de las categorías de DERIVADOS LACTEOS
##SIN MARGARINA NI QUESOS PETIT

derv_lacteos_categorias_bio_vs_enfermedades=pd.DataFrame({'comunidades':comunidades,'%mantequilla bio':derv_lacteos_categorias['%mantequilla bio'], '%nata bio':derv_lacteos_categorias['%nata bio'], '%postres preparados bio':derv_lacteos_categorias['%postres preparados bio'], '%yogures bio':derv_lacteos_categorias['%yogures bio'], 'hipertension': hipertension_p, 'diabetes': diabetes_p, 'colesterol': colesterol_p, 'obesidad':obesidad_p})
derv_lacteos_categorias_bio_vs_enfermedades

plt.figure(figsize=(10, 5))
derv_lacteos_categorias_bio_vs_enfermedades_cor = derv_lacteos_categorias_bio_vs_enfermedades.corr()
sns.heatmap(derv_lacteos_categorias_bio_vs_enfermedades_cor, 
            annot=True,
            xticklabels=derv_lacteos_categorias_bio_vs_enfermedades_cor.columns.values,
            yticklabels=derv_lacteos_categorias_bio_vs_enfermedades_cor.columns.values)

# %%
#mantequilla e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"],derv_lacteos_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"], derv_lacteos_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"], 'r', label='fitted line')
plt.xlabel("%mantequilla bio")
plt.ylabel("hipertension")
plt.legend()

#mantequilla y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"],derv_lacteos_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"], derv_lacteos_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"], 'r', label='fitted line')
plt.xlabel("%mantequilla bio")
plt.ylabel("diabetes")
plt.legend()

#mantequilla y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"],derv_lacteos_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"], derv_lacteos_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"], 'r', label='fitted line')
plt.xlabel("%mantequilla bio")
plt.ylabel("colesterol")
plt.legend()

#mantequilla y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"],derv_lacteos_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"], derv_lacteos_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%mantequilla bio"], 'r', label='fitted line')
plt.xlabel("%mantequilla bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.2506798510389957
# p_value colesterol:  0.6111904788795788
# p_value diabetes:  0.05845302930730144
# p_value obesidad:  0.06114055334037929

# %%
#nata e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"],derv_lacteos_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"], derv_lacteos_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"], 'r', label='fitted line')
plt.xlabel("%nata bio")
plt.ylabel("hipertension")
plt.legend()

#nata y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"],derv_lacteos_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"], derv_lacteos_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"], 'r', label='fitted line')
plt.xlabel("%nata bio")
plt.ylabel("diabetes")
plt.legend()

#nata y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"],derv_lacteos_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"], derv_lacteos_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"], 'r', label='fitted line')
plt.xlabel("%nata bio")
plt.ylabel("colesterol")
plt.legend()

#nata y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"],derv_lacteos_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"], derv_lacteos_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%nata bio"], 'r', label='fitted line')
plt.xlabel("%nata bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.026455835489199057
# p_value colesterol:  0.08876551996516886
# p_value diabetes:  0.7670473745437993
# p_value obesidad:  0.2756843964910236

# %%
#postres preparados e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"],derv_lacteos_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"], derv_lacteos_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"], 'r', label='fitted line')
plt.xlabel("%postres preparados bio")
plt.ylabel("hipertension")
plt.legend()

#postres preparados y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"],derv_lacteos_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"], derv_lacteos_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"], 'r', label='fitted line')
plt.xlabel("%postres preparados bio")
plt.ylabel("diabetes")
plt.legend()

#postres preparados y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"],derv_lacteos_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"], derv_lacteos_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"], 'r', label='fitted line')
plt.xlabel("%postres preparados bio")
plt.ylabel("colesterol")
plt.legend()

#postres preparados y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"],derv_lacteos_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"], derv_lacteos_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%postres preparados bio"], 'r', label='fitted line')
plt.xlabel("%postres preparados bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.4985748016039754
# p_value colesterol:  0.01905848421927284
# p_value diabetes:  0.5229973930763758
# p_value obesidad:  0.18631999830541535

# %%
#Miro cual es la CA con mayor %gasto en conservas carne
derv_lacteos_categorias_bio_vs_enfermedades.loc[:,('comunidades',"%postres preparados bio")].sort_values(by=['%postres preparados bio'])
# Out:
#            comunidades  %postres preparados bio
# 10       Ceuta_Melilla                 0.000005
# 11         Extremadura                 0.000009
# 7   Castilla_La_Mancha                 0.000009
# 5             Canarias                 0.000011
# 0            Andalucia                 0.000012
# 8        Castilla_Leon                 0.000018
# 4         C_Valenciana                 0.000020
# 15              Murcia                 0.000020
# 13            La_Rioja                 0.000022
# 1               Aragon                 0.000026
# 16             Navarra                 0.000027
# 6            Cantabria                 0.000027
# 9            Catalunya                 0.000028
# 2             Asturias                 0.000032
# 14              Madrid                 0.000035
# 3             Baleares                 0.000035
# 17          Pais_Vasco                 0.000038
# 12             Galicia                 0.000070

# %%
#elimino Galicia
sin_galicia_conservas_bio=derv_lacteos_categorias_bio_vs_enfermedades.drop(derv_lacteos_categorias_bio_vs_enfermedades[derv_lacteos_categorias_bio_vs_enfermedades['comunidades']=='Galicia'].index)

# %%
#postres preparados e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(sin_galicia_conservas_bio["%postres preparados bio"],sin_galicia_conservas_bio["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(sin_galicia_conservas_bio["%postres preparados bio"], sin_galicia_conservas_bio["hipertension"], 'o', label='original data')
plt.plot(sin_galicia_conservas_bio["%postres preparados bio"], ordenada + pendiente*sin_galicia_conservas_bio["%postres preparados bio"], 'r', label='fitted line')
plt.xlabel("%postres preparados bio")
plt.ylabel("hipertension")
plt.legend()

#postres preparados y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(sin_galicia_conservas_bio["%postres preparados bio"],sin_galicia_conservas_bio["diabetes"])
plt.subplot(222)
plt.plot(sin_galicia_conservas_bio["%postres preparados bio"], sin_galicia_conservas_bio["diabetes"], 'o', label='original data')
plt.plot(sin_galicia_conservas_bio["%postres preparados bio"], ordenada + pendiente*sin_galicia_conservas_bio["%postres preparados bio"], 'r', label='fitted line')
plt.xlabel("%postres preparados bio")
plt.ylabel("diabetes")
plt.legend()

#postres preparados y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(sin_galicia_conservas_bio["%postres preparados bio"],sin_galicia_conservas_bio["colesterol"])
plt.subplot(223)
plt.plot(sin_galicia_conservas_bio["%postres preparados bio"], sin_galicia_conservas_bio["colesterol"], 'o', label='original data')
plt.plot(sin_galicia_conservas_bio["%postres preparados bio"], ordenada + pendiente*sin_galicia_conservas_bio["%postres preparados bio"], 'r', label='fitted line')
plt.xlabel("%postres preparados bio")
plt.ylabel("colesterol")
plt.legend()

#postres preparados y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(sin_galicia_conservas_bio["%postres preparados bio"],sin_galicia_conservas_bio["obesidad"])
plt.subplot(224)
plt.plot(sin_galicia_conservas_bio["%postres preparados bio"], sin_galicia_conservas_bio["obesidad"], 'o', label='original data')
plt.plot(sin_galicia_conservas_bio["%postres preparados bio"], ordenada + pendiente*sin_galicia_conservas_bio["%postres preparados bio"], 'r', label='fitted line')
plt.xlabel("%postres preparados bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.5181528657700001
# p_value colesterol:  0.784307367798442
# p_value diabetes:  0.019999196593108184
# p_value obesidad:  0.012328893843260623

# %%
#yogures e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"],derv_lacteos_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"], derv_lacteos_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"], 'r', label='fitted line')
plt.xlabel("%yogures bio")
plt.ylabel("hipertension")
plt.legend()

#yogures y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"],derv_lacteos_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"], derv_lacteos_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"], 'r', label='fitted line')
plt.xlabel("%yogures bio")
plt.ylabel("diabetes")
plt.legend()

#yogures y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"],derv_lacteos_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"], derv_lacteos_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"], 'r', label='fitted line')
plt.xlabel("%yogures bio")
plt.ylabel("colesterol")
plt.legend()

#yogures y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"],derv_lacteos_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"], derv_lacteos_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"], ordenada + pendiente*derv_lacteos_categorias_bio_vs_enfermedades["%yogures bio"], 'r', label='fitted line')
plt.xlabel("%yogures bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.238515205296433
# p_value colesterol:  0.0023273117125611454
# p_value diabetes:  0.5302963935527734
# p_value obesidad:  0.5757873987491483

# %%
#Miro cual es la CA con mayor %gasto en conservas carne
derv_lacteos_categorias_bio_vs_enfermedades.loc[:,('comunidades',"%yogures bio")].sort_values(by=['%yogures bio'])
# Out:
#            comunidades  %yogures bio
# 11         Extremadura      0.000185
# 7   Castilla_La_Mancha      0.000198
# 10       Ceuta_Melilla      0.000275
# 0            Andalucia      0.000286
# 15              Murcia      0.000287
# 4         C_Valenciana      0.000348
# 8        Castilla_Leon      0.000354
# 1               Aragon      0.000362
# 6            Cantabria      0.000380
# 13            La_Rioja      0.000404
# 2             Asturias      0.000420
# 3             Baleares      0.000422
# 5             Canarias      0.000454
# 9            Catalunya      0.000508
# 16             Navarra      0.000526
# 14              Madrid      0.000628
# 17          Pais_Vasco      0.000722
# 12             Galicia      0.001746

# %%
#yogures e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(sin_galicia_conservas_bio["%yogures bio"],sin_galicia_conservas_bio["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(sin_galicia_conservas_bio["%yogures bio"], sin_galicia_conservas_bio["hipertension"], 'o', label='original data')
plt.plot(sin_galicia_conservas_bio["%yogures bio"], ordenada + pendiente*sin_galicia_conservas_bio["%yogures bio"], 'r', label='fitted line')
plt.xlabel("%yogures bio")
plt.ylabel("hipertension")
plt.legend()

#yogures y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(sin_galicia_conservas_bio["%yogures bio"],sin_galicia_conservas_bio["diabetes"])
plt.subplot(222)
plt.plot(sin_galicia_conservas_bio["%yogures bio"], sin_galicia_conservas_bio["diabetes"], 'o', label='original data')
plt.plot(sin_galicia_conservas_bio["%yogures bio"], ordenada + pendiente*sin_galicia_conservas_bio["%yogures bio"], 'r', label='fitted line')
plt.xlabel("%yogures bio")
plt.ylabel("diabetes")
plt.legend()

#yogures y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(sin_galicia_conservas_bio["%yogures bio"],sin_galicia_conservas_bio["colesterol"])
plt.subplot(223)
plt.plot(sin_galicia_conservas_bio["%yogures bio"], sin_galicia_conservas_bio["colesterol"], 'o', label='original data')
plt.plot(sin_galicia_conservas_bio["%yogures bio"], ordenada + pendiente*sin_galicia_conservas_bio["%yogures bio"], 'r', label='fitted line')
plt.xlabel("%yogures bio")
plt.ylabel("colesterol")
plt.legend()

#yogures y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(sin_galicia_conservas_bio["%yogures bio"],sin_galicia_conservas_bio["obesidad"])
plt.subplot(224)
plt.plot(sin_galicia_conservas_bio["%yogures bio"], sin_galicia_conservas_bio["obesidad"], 'o', label='original data')
plt.plot(sin_galicia_conservas_bio["%yogures bio"], ordenada + pendiente*sin_galicia_conservas_bio["%yogures bio"], 'r', label='fitted line')
plt.xlabel("%yogures bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.6582593516871467
# p_value colesterol:  0.5539052692983777
# p_value diabetes:  0.4205705912166291
# p_value obesidad:  0.021107441114140545

# %% [markdown]
# ### PRECOCINADOS

# %%
#Matriz de correlacion de las categorías de PRECOCINADOS
precocinados_categorias_bio_vs_enfermedades=pd.DataFrame({'comunidades':comunidades,'%platos prep refrigerados bio':precocinados_categorias['%platos prep refrigerados bio'], 'hipertension': hipertension_p, 'diabetes': diabetes_p, 'colesterol': colesterol_p, 'obesidad':obesidad_p})
precocinados_categorias_bio_vs_enfermedades

plt.figure(figsize=(10, 5))
precocinados_categorias_bio_vs_enfermedades_cor = precocinados_categorias_bio_vs_enfermedades.corr()
sns.heatmap(precocinados_categorias_bio_vs_enfermedades_cor, 
            annot=True,
            xticklabels=precocinados_categorias_bio_vs_enfermedades_cor.columns.values,
            yticklabels=precocinados_categorias_bio_vs_enfermedades_cor.columns.values)

# %%
#platos prep refrigerados e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"],precocinados_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"], precocinados_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"], ordenada + pendiente*precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"], 'r', label='fitted line')
plt.xlabel("%platos prep refrigerados bio")
plt.ylabel("hipertension")
plt.legend()

#platos prep refrigerados y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"],precocinados_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"], precocinados_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"], ordenada + pendiente*precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"], 'r', label='fitted line')
plt.xlabel("%platos prep refrigerados bio")
plt.ylabel("diabetes")
plt.legend()

#platos prep refrigerados y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"],precocinados_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"], precocinados_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"], ordenada + pendiente*precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"], 'r', label='fitted line')
plt.xlabel("%platos prep refrigerados bio")
plt.ylabel("colesterol")
plt.legend()

#platos prep refrigerados y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"],precocinados_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"], precocinados_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"], ordenada + pendiente*precocinados_categorias_bio_vs_enfermedades["%platos prep refrigerados bio"], 'r', label='fitted line')
plt.xlabel("%platos prep refrigerados bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.7490683512989833
# p_value colesterol:  0.7157073370196919
# p_value diabetes:  0.3649220576785579
# p_value obesidad:  0.019906665777088103

# %% [markdown]
# ### QUESOS

# %%
#Matriz de correlacion de las categorías de QUESOS
##SIN REQUESON, QUESO PASTA BLANDA, QUESO FUNDIDO, QUESO RALLADO NI QUESO AZUL
quesos_categorias_bio_vs_enfermedades=pd.DataFrame({'comunidades':comunidades, '%queso bola bio': quesos_categorias['%queso bola bio'], '%queso fresco bio':quesos_categorias['%queso fresco bio'], '%queso tradicional bio':quesos_categorias['%queso tradicional bio'], '%queso blanco past bio':quesos_categorias['%queso blanco past bio'], '%resto quesos bio':quesos_categorias['%resto quesos bio'], 'hipertension': hipertension_p, 'diabetes': diabetes_p, 'colesterol': colesterol_p, 'obesidad':obesidad_p})
quesos_categorias_bio_vs_enfermedades

plt.figure(figsize=(10, 5))
quesos_categorias_bio_vs_enfermedades_cor = quesos_categorias_bio_vs_enfermedades.corr()
sns.heatmap(quesos_categorias_bio_vs_enfermedades_cor, 
            annot=True,
            xticklabels=quesos_categorias_bio_vs_enfermedades_cor.columns.values,
            yticklabels=quesos_categorias_bio_vs_enfermedades_cor.columns.values)

# %%
#queso blanco past e hipertension
pendiente, ordenada, pearson, p_hip, error = ss.linregress(quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"],quesos_categorias_bio_vs_enfermedades["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"], quesos_categorias_bio_vs_enfermedades["hipertension"], 'o', label='original data')
plt.plot(quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"], ordenada + pendiente*quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"], 'r', label='fitted line')
plt.xlabel("%queso blanco past bio")
plt.ylabel("hipertension")
plt.legend()

#queso blanco past y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"],quesos_categorias_bio_vs_enfermedades["diabetes"])
plt.subplot(222)
plt.plot(quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"], quesos_categorias_bio_vs_enfermedades["diabetes"], 'o', label='original data')
plt.plot(quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"], ordenada + pendiente*quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"], 'r', label='fitted line')
plt.xlabel("%queso blanco past bio")
plt.ylabel("diabetes")
plt.legend()

#queso blanco past y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"],quesos_categorias_bio_vs_enfermedades["colesterol"])
plt.subplot(223)
plt.plot(quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"], quesos_categorias_bio_vs_enfermedades["colesterol"], 'o', label='original data')
plt.plot(quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"], ordenada + pendiente*quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"], 'r', label='fitted line')
plt.xlabel("%queso blanco past bio")
plt.ylabel("colesterol")
plt.legend()

#queso blanco past y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"],quesos_categorias_bio_vs_enfermedades["obesidad"])
plt.subplot(224)
plt.plot(quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"], quesos_categorias_bio_vs_enfermedades["obesidad"], 'o', label='original data')
plt.plot(quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"], ordenada + pendiente*quesos_categorias_bio_vs_enfermedades["%queso blanco past bio"], 'r', label='fitted line')
plt.xlabel("%queso blanco past bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.13457684647246432
# p_value colesterol:  0.00048779137222165883
# p_value diabetes:  0.34000148951547093
# p_value obesidad:  0.8781347878373074

# %%
#Miro cual es la CA con mayor %gasto en conservas carne
quesos_categorias_bio_vs_enfermedades.loc[:,('comunidades',"%queso blanco past bio")].sort_values(by=['%queso blanco past bio'])
# Out:
#            comunidades  %queso blanco past bio
# 15              Murcia                0.000002
# 1               Aragon                0.000003
# 10       Ceuta_Melilla                0.000003
# 13            La_Rioja                0.000003
# 4         C_Valenciana                0.000003
# 0            Andalucia                0.000004
# 7   Castilla_La_Mancha                0.000005
# 6            Cantabria                0.000005
# 2             Asturias                0.000005
# 5             Canarias                0.000005
# 9            Catalunya                0.000006
# 3             Baleares                0.000006
# 11         Extremadura                0.000007
# 14              Madrid                0.000009
# 17          Pais_Vasco                0.000009
# 8        Castilla_Leon                0.000012
# 16             Navarra                0.000013
# 12             Galicia                0.000056

# %%
#elimino Galicia
sin_galicia_conservas_bio=quesos_categorias_bio_vs_enfermedades.drop(quesos_categorias_bio_vs_enfermedades[quesos_categorias_bio_vs_enfermedades['comunidades']=='Galicia'].index)

# %%
#queso blanco past e hipertension
#SIN GALICIA
pendiente, ordenada, pearson, p_hip, error = ss.linregress(sin_galicia_conservas_bio["%queso blanco past bio"],sin_galicia_conservas_bio["hipertension"])

plt.figure(figsize=(18,10))
plt.subplot(221)
plt.plot(sin_galicia_conservas_bio["%queso blanco past bio"], sin_galicia_conservas_bio["hipertension"], 'o', label='original data')
plt.plot(sin_galicia_conservas_bio["%queso blanco past bio"], ordenada + pendiente*sin_galicia_conservas_bio["%queso blanco past bio"], 'r', label='fitted line')
plt.xlabel("%queso blanco past bio")
plt.ylabel("hipertension")
plt.legend()

#queso blanco past y diabetes
pendiente, ordenada, pearson, p_diab, error = ss.linregress(sin_galicia_conservas_bio["%queso blanco past bio"],sin_galicia_conservas_bio["diabetes"])
plt.subplot(222)
plt.plot(sin_galicia_conservas_bio["%queso blanco past bio"], sin_galicia_conservas_bio["diabetes"], 'o', label='original data')
plt.plot(sin_galicia_conservas_bio["%queso blanco past bio"], ordenada + pendiente*sin_galicia_conservas_bio["%queso blanco past bio"], 'r', label='fitted line')
plt.xlabel("%queso blanco past bio")
plt.ylabel("diabetes")
plt.legend()

#queso blanco past y colesterol
pendiente, ordenada, pearson, p_col, error = ss.linregress(sin_galicia_conservas_bio["%queso blanco past bio"],sin_galicia_conservas_bio["colesterol"])
plt.subplot(223)
plt.plot(sin_galicia_conservas_bio["%queso blanco past bio"], sin_galicia_conservas_bio["colesterol"], 'o', label='original data')
plt.plot(sin_galicia_conservas_bio["%queso blanco past bio"], ordenada + pendiente*sin_galicia_conservas_bio["%queso blanco past bio"], 'r', label='fitted line')
plt.xlabel("%queso blanco past bio")
plt.ylabel("colesterol")
plt.legend()

#queso blanco past y obesidad
pendiente, ordenada, pearson, p_obes, error = ss.linregress(sin_galicia_conservas_bio["%queso blanco past bio"],sin_galicia_conservas_bio["obesidad"])
plt.subplot(224)
plt.plot(sin_galicia_conservas_bio["%queso blanco past bio"], sin_galicia_conservas_bio["obesidad"], 'o', label='original data')
plt.plot(sin_galicia_conservas_bio["%queso blanco past bio"], ordenada + pendiente*sin_galicia_conservas_bio["%queso blanco past bio"], 'r', label='fitted line')
plt.xlabel("%queso blanco past bio")
plt.ylabel("obesidad")
plt.legend()

plt.show()

if p_hip < 0.05:
    print(Fore.RED + 'p_value hipertension: ', p_hip)
else:
    print(Style.RESET_ALL + 'p_value hipertension: ', p_hip)

if p_col < 0.05:
    print(Fore.RED + 'p_value colesterol: ', p_col)
else:
    print(Style.RESET_ALL + 'p_value colesterol: ', p_col)

if p_diab < 0.05:
    print(Fore.RED + 'p_value diabetes: ', p_diab)
else:
    print(Style.RESET_ALL + 'p_value diabetes: ', p_diab)

if p_obes < 0.05:
    print(Fore.RED + 'p_value obesidad: ', p_obes)
else:
    print(Style.RESET_ALL + 'p_value obesidad: ', p_obes)
# Out:
# p_value hipertension:  0.8359178943054277
# p_value colesterol:  0.0943683833888223
# p_value diabetes:  0.8395064969434642
# p_value obesidad:  0.04910631890002898
